# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# # TODO: A more generic way is needed here to load the path
# import sys

# sys.path.append(
#     "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
#     # "/global/homes/p/peishi89/jax-watershed/src"
# )

# %%
import optax
import equinox as eqx

import pickle
from functools import partial

from math import floor

# import numpy as np
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import pandas as pd

from jax_canoak.physics.energy_fluxes import get_dispersion_matrix

from jax_canoak.models import CanoakLeafRHHybridIFT
from jax_canoak.models import get_canle, update_canle
from jax_canoak.models import get_soilresp, update_soilresp
from jax_canoak.models import load_model, save_model
# from jax_canoak.models import run_canoak_in_batch

# from jax_canoak.shared_utilities.optim import perform_optimization
from jax_canoak.shared_utilities.optim import perform_optimization_batch, mse
from jax_canoak.shared_utilities import compute_metrics
from jax_canoak.subjects import convert_met_to_batched_met
from jax_canoak.subjects import (
    # convert_batchedstates_to_states,
    convert_obs_to_batched_obs,
)
from jax_canoak.subjects import get_met_forcings, get_obs, initialize_parameters


import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_daily,
    plot_imshow2,
    plot_timeseries_obs_1to1,
    plot_rad,
    plot_ir,
    visualize_tree_diff,
)
from jax_canoak.shared_utilities.plot import (
    plot_obs_1to1,
    plot_obs_comparison,
    plot_obs_energy_closure,
    plot_dij,
    plot_para_sensitivity_ranking,
    plot_le_gs_lai,
    get_time,
)

# from jax_canoak.shared_utilities.plot import plot_veg_temp, plot_dij
# from jax_canoak.shared_utilities.plot import plot_ir, plot_rad, plot_prof2
from jax_canoak.shared_utilities import tune_jax_naninfs_for_debug

jax.config.update("jax_enable_x64", True)
tune_jax_naninfs_for_debug(False)
# jax.config.update("jax_debug_nans", False)
# jax.config.update("jax_debug_infs", False)
# jax.config.update("XLA_PYTHON_CLIENT_ALLOCATOR", 'platform')

# %load_ext autoreload
# %autoreload 2

# %%
# import os
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="FALSE"

# %% [markdown]
# # Model parameters and settings

# %%
time_zone = -8
latitude = 38.0991538
longitude = -121.49933
stomata = 1
veg_ht = 0.8
leafangle = 1
n_can_layers = 50
n_atmos_layers = 50
meas_ht = 5.0
soil_depth = 0.15
n_hr_per_day = 48
niter = 15
# niter = 1

# batch_size = 2
# batch_size = 1274
# batch_size = int(74496/2)
batch_size, batch_size_test = int(74496/2), None

site = "US-Bi1"
key = "hybridRH"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-test.csv"

# Models
f_model = f"{site}_{key}_model.eqx"
# f_model_new = f"{site}_{key}_model.eqx"

# %% [markdown]
# # Load and set the model forcings

# %%
# Training
met, n_time = get_met_forcings(f_forcing)
if batch_size is None: batch_size = n_time
n_batch = floor(n_time / batch_size)
batched_met = convert_met_to_batched_met(met, n_batch, batch_size)
timesteps = get_time(met)

# %%
# Test
met_test, n_time_test = get_met_forcings(f_forcing_test)
if batch_size_test is None: batch_size_test = n_time_test
n_batch_test = floor(n_time_test / batch_size_test)
batched_met_test = convert_met_to_batched_met(met_test, n_batch_test, batch_size_test)
timesteps_test = get_time(met_test)

# %%
plt.plot(met.soilmoisture)

# %% [markdown]
# # Load the observations

# %%
# Training
obs = get_obs(f_obs)

# Test
obs_test = get_obs(f_obs_test)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Create the model parameter instance

# %%
setup, para, para_min, para_max = initialize_parameters(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    obs=obs,
    met=met,
    niter=niter,
    get_para_bounds=True,
)

# %% [markdown]
# # Generate or read the dispersion matrix

# %%
# dij = get_dispersion_matrix(setup, para)
dij = get_dispersion_matrix(setup, para, f"../../data/dij/Dij_{site}.csv")
# import numpy as np
# np.savetxt(f"../../data/dij/Dij_{site}.csv", np.array(dij), delimiter=',')

# %%
plot_dij(dij, para)
# Out:
# <Axes: xlabel='Dij [s/m]', ylabel='Height [m]'>

# %% [markdown]
# # Run CANOAK!

# %%
jax.clear_caches()
canoak_eqx_ift = CanoakLeafRHHybridIFT(para, setup, dij)

# %%
# Training data
# met, prof, ir, qin, sun, shade, soil, veg, can = canoak_eqx_ift(met)
states, drivers = canoak_eqx_ift(met)
met, prof, ir, qin, sun, shade, soil, veg, can = states
quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
# Test data
states_test, drivers_test = canoak_eqx_ift(met_test)
met_test, prof_test, ir_test, qin_test, sun_test, shade_test, soil_test, veg_test, can_test = states_test
quantum_test, nir_test, rnet_test, sun_ang_test, leaf_ang_test, lai_test = drivers_test

# %%
# Leaf relative humidity
plot_imshow2(
    sun.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)

plot_imshow2(
    sun_test.Leaf_RH.T,
    met_test,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")

# %%
# Daily average
plot_daily(met, soil, veg, para);
plot_daily(met_test, soil_test, veg_test, para);

# %%
# Analyze nan
nanind = jnp.where(jnp.isnan(prof.Tair_K.mean(axis=1)))

met.lai[nanind]
# qin.sun_abs[nanind]
# ir.ir_in[nanind]
sun.Tsfc[nanind, :]
# Out:
# Array([], dtype=float64)

# %% [markdown]
# # Local sensitivity analysis

# %%
jax.clear_caches()


@eqx.filter_jit
@partial(jax.grad, argnums=0)
def df_canoak_le(para, met, canoak_eqx):
    canoak_eqx = eqx.tree_at(lambda t: t.para, canoak_eqx, para)
    can_le = canoak_eqx.get_fixed_point_states(met, update_canle, get_canle)
    # met, update_soilresp, get_soilresp)
    return can_le.sum()


@eqx.filter_jit
def df_canoak_le_batched(para, batched_met, canoak_eqx):
    def compute_grad(para, met):
        grad = df_canoak_le(para, met, canoak_eqx)
        return para, grad

    _, gradients = jax.lax.scan(compute_grad, para, xs=batched_met)
    return gradients


# eqx.filter_make_jaxpr(df_canoak_le3)(para, met, canoak_eqx)

# %% [markdown]
# ## Perform SA at one time step

# %%
start, ntime = 20, 1
met2 = jtu.tree_map(lambda x: x[start : start + ntime], met)

# %%
gradients = df_canoak_le(para, met2, canoak_eqx_ift)

# %%
gradients.lleaf
# Out:
# Array(-20.70639241, dtype=float64, weak_type=True)

# %% [markdown]
# ## Perform SA at multiple steps

# %%
jax.clear_caches()
batched_met_sa = convert_met_to_batched_met(met, n_time, 1)
gradients = df_canoak_le_batched(para, batched_met_sa, canoak_eqx_ift)

# %%
plot_para_sensitivity_ranking(gradients, category="photosyn")
# plot_para_sensitivity_ranking(gradients, category=None)

# %%
# gm = jtu.tree_map(lambda x:x.mean(), gradients)
# a, b = jtu.tree_flatten(gm)

# %%
# bb = b.node_data()[1]
# names = bb.dynamic_field_names

# %% [markdown]
# # Comparison with the observations

# %%
plot_obs_energy_closure(obs)
# Out:
# <Axes: xlabel='Rnet, measured', ylabel='H+LE+Gsoil, measured'>

# %%
plot_obs_1to1(obs.rnet, can.rnet, lim=[-50, 800], varn="Rnet")
# Out:
# <Axes: title={'center': 'Rnet (L2: 1371.509)'}, xlabel='Measured', ylabel='Simulated'>

# %%
plot_timeseries_obs_1to1(
    obs.rnet,
    can.rnet,
    lim=[-100, 800],
    met=met,
    varn="Net radiation [W m-2]",
);

# %%
# plt.figure(0)
# plt.plot(obs.P)
# plt.figure(1)
# plt.plot(obs.Rsoil)
# plt.figure(1)
# plt.plot(soil.resp)

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
);

# %%
plot_obs_comparison(obs, can);

# %% [markdown]
# # Perform parameter estimation

# %%
# Filter the parameters to be estimated
filter_model_spec = jtu.tree_map(lambda _: False, canoak_eqx_ift)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.weight for layer in t.para.LeafRHDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.bias for layer in t.para.LeafRHDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [t.para.bprime, t.para.kball, t.para.lleaf, t.para.qalpha],
    filter_model_spec,
    replace=[True, True, True, True],
)

# %%
# Define optimizer and observations
args = [update_canle, get_canle]
# nsteps = 5  # number of epoches
nsteps = 300  # number of epoches
# nsteps = 100  # number of epoches
batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE
scheduler = optax.piecewise_constant_schedule(
    0.01, boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
    # 0.01, boundaries_and_scales={50: 0.1, 100: 0.1, 200: 0.1}
)
# scheduler = optax.exponential_decay(0.01, transition_steps=30, decay_rate=0.1)
# optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
# optim = optax.adam(learning_rate=0.01)  # Adam optimizer

batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE

batched_obs_test = convert_obs_to_batched_obs(obs_test, n_batch_test, batch_size_test)
batched_y_test = batched_obs_test.LE

# %%
# jax.clear_caches()
args = [update_canle, get_canle]
canoak_eqx_new, loss_train_set, loss_test_set = perform_optimization_batch(
    canoak_eqx_ift.get_fixed_point_states,
    filter_model_spec.get_fixed_point_states,
    optim,
    nsteps,
    mse,
    batched_y,
    batched_met,
    batched_y_test,
    batched_met_test,
    para_min,
    para_max,
    *args,
)
# canoak_eqx_new = canoak_eqx_new.args[0]
canoak_eqx_new = canoak_eqx_new.__self__
# Out:
# Argument model is triggering a compile.
# Argument filter_model_spec is triggering a compile.
# Argument batched_y is triggering a compile.
# Argument opt_state is triggering a compile.
# Argument batched_met is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 0: 3106.2444674242934; the test loss of step 0: 2298.373272629875.
# Argument model is triggering a compile.
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 1: 2859.3708101470875; the test loss of step 1: 1965.0795072505227.
# Compiling calculate_test_loss ...
# The training loss of step 2: 2311.926686332598; the test loss of step 2: 1816.8408391122998.
# Compiling calculate_test_loss ...
# The training loss of step 3: 1910.3452418997445; the test loss of step 3: 1960.0700585381044.
# Compiling calculate_test_loss ...
# The training loss of step 4: 1781.9762616685987; the test loss of step 4: 2378.27737855961.
# Compiling calculate_test_loss ...
# The training loss of step 5: 1949.1468126419074; the test loss of step 5: 2720.2808791512343.
# Compiling calculate_test_loss ...
# The training loss of step 6: 2145.726050093752; the test loss of step 6: 2742.358255536542.
# Compiling calculate_test_loss ...
# The training loss of step 7: 2137.344852081627; the test loss of step 7: 2499.037565320319.
# Compiling calculate_test_loss ...
# The training loss of step 8: 1959.8751707464503; the test loss of step 8: 2190.8570548122198.
# Compiling calculate_test_loss ...
# The training loss of step 9: 1775.4671668577403; the test loss of step 9: 1948.5309564155878.
# Compiling calculate_test_loss ...
# The training loss of step 10: 1676.0746503050268; the test loss of step 10: 1807.8547492632358.
# Compiling calculate_test_loss ...
# The training loss of step 11: 1669.957145568293; the test loss of step 11: 1747.4711006632403.
# Compiling calculate_test_loss ...
# The training loss of step 12: 1717.9424296054121; the test loss of step 12: 1729.5961055641226.
# Compiling calculate_test_loss ...
# The training loss of step 13: 1774.8281446414196; the test loss of step 13: 1725.8301603038096.
# Compiling calculate_test_loss ...
# The training loss of step 14: 1812.715662023558; the test loss of step 14: 1721.5036290049795.
# Compiling calculate_test_loss ...
# The training loss of step 15: 1818.7620022266005; the test loss of step 15: 1714.8135707805543.
# Compiling calculate_test_loss ...
# The training loss of step 16: 1794.6757220119664; the test loss of step 16: 1708.5277792073416.
# Compiling calculate_test_loss ...
# The training loss of step 17: 1745.5968190015178; the test loss of step 17: 1712.2236929209275.
# Compiling calculate_test_loss ...
# The training loss of step 18: 1684.79180861219; the test loss of step 18: 1737.7078015140264.
# Compiling calculate_test_loss ...
# The training loss of step 19: 1628.038619872846; the test loss of step 19: 1794.1695768225836.
# Compiling calculate_test_loss ...
# The training loss of step 20: 1591.0585069362537; the test loss of step 20: 1882.3241643195868.
# Compiling calculate_test_loss ...
# The training loss of step 21: 1582.6906748708425; the test loss of step 21: 1984.6531780152816.
# Compiling calculate_test_loss ...
# The training loss of step 22: 1600.1483788930525; the test loss of step 22: 2066.0863916312733.
# Compiling calculate_test_loss ...
# The training loss of step 23: 1623.8507194515546; the test loss of step 23: 2092.719169381772.
# Compiling calculate_test_loss ...
# The training loss of step 24: 1630.4674243235263; the test loss of step 24: 2055.595917335221.
# Compiling calculate_test_loss ...
# The training loss of step 25: 1612.127409121992; the test loss of step 25: 1976.0076220882463.
# Compiling calculate_test_loss ...
# The training loss of step 26: 1581.3875923827727; the test loss of step 26: 1886.414017286234.
# Compiling calculate_test_loss ...
# The training loss of step 27: 1556.6041650942288; the test loss of step 27: 1809.4961432109385.
# Compiling calculate_test_loss ...
# The training loss of step 28: 1547.3062551566113; the test loss of step 28: 1754.3615168886606.
# Compiling calculate_test_loss ...
# The training loss of step 29: 1551.694788759813; the test loss of step 29: 1719.961059530669.
# Compiling calculate_test_loss ...
# The training loss of step 30: 1562.896089276736; the test loss of step 30: 1701.7138407897287.
# Compiling calculate_test_loss ...
# The training loss of step 31: 1572.3562229738345; the test loss of step 31: 1694.6618328810787.
# Compiling calculate_test_loss ...
# The training loss of step 32: 1573.7029548866085; the test loss of step 32: 1696.5637486535563.
# Compiling calculate_test_loss ...
# The training loss of step 33: 1565.3022951454432; the test loss of step 33: 1708.0673491217183.
# Compiling calculate_test_loss ...
# The training loss of step 34: 1549.4556677562357; the test loss of step 34: 1731.1815728806002.
# Compiling calculate_test_loss ...
# The training loss of step 35: 1531.6839792501478; the test loss of step 35: 1766.747155927762.
# Compiling calculate_test_loss ...
# The training loss of step 36: 1517.416115080011; the test loss of step 36: 1811.7102728282207.
# Compiling calculate_test_loss ...
# The training loss of step 37: 1510.9450580213206; the test loss of step 37: 1857.5200938432233.
# Compiling calculate_test_loss ...
# The training loss of step 38: 1511.255160077647; the test loss of step 38: 1892.2336342671974.
# Compiling calculate_test_loss ...
# The training loss of step 39: 1514.0448027891507; the test loss of step 39: 1904.5562085237711.
# Compiling calculate_test_loss ...
# The training loss of step 40: 1513.8448878799952; the test loss of step 40: 1891.2898147601122.
# Compiling calculate_test_loss ...
# The training loss of step 41: 1508.4251984600364; the test loss of step 41: 1858.4076907302583.
# Compiling calculate_test_loss ...
# The training loss of step 42: 1500.2364898361968; the test loss of step 42: 1817.5564639398324.
# Compiling calculate_test_loss ...
# The training loss of step 43: 1493.6489719192812; the test loss of step 43: 1779.1469597072182.
# Compiling calculate_test_loss ...
# The training loss of step 44: 1491.371577154166; the test loss of step 44: 1749.69077154238.
# Compiling calculate_test_loss ...
# The training loss of step 45: 1492.7255701473962; the test loss of step 45: 1731.9885013885398.
# Compiling calculate_test_loss ...
# The training loss of step 46: 1494.7991675717135; the test loss of step 46: 1725.1210371810007.
# Compiling calculate_test_loss ...
# The training loss of step 47: 1494.4505382159746; the test loss of step 47: 1728.957823215889.
# Compiling calculate_test_loss ...
# The training loss of step 48: 1490.7049529333244; the test loss of step 48: 1742.4698039879052.
# Compiling calculate_test_loss ...
# The training loss of step 49: 1484.539330974361; the test loss of step 49: 1764.9875962064011.
# Compiling calculate_test_loss ...
# The training loss of step 50: 1478.5793453956035; the test loss of step 50: 1778.5315377504978.
# Compiling calculate_test_loss ...
# The training loss of step 51: 1476.3749901944416; the test loss of step 51: 1792.4650163645256.
# Compiling calculate_test_loss ...
# The training loss of step 52: 1474.9682797113437; the test loss of step 52: 1805.2971435420168.
# Compiling calculate_test_loss ...
# The training loss of step 53: 1474.0389300376683; the test loss of step 53: 1815.3586638116587.
# Compiling calculate_test_loss ...
# The training loss of step 54: 1473.487618272703; the test loss of step 54: 1821.3879293608106.
# Compiling calculate_test_loss ...
# The training loss of step 55: 1472.9891438159234; the test loss of step 55: 1822.75840927471.
# Compiling calculate_test_loss ...
# The training loss of step 56: 1472.2675651885447; the test loss of step 56: 1819.6918468982578.
# Compiling calculate_test_loss ...
# The training loss of step 57: 1471.219176278656; the test loss of step 57: 1813.0616815082662.
# Compiling calculate_test_loss ...
# The training loss of step 58: 1469.9515555097396; the test loss of step 58: 1803.890962619135.
# Compiling calculate_test_loss ...
# The training loss of step 59: 1468.7915674533233; the test loss of step 59: 1793.7607040743785.
# Compiling calculate_test_loss ...
# The training loss of step 60: 1467.9062302435486; the test loss of step 60: 1783.9845370546493.
# Compiling calculate_test_loss ...
# The training loss of step 61: 1467.3303796047599; the test loss of step 61: 1775.835724204887.
# Compiling calculate_test_loss ...
# The training loss of step 62: 1466.9990179252916; the test loss of step 62: 1769.8332647290392.
# Compiling calculate_test_loss ...
# The training loss of step 63: 1466.6474170467109; the test loss of step 63: 1766.4412323010074.
# Compiling calculate_test_loss ...
# The training loss of step 64: 1466.1720458041661; the test loss of step 64: 1765.8703255115715.
# Compiling calculate_test_loss ...
# The training loss of step 65: 1465.43764493071; the test loss of step 65: 1767.907225339162.
# Compiling calculate_test_loss ...
# The training loss of step 66: 1464.454052146663; the test loss of step 66: 1772.1910160154694.
# Compiling calculate_test_loss ...
# The training loss of step 67: 1463.3645195212987; the test loss of step 67: 1778.1718610804628.
# Compiling calculate_test_loss ...
# The training loss of step 68: 1462.2455680368123; the test loss of step 68: 1784.7537351142569.
# Compiling calculate_test_loss ...
# The training loss of step 69: 1461.3353748474926; the test loss of step 69: 1791.4277987152986.
# Compiling calculate_test_loss ...
# The training loss of step 70: 1460.457638806462; the test loss of step 70: 1797.023200532785.
# Compiling calculate_test_loss ...
# The training loss of step 71: 1459.8465906236738; the test loss of step 71: 1800.9478586860337.
# Compiling calculate_test_loss ...
# The training loss of step 72: 1459.2938856085898; the test loss of step 72: 1802.6708923362833.
# Compiling calculate_test_loss ...
# The training loss of step 73: 1458.698221247323; the test loss of step 73: 1802.0977856923678.
# Compiling calculate_test_loss ...
# The training loss of step 74: 1458.041779552204; the test loss of step 74: 1799.4596844282717.
# Compiling calculate_test_loss ...
# The training loss of step 75: 1457.3600735713635; the test loss of step 75: 1795.4254970922805.
# Compiling calculate_test_loss ...
# The training loss of step 76: 1456.6637147981837; the test loss of step 76: 1790.6003364527617.
# Compiling calculate_test_loss ...
# The training loss of step 77: 1456.04603594514; the test loss of step 77: 1785.984826197004.
# Compiling calculate_test_loss ...
# The training loss of step 78: 1455.4712116198361; the test loss of step 78: 1782.066804438834.
# Compiling calculate_test_loss ...
# The training loss of step 79: 1454.9115624877095; the test loss of step 79: 1779.4495350871218.
# Compiling calculate_test_loss ...
# The training loss of step 80: 1454.4919633418194; the test loss of step 80: 1778.4166451236154.
# Compiling calculate_test_loss ...
# The training loss of step 81: 1453.9201788105588; the test loss of step 81: 1778.8225968292245.
# Compiling calculate_test_loss ...
# The training loss of step 82: 1453.3555948455773; the test loss of step 82: 1780.7761623439742.
# Compiling calculate_test_loss ...
# The training loss of step 83: 1452.684400915548; the test loss of step 83: 1783.7244567809494.
# Compiling calculate_test_loss ...
# The training loss of step 84: 1451.9903009472469; the test loss of step 84: 1787.236100789807.
# Compiling calculate_test_loss ...
# The training loss of step 85: 1451.372100334813; the test loss of step 85: 1790.6180693853144.
# Compiling calculate_test_loss ...
# The training loss of step 86: 1450.7379951015666; the test loss of step 86: 1793.4385697257355.
# Compiling calculate_test_loss ...
# The training loss of step 87: 1450.1713107398095; the test loss of step 87: 1795.270951622246.
# Compiling calculate_test_loss ...
# The training loss of step 88: 1449.5958833748432; the test loss of step 88: 1795.9159153670262.
# Compiling calculate_test_loss ...
# The training loss of step 89: 1448.9754738347337; the test loss of step 89: 1795.2545130235899.
# Compiling calculate_test_loss ...
# The training loss of step 90: 1448.395769434964; the test loss of step 90: 1793.6540189937089.
# Compiling calculate_test_loss ...
# The training loss of step 91: 1447.8748547980704; the test loss of step 91: 1791.3857295952898.
# Compiling calculate_test_loss ...
# The training loss of step 92: 1447.372241278783; the test loss of step 92: 1788.9370893511664.
# Compiling calculate_test_loss ...
# The training loss of step 93: 1446.8641530860896; the test loss of step 93: 1786.8548976194024.
# Compiling calculate_test_loss ...
# The training loss of step 94: 1446.3630477304591; the test loss of step 94: 1785.3068250057918.
# Compiling calculate_test_loss ...
# The training loss of step 95: 1445.8476149058715; the test loss of step 95: 1784.715212562772.
# Compiling calculate_test_loss ...
# The training loss of step 96: 1445.3084661669682; the test loss of step 96: 1784.9550210838129.
# Compiling calculate_test_loss ...
# The training loss of step 97: 1444.7437455181325; the test loss of step 97: 1785.9726728171208.
# Compiling calculate_test_loss ...
# The training loss of step 98: 1444.1962962413209; the test loss of step 98: 1787.5575770163857.
# Compiling calculate_test_loss ...
# The training loss of step 99: 1443.6871383566126; the test loss of step 99: 1789.401659248975.
# Compiling calculate_test_loss ...
# The training loss of step 100: 1443.146767151123; the test loss of step 100: 1790.280598500011.
# Compiling calculate_test_loss ...
# The training loss of step 101: 1442.892945854926; the test loss of step 101: 1791.057768762967.
# Compiling calculate_test_loss ...
# The training loss of step 102: 1442.6088498937222; the test loss of step 102: 1791.6474557102076.
# Compiling calculate_test_loss ...
# The training loss of step 103: 1442.3222369132177; the test loss of step 103: 1791.9679533709484.
# Compiling calculate_test_loss ...
# The training loss of step 104: 1442.083164350467; the test loss of step 104: 1792.117256506563.
# Compiling calculate_test_loss ...
# The training loss of step 105: 1441.8336669730068; the test loss of step 105: 1792.0035940668756.
# Compiling calculate_test_loss ...
# The training loss of step 106: 1441.5893283799978; the test loss of step 106: 1791.7613717804647.
# Compiling calculate_test_loss ...
# The training loss of step 107: 1441.3414106488708; the test loss of step 107: 1791.3039613390067.
# Compiling calculate_test_loss ...
# The training loss of step 108: 1441.1201372493713; the test loss of step 108: 1790.7650291565008.
# Compiling calculate_test_loss ...
# The training loss of step 109: 1440.8361666830604; the test loss of step 109: 1790.1864001369881.
# Compiling calculate_test_loss ...
# The training loss of step 110: 1440.6253081216078; the test loss of step 110: 1789.6606074317701.
# Compiling calculate_test_loss ...
# The training loss of step 111: 1440.396662034781; the test loss of step 111: 1789.2023583013422.
# Compiling calculate_test_loss ...
# The training loss of step 112: 1440.1754372348776; the test loss of step 112: 1788.8704112061332.
# Compiling calculate_test_loss ...
# The training loss of step 113: 1439.9379833085873; the test loss of step 113: 1788.7546597189398.
# Compiling calculate_test_loss ...
# The training loss of step 114: 1439.68561856584; the test loss of step 114: 1788.7375139500186.
# Compiling calculate_test_loss ...
# The training loss of step 115: 1439.444116382419; the test loss of step 115: 1788.8844448900873.
# Compiling calculate_test_loss ...
# The training loss of step 116: 1439.2129410182627; the test loss of step 116: 1789.1558480899664.
# Compiling calculate_test_loss ...
# The training loss of step 117: 1438.9699704001578; the test loss of step 117: 1789.524127052524.
# Compiling calculate_test_loss ...
# The training loss of step 118: 1438.7261970206605; the test loss of step 118: 1789.9741452477735.
# Compiling calculate_test_loss ...
# The training loss of step 119: 1438.4572395927853; the test loss of step 119: 1790.3897099212063.
# Compiling calculate_test_loss ...
# The training loss of step 120: 1438.234656356452; the test loss of step 120: 1790.749853581719.
# Compiling calculate_test_loss ...
# The training loss of step 121: 1437.9917857374908; the test loss of step 121: 1791.0409306007627.
# Compiling calculate_test_loss ...
# The training loss of step 122: 1437.7410302295293; the test loss of step 122: 1791.2032159357743.
# Compiling calculate_test_loss ...
# The training loss of step 123: 1437.4919173906555; the test loss of step 123: 1791.3080077196598.
# Compiling calculate_test_loss ...
# The training loss of step 124: 1437.2856529497817; the test loss of step 124: 1791.2873635967208.
# Compiling calculate_test_loss ...
# The training loss of step 125: 1436.992245102746; the test loss of step 125: 1791.156900506882.
# Compiling calculate_test_loss ...
# The training loss of step 126: 1436.7694555012758; the test loss of step 126: 1790.9474095221294.
# Compiling calculate_test_loss ...
# The training loss of step 127: 1436.5444302794128; the test loss of step 127: 1790.7206472988466.
# Compiling calculate_test_loss ...
# The training loss of step 128: 1436.2850619212154; the test loss of step 128: 1790.4722110428859.
# Compiling calculate_test_loss ...
# The training loss of step 129: 1436.049024913169; the test loss of step 129: 1790.2689531497726.
# Compiling calculate_test_loss ...
# The training loss of step 130: 1435.8145903980412; the test loss of step 130: 1790.1191252009844.
# Compiling calculate_test_loss ...
# The training loss of step 131: 1435.5871843781633; the test loss of step 131: 1790.0142812962988.
# Compiling calculate_test_loss ...
# The training loss of step 132: 1435.3292045678377; the test loss of step 132: 1789.9565432090687.
# Compiling calculate_test_loss ...
# The training loss of step 133: 1435.1032669321787; the test loss of step 133: 1789.978988041353.
# Compiling calculate_test_loss ...
# The training loss of step 134: 1434.8681086048898; the test loss of step 134: 1790.080261344685.
# Compiling calculate_test_loss ...
# The training loss of step 135: 1434.610319400874; the test loss of step 135: 1790.2085976340004.
# Compiling calculate_test_loss ...
# The training loss of step 136: 1434.3294217287257; the test loss of step 136: 1790.3332523874192.
# Compiling calculate_test_loss ...
# The training loss of step 137: 1434.0935182862834; the test loss of step 137: 1790.4960723867994.
# Compiling calculate_test_loss ...
# The training loss of step 138: 1433.8506252653647; the test loss of step 138: 1790.6578685263198.
# Compiling calculate_test_loss ...
# The training loss of step 139: 1433.5829910228754; the test loss of step 139: 1790.7790070613364.
# Compiling calculate_test_loss ...
# The training loss of step 140: 1433.328780472627; the test loss of step 140: 1790.8231456764634.
# Compiling calculate_test_loss ...
# The training loss of step 141: 1433.0926694299906; the test loss of step 141: 1790.8467374761635.
# Compiling calculate_test_loss ...
# The training loss of step 142: 1432.8633013349468; the test loss of step 142: 1790.8125328778337.
# Compiling calculate_test_loss ...
# The training loss of step 143: 1432.6620671134024; the test loss of step 143: 1790.6929300693917.
# Compiling calculate_test_loss ...
# The training loss of step 144: 1432.408696432516; the test loss of step 144: 1790.5890176370895.
# Compiling calculate_test_loss ...
# The training loss of step 145: 1432.172171609107; the test loss of step 145: 1790.47353631933.
# Compiling calculate_test_loss ...
# The training loss of step 146: 1431.9415223178771; the test loss of step 146: 1790.3753160863266.
# Compiling calculate_test_loss ...
# The training loss of step 147: 1431.6971943503177; the test loss of step 147: 1790.28995272838.
# Compiling calculate_test_loss ...
# The training loss of step 148: 1431.453894354726; the test loss of step 148: 1790.197182607076.
# Compiling calculate_test_loss ...
# The training loss of step 149: 1431.223364211324; the test loss of step 149: 1790.1536187941863.
# Compiling calculate_test_loss ...
# The training loss of step 150: 1431.0228180981871; the test loss of step 150: 1790.1418897017847.
# Compiling calculate_test_loss ...
# The training loss of step 151: 1430.803468226228; the test loss of step 151: 1790.1735710686485.
# Compiling calculate_test_loss ...
# The training loss of step 152: 1430.5799731149054; the test loss of step 152: 1790.2016935628621.
# Compiling calculate_test_loss ...
# The training loss of step 153: 1430.359918755625; the test loss of step 153: 1790.2572433968623.
# Compiling calculate_test_loss ...
# The training loss of step 154: 1430.1281163596934; the test loss of step 154: 1790.3337699279791.
# Compiling calculate_test_loss ...
# The training loss of step 155: 1429.8934810653313; the test loss of step 155: 1790.391519702322.
# Compiling calculate_test_loss ...
# The training loss of step 156: 1429.6595357810006; the test loss of step 156: 1790.4542767010728.
# Compiling calculate_test_loss ...
# The training loss of step 157: 1429.4161780753639; the test loss of step 157: 1790.510762186838.
# Compiling calculate_test_loss ...
# The training loss of step 158: 1429.190816333676; the test loss of step 158: 1790.5494622352403.
# Compiling calculate_test_loss ...
# The training loss of step 159: 1428.950496601493; the test loss of step 159: 1790.5191766522303.
# Compiling calculate_test_loss ...
# The training loss of step 160: 1428.6989525945032; the test loss of step 160: 1790.4786846063887.
# Compiling calculate_test_loss ...
# The training loss of step 161: 1428.4868054005583; the test loss of step 161: 1790.4295596854195.
# Compiling calculate_test_loss ...
# The training loss of step 162: 1428.2627659616653; the test loss of step 162: 1790.3549493788262.
# Compiling calculate_test_loss ...
# The training loss of step 163: 1428.0511952057136; the test loss of step 163: 1790.2685129792399.
# Compiling calculate_test_loss ...
# The training loss of step 164: 1427.8163099493725; the test loss of step 164: 1790.1912071571992.
# Compiling calculate_test_loss ...
# The training loss of step 165: 1427.5917874659874; the test loss of step 165: 1790.1528282699842.
# Compiling calculate_test_loss ...
# The training loss of step 166: 1427.364729562038; the test loss of step 166: 1790.1289923339757.
# Compiling calculate_test_loss ...
# The training loss of step 167: 1427.145968309084; the test loss of step 167: 1790.1012204267065.
# Compiling calculate_test_loss ...
# The training loss of step 168: 1426.8986184606695; the test loss of step 168: 1790.0945150112705.
# Compiling calculate_test_loss ...
# The training loss of step 169: 1426.6587255624358; the test loss of step 169: 1790.068949623503.
# Compiling calculate_test_loss ...
# The training loss of step 170: 1426.4532622636852; the test loss of step 170: 1790.0668772151532.
# Compiling calculate_test_loss ...
# The training loss of step 171: 1426.2230735543908; the test loss of step 171: 1790.0773663835132.
# Compiling calculate_test_loss ...
# The training loss of step 172: 1425.9977237053456; the test loss of step 172: 1790.1111158140081.
# Compiling calculate_test_loss ...
# The training loss of step 173: 1425.7943423757356; the test loss of step 173: 1790.1172951694552.
# Compiling calculate_test_loss ...
# The training loss of step 174: 1425.5745449146366; the test loss of step 174: 1790.139363138338.
# Compiling calculate_test_loss ...
# The training loss of step 175: 1425.3447284316908; the test loss of step 175: 1790.1397952430402.
# Compiling calculate_test_loss ...
# The training loss of step 176: 1425.1539087948404; the test loss of step 176: 1790.1444470172914.
# Compiling calculate_test_loss ...
# The training loss of step 177: 1424.9740611786851; the test loss of step 177: 1790.1112671119997.
# Compiling calculate_test_loss ...
# The training loss of step 178: 1424.7364333357068; the test loss of step 178: 1790.102996069664.
# Compiling calculate_test_loss ...
# The training loss of step 179: 1424.523248458001; the test loss of step 179: 1790.0882154275898.
# Compiling calculate_test_loss ...
# The training loss of step 180: 1424.3349589182185; the test loss of step 180: 1790.102403589418.
# Compiling calculate_test_loss ...
# The training loss of step 181: 1424.1204710291227; the test loss of step 181: 1790.1074573636733.
# Compiling calculate_test_loss ...
# The training loss of step 182: 1423.8973654642614; the test loss of step 182: 1790.1091247865377.
# Compiling calculate_test_loss ...
# The training loss of step 183: 1423.6839879856038; the test loss of step 183: 1790.0899652279995.
# Compiling calculate_test_loss ...
# The training loss of step 184: 1423.4930369605677; the test loss of step 184: 1790.0715590625152.
# Compiling calculate_test_loss ...
# The training loss of step 185: 1423.2861355869293; the test loss of step 185: 1790.023560909524.
# Compiling calculate_test_loss ...
# The training loss of step 186: 1423.0985661582545; the test loss of step 186: 1789.9905595259095.
# Compiling calculate_test_loss ...
# The training loss of step 187: 1422.8771147858051; the test loss of step 187: 1789.994212279475.
# Compiling calculate_test_loss ...
# The training loss of step 188: 1422.6552736708313; the test loss of step 188: 1789.9773578474696.
# Compiling calculate_test_loss ...
# The training loss of step 189: 1422.4288952492439; the test loss of step 189: 1789.9864310069174.
# Compiling calculate_test_loss ...
# The training loss of step 190: 1422.2175146504392; the test loss of step 190: 1789.9150328956687.
# Compiling calculate_test_loss ...
# The training loss of step 191: 1421.998767931574; the test loss of step 191: 1789.890154854633.
# Compiling calculate_test_loss ...
# The training loss of step 192: 1421.8064179138514; the test loss of step 192: 1789.833074372324.
# Compiling calculate_test_loss ...
# The training loss of step 193: 1421.5976751230237; the test loss of step 193: 1789.7886195665371.
# Compiling calculate_test_loss ...
# The training loss of step 194: 1421.389307042408; the test loss of step 194: 1789.7026859536168.
# Compiling calculate_test_loss ...
# The training loss of step 195: 1421.161194417124; the test loss of step 195: 1789.6895508789762.
# Compiling calculate_test_loss ...
# The training loss of step 196: 1420.947737616193; the test loss of step 196: 1789.654734835567.
# Compiling calculate_test_loss ...
# The training loss of step 197: 1420.7550476520676; the test loss of step 197: 1789.6590811064511.
# Compiling calculate_test_loss ...
# The training loss of step 198: 1420.5479102881395; the test loss of step 198: 1789.6397858922949.
# Compiling calculate_test_loss ...
# The training loss of step 199: 1420.3805314933606; the test loss of step 199: 1789.7110053375998.
# Compiling calculate_test_loss ...
# The training loss of step 200: 1420.1760736319738; the test loss of step 200: 1789.6904246115912.
# Compiling calculate_test_loss ...
# The training loss of step 201: 1420.0792305687626; the test loss of step 201: 1789.6857709936196.
# Compiling calculate_test_loss ...
# The training loss of step 202: 1419.9945666981816; the test loss of step 202: 1789.6660174616657.
# Compiling calculate_test_loss ...
# The training loss of step 203: 1419.895129101943; the test loss of step 203: 1789.6692085759555.
# Compiling calculate_test_loss ...
# The training loss of step 204: 1419.8212307900105; the test loss of step 204: 1789.6570725955496.
# Compiling calculate_test_loss ...
# The training loss of step 205: 1419.789820298673; the test loss of step 205: 1789.6599291354662.
# Compiling calculate_test_loss ...
# The training loss of step 206: 1419.6499001390416; the test loss of step 206: 1789.6295999808628.
# Compiling calculate_test_loss ...
# The training loss of step 207: 1419.5718092413485; the test loss of step 207: 1789.6253932061672.
# Compiling calculate_test_loss ...
# The training loss of step 208: 1419.4753582921198; the test loss of step 208: 1789.602556853947.
# Compiling calculate_test_loss ...
# The training loss of step 209: 1419.3541461316324; the test loss of step 209: 1789.5886039314464.
# Compiling calculate_test_loss ...
# The training loss of step 210: 1419.248722667128; the test loss of step 210: 1789.5852658048614.
# Compiling calculate_test_loss ...
# The training loss of step 211: 1419.1570338560223; the test loss of step 211: 1789.5638264750344.
# Compiling calculate_test_loss ...
# The training loss of step 212: 1419.0691477638; the test loss of step 212: 1789.542792711314.
# Compiling calculate_test_loss ...
# The training loss of step 213: 1418.9939609330445; the test loss of step 213: 1789.5148774754239.
# Compiling calculate_test_loss ...
# The training loss of step 214: 1418.8852187561392; the test loss of step 214: 1789.5181708760651.
# Compiling calculate_test_loss ...
# The training loss of step 215: 1418.7843292638609; the test loss of step 215: 1789.4981743250232.
# Compiling calculate_test_loss ...
# The training loss of step 216: 1418.68601621567; the test loss of step 216: 1789.473538404951.
# Compiling calculate_test_loss ...
# The training loss of step 217: 1418.5831744786865; the test loss of step 217: 1789.4599340448037.
# Compiling calculate_test_loss ...
# The training loss of step 218: 1418.4908732271406; the test loss of step 218: 1789.4221015447988.
# Compiling calculate_test_loss ...
# The training loss of step 219: 1418.4104582500622; the test loss of step 219: 1789.3743149692841.
# Compiling calculate_test_loss ...
# The training loss of step 220: 1418.3078470151413; the test loss of step 220: 1789.3510494068828.
# Compiling calculate_test_loss ...
# The training loss of step 221: 1418.2017543947677; the test loss of step 221: 1789.316046512568.
# Compiling calculate_test_loss ...
# The training loss of step 222: 1418.0945146350007; the test loss of step 222: 1789.2956180039766.
# Compiling calculate_test_loss ...
# The training loss of step 223: 1417.9617736010166; the test loss of step 223: 1789.2631278123017.
# Compiling calculate_test_loss ...
# The training loss of step 224: 1417.862290967851; the test loss of step 224: 1789.2694260727674.
# Compiling calculate_test_loss ...
# The training loss of step 225: 1417.7790891405825; the test loss of step 225: 1789.2435234942445.
# Compiling calculate_test_loss ...
# The training loss of step 226: 1417.6950407321522; the test loss of step 226: 1789.213757897919.
# Compiling calculate_test_loss ...
# The training loss of step 227: 1417.587326135615; the test loss of step 227: 1789.192624941468.
# Compiling calculate_test_loss ...
# The training loss of step 228: 1417.48531252357; the test loss of step 228: 1789.174260018182.
# Compiling calculate_test_loss ...
# The training loss of step 229: 1417.4116514384054; the test loss of step 229: 1789.152260824695.
# Compiling calculate_test_loss ...
# The training loss of step 230: 1417.316337053798; the test loss of step 230: 1789.1353497541747.
# Compiling calculate_test_loss ...
# The training loss of step 231: 1417.2048952158048; the test loss of step 231: 1789.1157627263212.
# Compiling calculate_test_loss ...
# The training loss of step 232: 1417.0933859403697; the test loss of step 232: 1789.1034051737386.
# Compiling calculate_test_loss ...
# The training loss of step 233: 1416.9740394316173; the test loss of step 233: 1789.0976593211544.
# Compiling calculate_test_loss ...
# The training loss of step 234: 1416.8880978340112; the test loss of step 234: 1789.083523395565.
# Compiling calculate_test_loss ...
# The training loss of step 235: 1416.7866848016454; the test loss of step 235: 1789.0818268619303.
# Compiling calculate_test_loss ...
# The training loss of step 236: 1416.6810568793762; the test loss of step 236: 1789.0704892042618.
# Compiling calculate_test_loss ...
# The training loss of step 237: 1416.600502621757; the test loss of step 237: 1789.0697854171522.
# Compiling calculate_test_loss ...
# The training loss of step 238: 1416.4768254571575; the test loss of step 238: 1789.0517413752136.
# Compiling calculate_test_loss ...
# The training loss of step 239: 1416.3891718771965; the test loss of step 239: 1789.008271320429.
# Compiling calculate_test_loss ...
# The training loss of step 240: 1416.332699223709; the test loss of step 240: 1788.9925779068308.
# Compiling calculate_test_loss ...
# The training loss of step 241: 1416.172528229275; the test loss of step 241: 1788.9739324816155.
# Compiling calculate_test_loss ...
# The training loss of step 242: 1416.0830264026724; the test loss of step 242: 1788.9417773575547.
# Compiling calculate_test_loss ...
# The training loss of step 243: 1415.998169991714; the test loss of step 243: 1788.9235491606378.
# Compiling calculate_test_loss ...
# The training loss of step 244: 1415.8967579627406; the test loss of step 244: 1788.910117191444.
# Compiling calculate_test_loss ...
# The training loss of step 245: 1415.795974322346; the test loss of step 245: 1788.8988511893124.
# Compiling calculate_test_loss ...
# The training loss of step 246: 1415.7236524905538; the test loss of step 246: 1788.8956319087101.
# Compiling calculate_test_loss ...
# The training loss of step 247: 1415.6360174989215; the test loss of step 247: 1788.8953595443434.
# Compiling calculate_test_loss ...
# The training loss of step 248: 1415.5513295015162; the test loss of step 248: 1788.870822257909.
# Compiling calculate_test_loss ...
# The training loss of step 249: 1415.453256260339; the test loss of step 249: 1788.8542350578728.
# Compiling calculate_test_loss ...
# The training loss of step 250: 1415.3448635211516; the test loss of step 250: 1788.8497952486312.
# Compiling calculate_test_loss ...
# The training loss of step 251: 1415.2691039117308; the test loss of step 251: 1788.8319047803502.
# Compiling calculate_test_loss ...
# The training loss of step 252: 1415.172635722295; the test loss of step 252: 1788.8129935133752.
# Compiling calculate_test_loss ...
# The training loss of step 253: 1415.0889271530386; the test loss of step 253: 1788.8012778697441.
# Compiling calculate_test_loss ...
# The training loss of step 254: 1414.9897772686568; the test loss of step 254: 1788.779046228071.
# Compiling calculate_test_loss ...
# The training loss of step 255: 1414.8906244469658; the test loss of step 255: 1788.7648222607572.
# Compiling calculate_test_loss ...
# The training loss of step 256: 1414.788585369485; the test loss of step 256: 1788.7280919504865.
# Compiling calculate_test_loss ...
# The training loss of step 257: 1414.6833506952444; the test loss of step 257: 1788.7050079914102.
# Compiling calculate_test_loss ...
# The training loss of step 258: 1414.581073617952; the test loss of step 258: 1788.6712590245108.
# Compiling calculate_test_loss ...
# The training loss of step 259: 1414.4879929598715; the test loss of step 259: 1788.652751590221.
# Compiling calculate_test_loss ...
# The training loss of step 260: 1414.3854902645257; the test loss of step 260: 1788.6439426317877.
# Compiling calculate_test_loss ...
# The training loss of step 261: 1414.2899201896362; the test loss of step 261: 1788.6100836817623.
# Compiling calculate_test_loss ...
# The training loss of step 262: 1414.1974300016275; the test loss of step 262: 1788.592608578956.
# Compiling calculate_test_loss ...
# The training loss of step 263: 1414.087999914752; the test loss of step 263: 1788.5535573020798.
# Compiling calculate_test_loss ...
# The training loss of step 264: 1413.9901397792985; the test loss of step 264: 1788.5292418749302.
# Compiling calculate_test_loss ...
# The training loss of step 265: 1413.8994770472545; the test loss of step 265: 1788.4840082366334.
# Compiling calculate_test_loss ...
# The training loss of step 266: 1413.786342928775; the test loss of step 266: 1788.4713953235625.
# Compiling calculate_test_loss ...
# The training loss of step 267: 1413.68417056237; the test loss of step 267: 1788.4604726349455.
# Compiling calculate_test_loss ...
# The training loss of step 268: 1413.5937161126067; the test loss of step 268: 1788.4635982167738.
# Compiling calculate_test_loss ...
# The training loss of step 269: 1413.5160402939553; the test loss of step 269: 1788.4583930177469.
# Compiling calculate_test_loss ...
# The training loss of step 270: 1413.4190295274711; the test loss of step 270: 1788.45035771182.
# Compiling calculate_test_loss ...
# The training loss of step 271: 1413.313860825053; the test loss of step 271: 1788.442242072484.
# Compiling calculate_test_loss ...
# The training loss of step 272: 1413.214477475407; the test loss of step 272: 1788.4264898619515.
# Compiling calculate_test_loss ...
# The training loss of step 273: 1413.1300595126404; the test loss of step 273: 1788.39542512447.
# Compiling calculate_test_loss ...
# The training loss of step 274: 1413.0379909960493; the test loss of step 274: 1788.3737633452108.
# Compiling calculate_test_loss ...
# The training loss of step 275: 1412.9380623744569; the test loss of step 275: 1788.355059970357.
# Compiling calculate_test_loss ...
# The training loss of step 276: 1412.8418134616054; the test loss of step 276: 1788.307083988405.
# Compiling calculate_test_loss ...
# The training loss of step 277: 1412.7463750352372; the test loss of step 277: 1788.2870227015035.
# Compiling calculate_test_loss ...
# The training loss of step 278: 1412.6701430850917; the test loss of step 278: 1788.2653182451934.
# Compiling calculate_test_loss ...
# The training loss of step 279: 1412.5845240494637; the test loss of step 279: 1788.250738940743.
# Compiling calculate_test_loss ...
# The training loss of step 280: 1412.4818912084338; the test loss of step 280: 1788.2347062467181.
# Compiling calculate_test_loss ...
# The training loss of step 281: 1412.3886632986478; the test loss of step 281: 1788.2228704645763.
# Compiling calculate_test_loss ...
# The training loss of step 282: 1412.3122891434164; the test loss of step 282: 1788.2148856446845.
# Compiling calculate_test_loss ...
# The training loss of step 283: 1412.2120115699768; the test loss of step 283: 1788.2061185327764.
# Compiling calculate_test_loss ...
# The training loss of step 284: 1412.123803825251; the test loss of step 284: 1788.1972108330608.
# Compiling calculate_test_loss ...
# The training loss of step 285: 1412.0132634439756; the test loss of step 285: 1788.1840735869387.
# Compiling calculate_test_loss ...
# The training loss of step 286: 1411.9215872416908; the test loss of step 286: 1788.1799845050045.
# Compiling calculate_test_loss ...
# The training loss of step 287: 1411.8437824814741; the test loss of step 287: 1788.170862383977.
# Compiling calculate_test_loss ...
# The training loss of step 288: 1411.7444497953845; the test loss of step 288: 1788.1678763095258.
# Compiling calculate_test_loss ...
# The training loss of step 289: 1411.639434657276; the test loss of step 289: 1788.1850746048358.
# Compiling calculate_test_loss ...
# The training loss of step 290: 1411.5385193440832; the test loss of step 290: 1788.1526749564853.
# Compiling calculate_test_loss ...
# The training loss of step 291: 1411.4481813214672; the test loss of step 291: 1788.1641796652493.
# Compiling calculate_test_loss ...
# The training loss of step 292: 1411.3533015111207; the test loss of step 292: 1788.130485651367.
# Compiling calculate_test_loss ...
# The training loss of step 293: 1411.268891868833; the test loss of step 293: 1788.1265639195458.
# Compiling calculate_test_loss ...
# The training loss of step 294: 1411.1669416722575; the test loss of step 294: 1788.1096103035522.
# Compiling calculate_test_loss ...
# The training loss of step 295: 1411.0677646849626; the test loss of step 295: 1788.1015366009178.
# Compiling calculate_test_loss ...
# The training loss of step 296: 1410.978196391863; the test loss of step 296: 1788.091720129315.
# Compiling calculate_test_loss ...
# The training loss of step 297: 1410.8805425978505; the test loss of step 297: 1788.06285618511.
# Compiling calculate_test_loss ...
# The training loss of step 298: 1410.806132176927; the test loss of step 298: 1788.0408040681627.
# Compiling calculate_test_loss ...
# The training loss of step 299: 1410.7217564407974; the test loss of step 299: 1788.0135203023758.

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.plot(loss_train_set, label='Train')
ax.plot(loss_test_set, label='Test')
ax.set(xlabel="Epochs", ylabel="L2", title="Loss function", yscale="linear");
ax.legend()

# %% [markdown]
# ## Rerun the model using the estimated parameters

# %% [markdown]
# ### Calibration period

# %%
states, drivers = canoak_eqx_new(met)
(
    met_new,
    prof_new,
    ir_new,
    qin_new,
    sun_new,
    shade_new,
    soil_new,
    veg_new,
    can_new,
) = states
# quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
plot_obs_comparison(obs, can_new);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can_new.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %% [markdown]
# ### Test period

# %%
states_test, drivers_test = canoak_eqx_new(met_test)
(
    _,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test

# %%
plot_obs_comparison(obs_test, can_test);

# %%
plot_timeseries_obs_1to1(
    obs_test.LE,
    can_test.LE,
    lim=[-100, 1000],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
);

# %%
metrics = compute_metrics(obs.LE, can_new.LE)
metrics_test = compute_metrics(obs_test.LE, can_test.LE)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 37.55838841651255, 'mse': 1410.632540445624, 'r2': 0.8765311001689461, 'kge': 0.9161982802549525, 'nse': 0.8631958619234232, 'mkge': 0.9246599524007678, 'cc': 0.9363786298909711, 'alpha': 1.0143661576278653, 'beta': 1.0377101783702471}
# {'rmse': 42.28490889551944, 'mse': 1788.0135203023794, 'r2': 0.8502472673274408, 'kge': 0.7613572990591261, 'nse': 0.7841017774724016, 'mkge': 0.8461301456355814, 'cc': 0.9291922530036875, 'alpha': 1.1079498800425445, 'beta': 1.0837198808302653}

# %% [markdown]
# # Save the models

# %%
config = {
    "site": site,
    "key": key,
    "f_forcing": f_forcing,
    "f_obs": f_obs,
    "f_forcing_test": f_forcing_test,
    "f_obs_test": f_obs_test,
}

train = {
    "loss": loss_train_set,
    "time": timesteps,
    "can.LE": can_new.LE,
    "sun.gs": sun_new.gs,
    "shade.gs": shade_new.gs,
    "sun.Ps": sun_new.Ps,
    "shade.Ps": shade_new.Ps,
    "can.H": can_new.H,
    "can.rnet": can_new.rnet,
    "can.gsoil": can_new.gsoil,
    "sun.Tlk": sun_new.Tsfc,
    "shade.Tlk": shade_new.Tsfc,
    "sun.Leaf_RH": sun_new.Leaf_RH,
    "shade.Leaf_RH": shade_new.Leaf_RH,
    "soil.Tsoil": soil_new.T_soil,
}

test = {
    "loss": loss_test_set,
    "time": timesteps_test,
    "can.LE": can_test.LE,
    "sun.gs": sun_test.gs,
    "shade.gs": shade_test.gs,
    "sun.Ps": sun_test.Ps,
    "shade.Ps": shade_test.Ps,
    "can.H": can_test.H,
    "can.rnet": can_test.rnet,
    "can.gsoil": can_test.gsoil,
    "sun.Tlk": sun_test.Tsfc,
    "shade.Tlk": shade_test.Tsfc,
    "sun.Leaf_RH": sun_test.Leaf_RH,
    "shade.Leaf_RH": shade_test.Leaf_RH,
    "soil.Tsoil": soil_test.T_soil,
}

out = {"train": train, "test": test, "config": config}
pickle.dump(out, open(f"{site}_{key}.pkl", "wb"), pickle.HIGHEST_PROTOCOL)

# %%
# Save the model
hyperparams = dict(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    niter=niter,
)

save_model(f_model, hyperparams, canoak_eqx_new)
