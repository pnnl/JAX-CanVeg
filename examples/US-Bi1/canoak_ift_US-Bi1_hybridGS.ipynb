# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# TODO: A more generic way is needed here to load the path
import sys

sys.path.append(
    "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
    # "/global/homes/p/peishi89/jax-watershed/src"
)

# %%
import optax
import equinox as eqx

from functools import partial

from math import floor

# import numpy as np
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import pandas as pd

from jax_canoak.physics.energy_fluxes import get_dispersion_matrix

# from jax_canoak.models import CanoakIFT
from jax_canoak.models import CanoakGSHybridIFT
from jax_canoak.models import get_canle, update_canle

# from jax_canoak.shared_utilities.optim import perform_optimization
from jax_canoak.shared_utilities.optim import perform_optimization_batch
from jax_canoak.subjects import convert_met_to_batched_met
from jax_canoak.subjects import (
    # convert_batchedstates_to_states,
    convert_obs_to_batched_obs,
)
from jax_canoak.subjects import get_met_forcings, get_obs, initialize_parameters
from jax_canoak.models import run_canoak_in_batch

# from jax_canoak.models import run_canoak_in_batch_any

import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_daily,
    plot_imshow2,
    plot_timeseries_obs_1to1,
    plot_rad,
    plot_ir,
    visualize_tree_diff,
)
from jax_canoak.shared_utilities.plot import (
    plot_obs_1to1,
    plot_obs_comparison,
    plot_obs_energy_closure,
    plot_dij,
    plot_para_sensitivity_ranking,
    plot_le_gs_lai,
    get_time,
)

# from jax_canoak.shared_utilities.plot import plot_veg_temp, plot_dij
# from jax_canoak.shared_utilities.plot import plot_ir, plot_rad, plot_prof2

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_debug_nans", False)
jax.config.update("jax_debug_infs", False)
# jax.config.update("XLA_PYTHON_CLIENT_ALLOCATOR", 'platform')

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Model parameters and settings

# %%
time_zone = -8
latitude = 38.0991538
longitude = -121.49933
stomata = 1
veg_ht = 0.8
leafangle = 1
n_can_layers = 50
n_atmos_layers = 50
meas_ht = 5.0
soil_depth = 0.15
n_hr_per_day = 48
niter = 15
# niter = 1

batch_size = 1
# batch_size = 1274

# Calibration period
f_forcing = "../data/fluxtower/US-Bi1/US-Bi1-forcings.csv"
f_obs = "../data/fluxtower/US-Bi1/US-Bi1-fluxes.csv"

# Test period
f_forcing_test = "../data/fluxtower/US-Bi1/US-Bi1-forcings-test.csv"
f_obs_test = "../data/fluxtower/US-Bi1/US-Bi1-fluxes-test.csv"

# %% [markdown]
# # Load the observations

# %%
obs = get_obs(f_obs)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Load and set the model forcings

# %%
met, n_time = get_met_forcings(f_forcing)
n_batch = floor(n_time / batch_size)
batched_met = convert_met_to_batched_met(met, n_batch, batch_size)

timesteps = get_time(met)

# %%
# plt.plot(met.eair_Pa)
# plt.plot(met.es)
# plt.plot(met.lai)
# plt.plot(veg_new.gs)
plt.plot(met.soilmoisture)

# %% [markdown]
# # Create the model parameter instance

# %%
setup, para, para_min, para_max = initialize_parameters(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    obs=obs,
    met=met,
    niter=niter,
    get_para_bounds=True,
)

# %% [markdown]
# # Generate or read the dispersion matrix

# %%
# dij = get_dispersion_matrix(setup, para)
dij = get_dispersion_matrix(setup, para, "../data/dij/Dij_US-Bi1.csv")
# import numpy as np
# np.savetxt("../data/dij/Dij_US-Bi1.csv", np.array(dij), delimiter=',')

# %%
plot_dij(dij, para)
# Out:
# <Axes: xlabel='Dij [s/m]', ylabel='Height [m]'>

# %% [markdown]
# # Run CANOAK!

# %%
# met.eair

# %%
jax.clear_caches()
# jax.config.update("jax_debug_nans", True)
# jax.config.update("jax_debug_infs", True)
# jax.config.update("jax_disable_jit", True)

canoak_eqx_ift = CanoakGSHybridIFT(para, setup, dij)
# met, prof, ir, qin, sun, shade, soil, veg, can = canoak_eqx_ift(met)
states, drivers = canoak_eqx_ift(met)
_, prof, ir, qin, sun, shade, soil, veg, can = states
quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
# Daily average
plot_daily(met, soil, veg, para);

# %%
# Leaf relative humidity
plot_imshow2(
    sun.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/plot.py:115: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")

# %%
# plot_rad(quantum, setup, lai, "PAR")
# plot_rad(nir, setup, lai, "nir")
# plot_ir(ir, setup, lai)

# %%
# # Profiles
# plot_imshow2(
#     prof.Tair_K.T,
#     met,
#     para.zht,
#     key="T",
#     title="Temperature profile [degk]",
#     cmap="turbo",
# )
# plot_imshow2(
#     prof.eair_Pa.T, met, para.zht, key="e", title="Pressure profile [Pa]", cmap="turbo"
# )
# plot_imshow2(
#     prof.co2.T, met, para.zht, key="co2", title="CO2 profile [ppm]", cmap="turbo"
# )

# %%
# # Temperature
# plot_imshow2(
#     sun.Tsfc.T, met, para.zht1, key="T", title="Sunlit leaf temp [degk]", cmap="turbo"
# )
# plot_imshow2(
#     shade.Tsfc.T, met, para.zht1, key="T", title="Shaded leaf temp [degK]", cmap="turbo"
# )
# plot_imshow2(
#     soil.T_soil[:, :-1].T,
#     met,
#     soil.z_soil,
#     key="T",
#     title="Soil temp [degK]",
#     cmap="turbo",
#     is_canopy=False,
# )

# %%
# # respiration/photosynthesis
# plot_imshow2(
#     sun.Ps.T,
#     met,
#     para.zht1,
#     key="co2",
#     title="Sunlit leaf photosynthesis \n [umol m-2 s-1]",
#     cmap="turbo",
# )
# plot_imshow2(
#     shade.Ps.T,
#     met,
#     para.zht1,
#     key="co2",
#     title="Shaded leaf photosynthesis \n [umol m-2 s-1]",
#     cmap="turbo",
# )
# plot_imshow2(
#     sun.Resp.T,
#     met,
#     para.zht1,
#     key="co2",
#     title="Sunlit leaf respiration \n [umol m-2 s-1]",
#     cmap="turbo",
# )
# plot_imshow2(
#     shade.Resp.T,
#     met,
#     para.zht1,
#     key="co2",
#     title="Shaded leaf respiration \n [umol m-2 s-1]",
#     cmap="turbo",
# )

# %%
# met2 = jax.tree_util.tree_map(lambda x: x.reshape(1,816), met)
# jax.vmap(canoak, in_axes=[None,None,0,None,None,None])(para, setup, met2,
#    dij, setup.soil_mtime, setup.niter)

# %% [markdown]
# # Local sensitivity analysis

# %%
jax.clear_caches()


@eqx.filter_jit
@partial(jax.grad, argnums=0)
def df_canoak_le(para, met, canoak_eqx):
    canoak_eqx = eqx.tree_at(lambda t: t.para, canoak_eqx, para)
    can_le = canoak_eqx.get_fixed_point_states(met, update_canle, get_canle)
    return can_le.sum()


@eqx.filter_jit
def df_canoak_le_batched(para, batched_met, canoak_eqx):
    def compute_grad(para, met):
        grad = df_canoak_le(para, met, canoak_eqx)
        return para, grad

    _, gradients = jax.lax.scan(compute_grad, para, xs=batched_met)
    return gradients


# eqx.filter_make_jaxpr(df_canoak_le3)(para, met, canoak_eqx)

# %% [markdown]
# ## Perform SA at one time step

# %%
start, ntime = 20, 1
met2 = jtu.tree_map(lambda x: x[start : start + ntime], met)

# %%
gradients = df_canoak_le(para, met2, canoak_eqx_ift)

# %%
gradients.lleaf
# Out:
# Array(122.5065275, dtype=float64, weak_type=True)

# %% [markdown]
# ## Perform SA at multiple steps

# %%
jax.clear_caches()
gradients = df_canoak_le_batched(para, batched_met, canoak_eqx_ift)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(timesteps, jnp.abs(gradients.bprime), ".", label="observations")
ax.set(yscale="symlog", ylabel="|dLE/dbprime|")
# ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# ax.set(ylim=[-120, 100], ylabel="Latent heat flux [W M-2]")
# ax.legend()
# Out:
# [None, Text(0, 0.5, '|dLE/dbprime|')]

# %%
plot_para_sensitivity_ranking(gradients, category="photosyn")
# plot_para_sensitivity_ranking(gradients, category=None)

# %% [markdown]
# # Comparison with the observations

# %%
plot_obs_energy_closure(obs)
# Out:
# <Axes: xlabel='Rnet, measured', ylabel='H+LE+Gsoil, measured'>

# %%
plot_obs_1to1(obs.rnet, can.rnet, lim=[-50, 800], varn="Rnet")
# Out:
# <Axes: title={'center': 'Rnet (L2: 1979.236)'}, xlabel='Measured', ylabel='Simulated'>

# %%
plot_timeseries_obs_1to1(
    obs.rnet,
    can.rnet,
    lim=[-100, 1000],
    met=met,
    varn="Net radiation [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can.LE,
    lim=[-100, 800],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
);

# %%
plot_obs_comparison(obs, can);

# %% [markdown]
# # Perform the parameter estimation

# %%
# # Filter the parameters to be estimated
# filter_model_spec = jtu.tree_map(lambda _: False, canoak_eqx_ift)
# filter_model_spec = eqx.tree_at(
#     lambda t: [layer.weight for layer in t.para.LeafRHDL.layers],
#     filter_model_spec,
#     replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
# )
# filter_model_spec = eqx.tree_at(
#     lambda t: [layer.bias for layer in t.para.LeafRHDL.layers],
#     filter_model_spec,
#     replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
# )
# filter_model_spec = eqx.tree_at(
#     lambda t: [layer.weight for layer in t.para.bprimeDL.layers],
#     filter_model_spec,
#     replace=[True for layer in filter_model_spec.para.bprimeDL.layers],
# )
# filter_model_spec = eqx.tree_at(
#     lambda t: [layer.bias for layer in t.para.bprimeDL.layers],
#     filter_model_spec,
#     replace=[True for layer in filter_model_spec.para.bprimeDL.layers],
# )
# filter_model_spec = eqx.tree_at(
#     lambda t: [t.para.bprime, t.para.ep],
#     filter_model_spec,
#     replace=[True, True],
# )

# %%
# Filter the parameters to be estimated
filter_model_spec = jtu.tree_map(lambda _: False, canoak_eqx_ift)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.weight for layer in t.para.gscoefDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.gscoefDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.bias for layer in t.para.gscoefDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.gscoefDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [t.para.ep],
    filter_model_spec,
    replace=[True],
)

# %%
jax.config.update("jax_debug_nans", False)
jax.config.update("jax_debug_infs", False)
jax.config.update("jax_disable_jit", False)

# Define optimizer and observations
args = [update_canle, get_canle]
# nsteps = 500  # number of epoches
nsteps = 100  # number of epoches
batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE
scheduler = optax.piecewise_constant_schedule(
    0.1, boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
)
# scheduler = optax.exponential_decay(0.01, transition_steps=30, decay_rate=0.1)
# optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer

# %%
canoak_eqx_new.para.grasshof
# Out:
# Array(3561756.3229409, dtype=float64, weak_type=True)

# %%
# jax.clear_caches()
jax.config.update("jax_debug_nans", False)
jax.config.update("jax_debug_infs", False)
jax.config.update("jax_disable_jit", False)

canoak_eqx_new, loss_set = perform_optimization_batch(
    canoak_eqx_ift.get_fixed_point_states,
    filter_model_spec.get_fixed_point_states,
    optim,
    batched_y,
    batched_met,
    nsteps,
    # 1,
    para_min,
    para_max,
    *args
)
# canoak_eqx_new = canoak_eqx_new.args[0]
canoak_eqx_new = canoak_eqx_new.__self__
# Out:
# Argument model is triggering a compile.
# Argument filter_model_spec is triggering a compile.
# Argument batched_y is triggering a compile.
# Argument opt_state is triggering a compile.
# Argument batched_met is triggering a compile.
# Compiling make_step ...
# The loss of step 0: 17707.241562249084
# Argument model is triggering a compile.
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb Cell 49 line 6
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=2'>3</a> jax.config.update("jax_debug_infs", False)
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=3'>4</a> jax.config.update("jax_disable_jit", False)
# ----> <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=5'>6</a> canoak_eqx_new, loss_set = perform_optimization_batch(
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=6'>7</a>     canoak_eqx_ift.get_fixed_point_states,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=7'>8</a>     filter_model_spec.get_fixed_point_states,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=8'>9</a>     optim,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=9'>10</a>     batched_y,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=10'>11</a>     batched_met,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=11'>12</a>     nsteps,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=12'>13</a>     # 1,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=13'>14</a>     para_min,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=14'>15</a>     para_max,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=15'>16</a>     *args
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=16'>17</a> )
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=17'>18</a> # canoak_eqx_new = canoak_eqx_new.args[0]
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#X64sZmlsZQ%3D%3D?line=18'>19</a> canoak_eqx_new = canoak_eqx_new.__self__
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/optim/optim.py:150, in perform_optimization_batch(model, filter_model_spec, optim, batched_y, batched_met, nsteps, para_min, para_max, *args)
#     148 check_arg(batched_met, "batched_met")
#     149 # Update the model parameters
# --> 150 model, opt_state, loss, grads = make_step(
#     151     model, filter_model_spec, batched_y, opt_state, batched_met, *args
#     152 )
#     153 loss_set.append(loss)
#     154 print(f"The loss of step {i}: {loss}")
#
#     [... skipping hidden 10 frame]
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1144, in ExecuteReplicated.__call__(self, *args)
#    1141 if (self.ordered_effects or self.has_unordered_effects
#    1142     or self.has_host_callbacks):
#    1143   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1144   results = self.xla_executable.execute_sharded(
#    1145       input_bufs, with_tokens=True
#    1146   )
#    1147   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1148       len(self.ordered_effects))
#    1149   sharded_runtime_token = results.consume_token()
#
# XlaRuntimeError: The linear solver returned non-finite (NaN or inf) output. This usually means that the
# operator was not well-posed, and that the solver does not support this.
#
# If you are trying solve a linear least-squares problem then you should pass
# `solver=AutoLinearSolver(well_posed=False)`. By default `lineax.linear_solve`
# assumes that the operator is square and nonsingular.
#
# If you *were* expecting this solver to work with this operator, then it may be because:
#
# (a) the operator is singular, and your code has a bug; or
#
# (b) the operator was nearly singular (i.e. it had a high condition number:
#     `jnp.linalg.cond(operator.as_matrix())` is large), and the solver suffered from
#     numerical instability issues; or
#
# (c) the operator is declared to exhibit a certain property (e.g. positive definiteness)
#     that is does not actually satisfy.
# -------
# This error occurred during the runtime of your JAX program. Setting the environment
# variable `EQX_ON_ERROR=breakpoint` is usually the most useful way to debug such errors.
# (This can be navigated using most of the usual commands for the Python debugger:
# `u` and `d` to move through stack frames, the name of a variable to print its value,
# etc.) See also `https://docs.kidger.site/equinox/api/errors/#equinox.error_if` for more
# information.

# %%
canoak_eqx_new.para.gscoefDL.layers[0].weight
# Out:
# Array([[nan, nan, nan],
#        [nan, nan, nan],
#        [nan, nan, nan],
#        [nan, nan, nan],
#        [nan, nan, nan],
#        [nan, nan, nan]], dtype=float64)

# %%
# # jax.clear_caches()
# # Let's find out where the nan occurs
# # jax.config.update("jax_debug_nans", False)

# # Perform the optimization again
# perform_optimization_batch(
#     canoak_eqx_new.get_fixed_point_states,
#     filter_model_spec.get_fixed_point_states,
#     optim,
#     batched_y,
#     batched_met,
#     1,
#     para_min,
#     para_max,
#     *args,
# )
# Out:
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb Cell 49 line 6
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=0'>1</a> # jax.clear_caches()
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=1'>2</a> # Let's find out where the nan occurs
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=2'>3</a> # jax.config.update("jax_debug_nans", False)
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=4'>5</a> # Perform the optimization again
# ----> <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=5'>6</a> perform_optimization_batch(
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=6'>7</a>     canoak_eqx_new.get_fixed_point_states,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=7'>8</a>     filter_model_spec.get_fixed_point_states,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=8'>9</a>     optim,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=9'>10</a>     batched_y,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=10'>11</a>     batched_met,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=11'>12</a>     1,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=12'>13</a>     para_min,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=13'>14</a>     para_max,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=14'>15</a>     *args,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y134sZmlsZQ%3D%3D?line=15'>16</a> )
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/optim/optim.py:146, in perform_optimization_batch(model, filter_model_spec, optim, batched_y, batched_met, nsteps, para_min, para_max, *args)
#     144 check_arg(batched_met, "batched_met")
#     145 # Update the model parameters
# --> 146 model, opt_state, loss, grads = make_step(
#     147     model, filter_model_spec, batched_y, opt_state, batched_met, *args
#     148 )
#     149 loss_set.append(loss)
#     150 print(f"The loss of step {i}: {loss}")
#
#     [... skipping hidden 10 frame]
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1144, in ExecuteReplicated.__call__(self, *args)
#    1141 if (self.ordered_effects or self.has_unordered_effects
#    1142     or self.has_host_callbacks):
#    1143   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1144   results = self.xla_executable.execute_sharded(
#    1145       input_bufs, with_tokens=True
#    1146   )
#    1147   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1148       len(self.ordered_effects))
#    1149   sharded_runtime_token = results.consume_token()
#
# XlaRuntimeError: The linear solver returned non-finite (NaN or inf) output. This usually means that the
# operator was not well-posed, and that the solver does not support this.
#
# If you are trying solve a linear least-squares problem then you should pass
# `solver=AutoLinearSolver(well_posed=False)`. By default `lineax.linear_solve`
# assumes that the operator is square and nonsingular.
#
# If you *were* expecting this solver to work with this operator, then it may be because:
#
# (a) the operator is singular, and your code has a bug; or
#
# (b) the operator was nearly singular (i.e. it had a high condition number:
#     `jnp.linalg.cond(operator.as_matrix())` is large), and the solver suffered from
#     numerical instability issues; or
#
# (c) the operator is declared to exhibit a certain property (e.g. positive definiteness)
#     that is does not actually satisfy.
# -------
# This error occurred during the runtime of your JAX program. Setting the environment
# variable `EQX_ON_ERROR=breakpoint` is usually the most useful way to debug such errors.
# (This can be navigated using most of the usual commands for the Python debugger:
# `u` and `d` to move through stack frames, the name of a variable to print its value,
# etc.) See also `https://docs.kidger.site/equinox/api/errors/#equinox.error_if` for more
# information.

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.plot(loss_set)
ax.set(xlabel="Epochs", ylabel="L2", title="Loss function", yscale="linear");

# %%
# visualize_tree_diff(canoak_eqx_ift.para, canoak_eqx_new.para)

# %%
# # canoak_eqx - canoak_eqx_new
# # filter_model_spec
# canoak_eqx_new.para.bprime, canoak_eqx_ift.para.bprime

# %% [markdown]
# ## Rerun the model using the estimated parameters

# %% [markdown]
# ### Calibration period

# %%
canoak_eqx_new.para.ep, canoak_eqx_ift.para.ep
# Out:
# (Array(nan, dtype=float64), Array(0.98, dtype=float64, weak_type=True))

# %%
# jax.config.update("jax_debug_nans", False)
# jax.config.update("jax_debug_infs", False)
# jax.config.update("jax_disable_jit", False)

states, drivers = canoak_eqx_new(met)
(
    met_new,
    prof_new,
    ir_new,
    qin_new,
    sun_new,
    shade_new,
    soil_new,
    veg_new,
    can_new,
) = states
# quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb Cell 55 line 5
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=1'>2</a> jax.config.update("jax_debug_infs", True)
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=2'>3</a> jax.config.update("jax_disable_jit", True)
# ----> <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=4'>5</a> states, drivers = canoak_eqx_new(met)
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=5'>6</a> (
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=6'>7</a>     met_new,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=7'>8</a>     prof_new,
#    (...)
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=14'>15</a>     can_new,
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=15'>16</a> ) = states
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=16'>17</a> # quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/canoak_ift_US-Bi1_hybridGS.ipynb#Y103sZmlsZQ%3D%3D?line=17'>18</a> # met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/models/canoak_eqx.py:471, in CanoakGSHybridIFT.__call__(self, met, update_substates_func, get_substates_func)
#     468 ntime = met.zL.size
#     470 # Initialization
# --> 471 quantum, nir, rnet, lai, sun_ang, leaf_ang, initials = canoak_initialize_states(
#     472     para,
#     473     met,
#     474     lat_deg,
#     475     long_deg,
#     476     time_zone,
#     477     leafangle,
#     478     n_can_layers,
#     479     n_total_layers,
#     480     n_soil_layers,
#     481     ntime,
#     482     dt_soil,
#     483     soil_mtime,
#     484 )
#     485 states_guess = initials
#     487 # Forward runs
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/equinox/_jit.py:162, in _JitWrapper.__call__(self, *args, **kwargs)
#     160 def __call__(self, /, *args, **kwargs):
#     161     try:
# --> 162         return self._call(False, args, kwargs)
#     163     except XlaRuntimeError as e:
#     164         # Catch Equinox's runtime errors, and strip the more intimidating parts of
#     165         # the error message.
#     166         if len(e.args) != 1 or not isinstance(e.args[0], str):
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/equinox/_module.py:854, in BoundMethod.__call__(self, *args, **kwargs)
#     853 def __call__(self, *args, **kwargs):
# --> 854     return self.__func__(self.__self__, *args, **kwargs)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/equinox/_jit.py:157, in _JitWrapper._call(self, is_lower, args, kwargs)
#     155         out = self._cached(dynamic, static)
#     156 else:
# --> 157     out = self._cached(dynamic, static)
#     158 return _postprocess(out)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/equinox/_jit.py:41, in _filter_jit_cache.<locals>.fun_wrapped(dynamic, static)
#      39 fun = hashable_combine(dynamic_fun, static_fun)
#      40 args, kwargs = hashable_combine(dynamic_spec, static_spec)
# ---> 41 out = fun(*args, **kwargs)
#      42 dynamic_out, static_out = partition(out, is_array)
#      43 return dynamic_out, Static(static_out)
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/models/canoak.py:84, in canoak_initialize_states(para, met, lat_deg, long_deg, time_zone, leafangle, n_can_layers, n_total_layers, n_soil_layers, time_batch_size, dt_soil, soil_mtime)
#      67 prof = initialize_profile(met, para, ntime, jtot, jtot_total)
#      69 # ---------------------------------------------------------------------------- #
#      70 #                     Initialize model states                        #
#      71 # ---------------------------------------------------------------------------- #
#      72 (
#      73     soil,
#      74     quantum,
#      75     nir,
#      76     ir,
#      77     qin,
#      78     rnet,
#      79     sun,
#      80     shade,
#      81     veg,
#      82     lai,
#      83     can,
# ---> 84 ) = initialize_model_states(  # noqa: E501
#      85     met, para, ntime, jtot, dt_soil, soil_mtime, n_soil_layers
#      86 )
#      88 # ---------------------------------------------------------------------------- #
#      89 #                     Compute sun angles                                       #
#      90 # ---------------------------------------------------------------------------- #
#      91 sun_ang = angle(lat_deg, long_deg, time_zone, met.day, met.hhour)
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/subjects/initialization_update.py:654, in initialize_model_states(met, para, ntime, jtot, dt_soil, soil_mtime, n_soil_layers)
#     652 depth = para.soil_depth
#     653 # Soil
# --> 654 soil = initialize_soil(para, met, ntime, dt_soil, soil_mtime, n_soil_layers, depth)
#     656 # Quantum and NIR
#     657 # quantum = initialize_parnir(para, setup, "par")
#     658 # nir = initialize_parnir(para, setup, "nir")
#     659 quantum = initialize_parnir(para, ntime, jtot, 0)
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/subjects/initialization_update.py:992, in initialize_soil(para, met, ntime, dt_soil, soil_mtime, n_soil_layers, depth)
#     990 gsoil = jnp.zeros(ntime)
#     991 resp = jnp.zeros(ntime)
# --> 992 lout = para.epsigma * jnp.power(met.T_air_K, 4)  # initialization
#     993 llout = lout
#     995 # lower boundary
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/subjects/parameters.py:532, in Para.epsigma(self)
#     530 @property
#     531 def epsigma(self):
# --> 532     return self.ep * self.sigma
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:256, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     254 args = (other, self) if swap else (self, other)
#     255 if isinstance(other, _accepted_binop_types):
# --> 256   return binary_op(*args)
#     257 # Note: don't use isinstance here, because we don't want to raise for
#     258 # subclasses, e.g. NamedTuple objects that may override operators.
#     259 if type(other) in _rejected_binop_types:
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/numpy/ufuncs.py:97, in _maybe_bool_binop.<locals>.fn(x1, x2)
#      95 def fn(x1, x2, /):
#      96   x1, x2 = promote_args(numpy_fn.__name__, x1, x2)
# ---> 97   return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/lax/lax.py:424, in mul(x, y)
#     422 def mul(x: ArrayLike, y: ArrayLike) -> Array:
#     423   r"""Elementwise multiplication: :math:`x \times y`."""
# --> 424   return mul_p.bind(x, y)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/core.py:386, in Primitive.bind(self, *args, **params)
#     383 def bind(self, *args, **params):
#     384   assert (not config.jax_enable_checks or
#     385           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 386   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/core.py:389, in Primitive.bind_with_trace(self, trace, args, params)
#     388 def bind_with_trace(self, trace, args, params):
# --> 389   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/core.py:869, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     868 def process_primitive(self, primitive, tracers, params):
# --> 869   return primitive.impl(*tracers, **params)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/dispatch.py:140, in apply_primitive(prim, *args, **params)
#     136   msg = pjit._device_assignment_mismatch_error(
#     137       prim.name, fails, args, 'jit', arg_names)
#     138   raise ValueError(msg) from None
# --> 140 return compiled_fun(*args)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/dispatch.py:172, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     170   call = compiled.unsafe_call
#     171 if not prim.multiple_results:
# --> 172   return lambda *args, **kw: call(*args, **kw)[0]
#     173 else:
#     174   return call
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1156, in ExecuteReplicated.__call__(self, *args)
#    1154   out_arrays = results.disassemble_into_single_device_arrays()
#    1155   for arrays in out_arrays:
# -> 1156     dispatch.check_special(self.name, arrays)
#    1157   return self.out_handler(out_arrays)
#    1158 return results.consume_with_handlers(self.out_handler.handlers)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/dispatch.py:403, in check_special(name, bufs)
#     401 if needs_check_special():
#     402   for buf in bufs:
# --> 403     _check_special(name, buf.dtype, buf)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/jax/_src/dispatch.py:408, in _check_special(name, dtype, buf)
#     406 if dtypes.issubdtype(dtype, np.inexact):
#     407   if config.jax_debug_nans and np.any(np.isnan(np.asarray(buf))):
# --> 408     raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     409   if config.jax_debug_infs and np.any(np.isinf(np.asarray(buf))):
#     410     raise FloatingPointError(f"invalid value (inf) encountered in {name}")
#
# FloatingPointError: invalid value (nan) encountered in jit(mul)

# %%
plot_obs_comparison(obs, can_new);

# %%
# Daily average
plot_daily(met, soil_new, veg_new, para);

# %%
timesteps = get_time(met)

fig, ax1, ax2 = plot_timeseries_obs_1to1(
    obs.LE,
    can_new.LE,
    lim=[-150, 350],
    met=met,
    varn="Latent heat fluxes [W m-2]",
    # linestyle=".",
)
ax1.set(ylabel="[W m-2]")
ax12 = ax1.twinx()
ax12.invert_yaxis()
ax12.plot(timesteps, obs.P, "k")
ax12.set(ylim=[10, 0], ylabel="Rainfall [mm]")
# Out:
# [(10.0, 0.0), Text(0, 0.5, 'Rainfall [mm]')]

# %%
# Leaf relative humidity
plot_imshow2(
    sun_new.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/plot.py:115: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
# start, end = 2000, 2100
# start, end = 4000, 4100
start, end = 2700, 2800
ax.plot(timesteps[start:end], obs.LE[start:end], ".", label="observations")
ax.plot(timesteps[start:end], can_new.LE[start:end], ".", label="simulation")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
ax.set(ylim=[-120, 100], ylabel="Latent heat flux [W M-2]")
ax.legend()
# Out:
# /var/folders/b7/q6wyxw8x1_s5rh1mqvfb8vsr0000gn/T/ipykernel_7052/4059250782.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can_new.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
    linestyle=".",
);

# %% [markdown]
# ### Test period

# %%
# Read the observations
met_test, n_time_test = get_met_forcings(f_forcing_test)
timesteps_test = get_time(met_test)

# Read the observations
obs_test = get_obs(f_obs_test)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/subjects/initialization_update.py:262: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %%
states_test, drivers_test = canoak_eqx_new(met_test)
(
    _,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test

# %%
plot_obs_comparison(obs_test, can_test);

# %%
fig, ax1, ax2 = plot_timeseries_obs_1to1(
    obs_test.LE,
    can_test.LE,
    lim=[-150, 350],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
    # linestyle=".",
)
ax1.set(ylabel="[W m-2]")
ax12 = ax1.twinx()
ax12.invert_yaxis()
ax12.plot(timesteps_test, obs_test.P, "k")
ax12.set(ylim=[10, 0], ylabel="Rainfall [mm]")
# Out:
# [(10.0, 0.0), Text(0, 0.5, 'Rainfall [mm]')]

# %% [markdown]
# # Backup

# %%
# fig, ax = plt.subplots(1, 1, figsize=(10, 3))
# # ax.plot(can_new.LE)
# ax.plot(obs.LE)
# ax2 = ax.twinx()
# # ax2.plot(lai.lai, 'black')
# # ax2.plot(qin_new.sun_abs.sum(axis=1), 'black', alpha=0.5)
# ax2.plot(met.soilmoisture, "black", alpha=0.5)

# %%
# plot_le_gs_lai(can_new.LE, obs.LE, veg_new.gs, lai.lai, met=met)
# # plot_le_gs_lai(can_new.LE / lai.lai, obs.LE / lai.lai, veg_new.gs, lai.lai, met=met)
# # plot_le_gs_lai(shade_new.LE.mean(axis=1), obs.LE, veg_new.gs, lai.lai, met=met)
# # plot_le_gs_lai(soil.evap, obs.LE, veg_new.gs, lai.lai, met=met)

# %%
# # Try again with another set of parameters
# canoak_eqx_new2 = eqx.tree_at(lambda t: t.para.bprime, canoak_eqx_new, 0.005)
# (
#     _,
#     prof_new,
#     can_new,
#     veg_new,
#     shade_new,
#     sun_new,
#     qin_new,
#     rnet_new,
#     sun_ang_new,
#     ir_new,
#     nir_new,
#     quantum_new,
#     lai_new,
#     leaf_ang_new,
#     soil_new,
# ) = run_canoak_in_batch(batched_met, canoak_eqx_new2)
# plot_obs_comparison(obs, can_new);

# %%
# plot_timeseries_obs_1to1(
#     obs.LE,
#     can_new.LE,
#     lim=[-100, 500],
#     met=met,
#     varn="Latent heat fluxes [W m-2]",
# );

# %%
# plot_le_gs_lai(can_new.LE, obs.LE, veg_new.gs, lai.lai, met=met)
