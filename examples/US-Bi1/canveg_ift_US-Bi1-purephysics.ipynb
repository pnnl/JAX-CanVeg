# %% [markdown]
# This notebook is used to train the process-based JAX-CanVeg in US-Bi1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# # TODO: A more generic way is needed here to load the path
# import sys

# sys.path.append(
#     "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
#     # "/global/homes/p/peishi89/jax-watershed/src"
# )

# %%
import optax
import equinox as eqx

import pickle
from functools import partial

from math import floor

# import numpy as np
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import pandas as pd

from jax_canveg.physics.energy_fluxes import get_dispersion_matrix

from jax_canveg.models import CanvegIFT
from jax_canveg.models import get_canle, update_canle
from jax_canveg.models import get_soilresp, update_soilresp
from jax_canveg.models import load_model, save_model

# from jax_canveg.models import run_canveg_in_batch

# from jax_canveg.shared_utilities.optim import perform_optimization
from jax_canveg.shared_utilities.optim import perform_optimization_batch, mse
from jax_canveg.shared_utilities import compute_metrics
from jax_canveg.subjects import convert_met_to_batched_met
from jax_canveg.subjects import (
    # convert_batchedstates_to_states,
    convert_obs_to_batched_obs,
)
from jax_canveg.subjects import get_met_forcings, get_obs, initialize_parameters


import matplotlib.pyplot as plt
from jax_canveg.shared_utilities.plot import (
    plot_daily,
    plot_imshow2,
    plot_timeseries_obs_1to1,
    plot_rad,
    plot_ir,
    visualize_tree_diff,
)
from jax_canveg.shared_utilities.plot import (
    plot_obs_1to1,
    plot_obs_comparison,
    plot_obs_energy_closure,
    plot_dij,
    plot_para_sensitivity_ranking,
    plot_le_gs_lai,
    get_time,
)

# from jax_canveg.shared_utilities.plot import plot_veg_temp, plot_dij
# from jax_canveg.shared_utilities.plot import plot_ir, plot_rad, plot_prof2
from jax_canveg.shared_utilities import tune_jax_naninfs_for_debug

jax.config.update("jax_enable_x64", True)
tune_jax_naninfs_for_debug(False)
# jax.config.update("jax_debug_nans", False)
# jax.config.update("jax_debug_infs", False)
# jax.config.update("XLA_PYTHON_CLIENT_ALLOCATOR", 'platform')

# %load_ext autoreload
# %autoreload 2

# %%
# import os
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="FALSE"

# %% [markdown]
# # Model parameters and settings

# %%
time_zone = -8
latitude = 38.0991538
longitude = -121.49933
stomata = 1
veg_ht = 0.8
leafangle = 1
n_can_layers = 50
n_atmos_layers = 50
meas_ht = 5.0
soil_depth = 0.15
n_hr_per_day = 48
niter = 15
# niter = 1

# batch_size = 2
# batch_size = 1274
# batch_size = int(74496/2)
batch_size, batch_size_test = int(74496 / 2), None

site = "US-Bi1"
key = "purephysics"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-test.csv"

# Models
f_model = f"{site}_{key}_model.eqx"
# f_model_new = f"{site}_{key}_model.eqx"

# %% [markdown]
# # Load and set the model forcings

# %%
# Training
met, n_time = get_met_forcings(f_forcing)
if batch_size is None:
    batch_size = n_time
n_batch = floor(n_time / batch_size)
batched_met = convert_met_to_batched_met(met, n_batch, batch_size)
timesteps = get_time(met)

# %%
# Test
met_test, n_time_test = get_met_forcings(f_forcing_test)
if batch_size_test is None:
    batch_size_test = n_time_test
n_batch_test = floor(n_time_test / batch_size_test)
batched_met_test = convert_met_to_batched_met(met_test, n_batch_test, batch_size_test)
timesteps_test = get_time(met_test)

# %%
plt.plot(met.soilmoisture)

# %% [markdown]
# # Load the observations

# %%
# Training
obs = get_obs(f_obs)

# Test
obs_test = get_obs(f_obs_test)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canveg/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canveg/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Create the model parameter instance

# %%
setup, para, para_min, para_max = initialize_parameters(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    obs=obs,
    met=met,
    niter=niter,
    get_para_bounds=True,
)

# %% [markdown]
# # Generate or read the dispersion matrix

# %%
# dij = get_dispersion_matrix(setup, para)
dij = get_dispersion_matrix(setup, para, f"../../data/dij/Dij_{site}.csv")
# import numpy as np
# np.savetxt(f"../../data/dij/Dij_{site}.csv", np.array(dij), delimiter=',')

# %%
plot_dij(dij, para)
# Out:
# <Axes: xlabel='Dij [s/m]', ylabel='Height [m]'>

# %% [markdown]
# # Run CanVeg!

# %%
jax.clear_caches()
canveg_eqx_ift = CanvegIFT(para, setup, dij)

# %%
# Training data
# met, prof, ir, qin, sun, shade, soil, veg, can = canveg_eqx_ift(met)
states, drivers = canveg_eqx_ift(met)
met, prof, ir, qin, sun, shade, soil, veg, can = states
quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canveg_in_batch(batched_met, canveg_eqx_ift)

# %%
# Test data
states_test, drivers_test = canveg_eqx_ift(met_test)
(
    met_test,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test
quantum_test, nir_test, rnet_test, sun_ang_test, leaf_ang_test, lai_test = drivers_test

# %%
# Leaf relative humidity
plot_imshow2(
    sun.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)

plot_imshow2(
    sun_test.Leaf_RH.T,
    met_test,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canveg/shared_utilities/plot.py:131: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canveg/shared_utilities/plot.py:131: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
# ([<Axes: title={'center': 'Air temperature [degK]'}>,
#   <Axes: title={'center': 'Leaf relative humidity [-]'}, ylabel='Aboveground height [m]'>,
#   <Axes: title={'center': 'Averaged'}, xlabel='Leaf relative humidity [-]'>,
#   <Axes: >],
#  <matplotlib.image.AxesImage at 0x34b0157e0>)

# %%
# Daily average
plot_daily(met, soil, veg, para)
plot_daily(met_test, soil_test, veg_test, para);

# %%
# Analyze nan
nanind = jnp.where(jnp.isnan(prof.Tair_K.mean(axis=1)))

met.lai[nanind]
# qin.sun_abs[nanind]
# ir.ir_in[nanind]
sun.Tsfc[nanind, :]
# Out:
# Array([], dtype=float64)

# %% [markdown]
# # Local sensitivity analysis

# %%
jax.clear_caches()


@eqx.filter_jit
@partial(jax.grad, argnums=0)
def df_canveg_le(para, met, canveg_eqx):
    canveg_eqx = eqx.tree_at(lambda t: t.para, canveg_eqx, para)
    can_le = canveg_eqx.get_fixed_point_states(met, update_canle, get_canle)
    # met, update_soilresp, get_soilresp)
    return can_le.sum()


@eqx.filter_jit
def df_canveg_le_batched(para, batched_met, canveg_eqx):
    def compute_grad(para, met):
        grad = df_canveg_le(para, met, canveg_eqx)
        return para, grad

    _, gradients = jax.lax.scan(compute_grad, para, xs=batched_met)
    return gradients


# eqx.filter_make_jaxpr(df_canveg_le3)(para, met, canveg_eqx)

# %% [markdown]
# ## Perform SA at one time step

# %%
start, ntime = 20, 1
met2 = jtu.tree_map(lambda x: x[start : start + ntime], met)

# %%
gradients = df_canveg_le(para, met2, canveg_eqx_ift)

# %%
gradients.lleaf
# Out:
# Array(222.8998183, dtype=float64, weak_type=True)

# %% [markdown]
# ## Perform SA at multiple steps

# %%
jax.clear_caches()
batched_met_sa = convert_met_to_batched_met(met, n_time, 1)
gradients = df_canveg_le_batched(para, batched_met_sa, canveg_eqx_ift)

# %%
plot_para_sensitivity_ranking(gradients, category="photosyn")
# plot_para_sensitivity_ranking(gradients, category=None)
# Out:
# <Axes: xlabel='E[|Gradient|] / Nt', ylabel='Parameters'>

# %%
# gm = jtu.tree_map(lambda x:x.mean(), gradients)
# a, b = jtu.tree_flatten(gm)

# %%
# bb = b.node_data()[1]
# names = bb.dynamic_field_names

# %% [markdown]
# # Comparison with the observations

# %%
plot_obs_energy_closure(obs)
# Out:
# <Axes: xlabel='Rnet, measured', ylabel='H+LE+Gsoil, measured'>

# %%
plot_obs_1to1(obs.rnet, can.rnet, lim=[-50, 800], varn="Rnet")
# Out:
# <Axes: title={'center': 'Rnet (MSE: 1263.399)'}, xlabel='Observation', ylabel='JAX-CANOAK'>

# %%
plot_timeseries_obs_1to1(
    obs.rnet,
    can.rnet,
    lim=[-100, 800],
    met=met,
    varn="Net radiation [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
);

# %%
plot_obs_comparison(obs, can);

# %% [markdown]
# # Perform parameter estimation

# %%
# Filter the parameters to be estimated
filter_model_spec = jtu.tree_map(lambda _: False, canveg_eqx_ift)
filter_model_spec = eqx.tree_at(
    lambda t: (
        t.para.bprime,
        # t.para.ep,
        t.para.lleaf,
        t.para.qalpha,
        t.para.kball,
        # t.para.leaf_clumping_factor,
    ),
    filter_model_spec,
    replace=(True, True, True, True),
)

# %%
# Define optimizer and observations
args = [update_canle, get_canle]
# nsteps = 5  # number of epoches
nsteps = 300  # number of epoches
# nsteps = 100  # number of epoches
batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE
scheduler = optax.piecewise_constant_schedule(
    0.01,
    boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
    # 0.01, boundaries_and_scales={50: 0.1, 100: 0.1, 200: 0.1}
)
# scheduler = optax.exponential_decay(0.01, transition_steps=30, decay_rate=0.1)
# optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
# optim = optax.adam(learning_rate=0.01)  # Adam optimizer

batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE

batched_obs_test = convert_obs_to_batched_obs(obs_test, n_batch_test, batch_size_test)
batched_y_test = batched_obs_test.LE

# %%
# jax.clear_caches()
args = [update_canle, get_canle]
canveg_eqx_new, loss_train_set, loss_test_set = perform_optimization_batch(
    canveg_eqx_ift.get_fixed_point_states,
    filter_model_spec.get_fixed_point_states,
    optim,
    nsteps,
    mse,
    batched_y,
    batched_met,
    batched_y_test,
    batched_met_test,
    para_min,
    para_max,
    *args,
)
# canveg_eqx_new = canveg_eqx_new.args[0]
canveg_eqx_new = canveg_eqx_new.__self__
# Out:
# Argument model is triggering a compile.
# Argument filter_model_spec is triggering a compile.
# Argument batched_y is triggering a compile.
# Argument opt_state is triggering a compile.
# Argument batched_met is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 0: 1655.1999581264167; the test loss of step 0: 2120.314681660878.
# Argument model is triggering a compile.
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 1: 1627.808121209337; the test loss of step 1: 2034.4709213137044.
# Compiling calculate_test_loss ...
# The training loss of step 2: 1584.8380760539337; the test loss of step 2: 1900.0692588861168.
# Compiling calculate_test_loss ...
# The training loss of step 3: 1551.996609708308; the test loss of step 3: 1828.1929589584793.
# Compiling calculate_test_loss ...
# The training loss of step 4: 1545.5931538718128; the test loss of step 4: 1816.2278673911255.
# Compiling calculate_test_loss ...
# The training loss of step 5: 1532.6375292095736; the test loss of step 5: 1843.4768450834356.
# Compiling calculate_test_loss ...
# The training loss of step 6: 1518.5496952557141; the test loss of step 6: 1887.026606330891.
# Compiling calculate_test_loss ...
# The training loss of step 7: 1520.5994775171755; the test loss of step 7: 1911.2154134796974.
# Compiling calculate_test_loss ...
# The training loss of step 8: 1529.8013044673758; the test loss of step 8: 1894.1860574126258.
# Compiling calculate_test_loss ...
# The training loss of step 9: 1530.1505131251179; the test loss of step 9: 1849.13907669022.
# Compiling calculate_test_loss ...
# The training loss of step 10: 1525.7143887634957; the test loss of step 10: 1805.3914477345186.
# Compiling calculate_test_loss ...
# The training loss of step 11: 1526.3043261016137; the test loss of step 11: 1779.6948476561374.
# Compiling calculate_test_loss ...
# The training loss of step 12: 1532.112911494369; the test loss of step 12: 1774.4292874613475.
# Compiling calculate_test_loss ...
# The training loss of step 13: 1534.9927730248778; the test loss of step 13: 1785.8810457962506.
# Compiling calculate_test_loss ...
# The training loss of step 14: 1534.8279934681389; the test loss of step 14: 1803.2180448995512.
# Compiling calculate_test_loss ...
# The training loss of step 15: 1534.7356116107173; the test loss of step 15: 1822.5440035303086.
# Compiling calculate_test_loss ...
# The training loss of step 16: 1535.3344292590614; the test loss of step 16: 1836.5170883589933.
# Compiling calculate_test_loss ...
# The training loss of step 17: 1535.4367897459454; the test loss of step 17: 1839.7791487451686.
# Compiling calculate_test_loss ...
# The training loss of step 18: 1533.1735892700476; the test loss of step 18: 1832.1737366696238.
# Compiling calculate_test_loss ...
# The training loss of step 19: 1529.015624076646; the test loss of step 19: 1820.3183862262447.
# Compiling calculate_test_loss ...
# The training loss of step 20: 1524.949150258854; the test loss of step 20: 1812.2271558931325.
# Compiling calculate_test_loss ...
# The training loss of step 21: 1521.5386666648365; the test loss of step 21: 1792.8900353082038.
# Compiling calculate_test_loss ...
# The training loss of step 22: 1521.9901370400185; the test loss of step 22: 1794.7838447374052.
# Compiling calculate_test_loss ...
# The training loss of step 23: 1520.477314147789; the test loss of step 23: 1814.0909083492927.
# Compiling calculate_test_loss ...
# The training loss of step 24: 1517.8022517216455; the test loss of step 24: 1881.3540954156372.
# Compiling calculate_test_loss ...
# The training loss of step 25: 1522.5649585712563; the test loss of step 25: 1923.7099503442898.
# Compiling calculate_test_loss ...
# The training loss of step 26: 1530.492981833631; the test loss of step 26: 1915.1861527077904.
# Compiling calculate_test_loss ...
# The training loss of step 27: 1527.023744125486; the test loss of step 27: 1878.1670996476532.
# Compiling calculate_test_loss ...
# The training loss of step 28: 1519.250093016732; the test loss of step 28: 1838.504543163175.
# Compiling calculate_test_loss ...
# The training loss of step 29: 1515.848585357559; the test loss of step 29: 1812.2403969749498.
# Compiling calculate_test_loss ...
# The training loss of step 30: 1518.0729082395435; the test loss of step 30: 1807.0346376394536.
# Compiling calculate_test_loss ...
# The training loss of step 31: 1518.9222284487587; the test loss of step 31: 1820.081965111009.
# Compiling calculate_test_loss ...
# The training loss of step 32: 1516.6408748794847; the test loss of step 32: 1847.9187239316573.
# Compiling calculate_test_loss ...
# The training loss of step 33: 1515.8741081468838; the test loss of step 33: 1876.6485322435124.
# Compiling calculate_test_loss ...
# The training loss of step 34: 1518.6284823312767; the test loss of step 34: 1889.3139527016674.
# Compiling calculate_test_loss ...
# The training loss of step 35: 1521.0397524738444; the test loss of step 35: 1878.751575992809.
# Compiling calculate_test_loss ...
# The training loss of step 36: 1519.8660262206317; the test loss of step 36: 1852.6252335341087.
# Compiling calculate_test_loss ...
# The training loss of step 37: 1517.1946952933306; the test loss of step 37: 1826.813387807221.
# Compiling calculate_test_loss ...
# The training loss of step 38: 1516.663197698737; the test loss of step 38: 1812.0131305912219.
# Compiling calculate_test_loss ...
# The training loss of step 39: 1517.2862429979446; the test loss of step 39: 1809.894428720512.
# Compiling calculate_test_loss ...
# The training loss of step 40: 1517.6235061778402; the test loss of step 40: 1819.550124274163.
# Compiling calculate_test_loss ...
# The training loss of step 41: 1517.6825292798014; the test loss of step 41: 1836.2802038316458.
# Compiling calculate_test_loss ...
# The training loss of step 42: 1518.9761964199379; the test loss of step 42: 1850.55264287278.
# Compiling calculate_test_loss ...
# The training loss of step 43: 1521.5117561403808; the test loss of step 43: 1852.6322295103487.
# Compiling calculate_test_loss ...
# The training loss of step 44: 1522.144009727645; the test loss of step 44: 1842.4699048838336.
# Compiling calculate_test_loss ...
# The training loss of step 45: 1520.7545027510755; the test loss of step 45: 1830.1406475398985.
# Compiling calculate_test_loss ...
# The training loss of step 46: 1519.5318879408908; the test loss of step 46: 1812.53671023922.
# Compiling calculate_test_loss ...
# The training loss of step 47: 1519.1590580056586; the test loss of step 47: 1805.450016582916.
# Compiling calculate_test_loss ...
# The training loss of step 48: 1519.1949615526446; the test loss of step 48: 1810.842264426433.
# Compiling calculate_test_loss ...
# The training loss of step 49: 1518.6919789120586; the test loss of step 49: 1830.2959744043778.
# Compiling calculate_test_loss ...
# The training loss of step 50: 1518.811201316465; the test loss of step 50: 1840.6172355396204.
# Compiling calculate_test_loss ...
# The training loss of step 51: 1519.050009321366; the test loss of step 51: 1848.193367302472.
# Compiling calculate_test_loss ...
# The training loss of step 52: 1519.6900892818326; the test loss of step 52: 1848.0496317001073.
# Compiling calculate_test_loss ...
# The training loss of step 53: 1519.7071653759622; the test loss of step 53: 1844.2138573380628.
# Compiling calculate_test_loss ...
# The training loss of step 54: 1518.679230996846; the test loss of step 54: 1836.928255561901.
# Compiling calculate_test_loss ...
# The training loss of step 55: 1517.6604805307522; the test loss of step 55: 1829.4707318456515.
# Compiling calculate_test_loss ...
# The training loss of step 56: 1517.2568826463657; the test loss of step 56: 1823.8906926184056.
# Compiling calculate_test_loss ...
# The training loss of step 57: 1516.5077962846758; the test loss of step 57: 1821.4741245293853.
# Compiling calculate_test_loss ...
# The training loss of step 58: 1516.586337059626; the test loss of step 58: 1822.6913895964556.
# Compiling calculate_test_loss ...
# The training loss of step 59: 1516.4423323207725; the test loss of step 59: 1827.311251900181.
# Compiling calculate_test_loss ...
# The training loss of step 60: 1516.301643430857; the test loss of step 60: 1834.0763512030671.
# Compiling calculate_test_loss ...
# The training loss of step 61: 1516.4575278947873; the test loss of step 61: 1775.9613373101042.
# Compiling calculate_test_loss ...
# The training loss of step 62: 1522.9575913400706; the test loss of step 62: 1744.6332240979705.
# Compiling calculate_test_loss ...
# The training loss of step 63: 1538.7275633894976; the test loss of step 63: 1728.9961028376306.
# Compiling calculate_test_loss ...
# The training loss of step 64: 1552.0278535590737; the test loss of step 64: 1725.8116736476247.
# Compiling calculate_test_loss ...
# The training loss of step 65: 1554.326679883845; the test loss of step 65: 1732.9873193991132.
# Compiling calculate_test_loss ...
# The training loss of step 66: 1547.319869664867; the test loss of step 66: 1750.242527388256.
# Compiling calculate_test_loss ...
# The training loss of step 67: 1537.5137430822633; the test loss of step 67: 1778.7495440490106.
# Compiling calculate_test_loss ...
# The training loss of step 68: 1531.1424208198687; the test loss of step 68: 1815.3551362266319.
# Compiling calculate_test_loss ...
# The training loss of step 69: 1531.7655456515572; the test loss of step 69: 1855.028800884242.
# Compiling calculate_test_loss ...
# The training loss of step 70: 1540.0697968582094; the test loss of step 70: 1886.0536563676658.
# Compiling calculate_test_loss ...
# The training loss of step 71: 1549.421009072679; the test loss of step 71: 1901.0900407398915.
# Compiling calculate_test_loss ...
# The training loss of step 72: 1553.5517528614575; the test loss of step 72: 1896.5272560996664.
# Compiling calculate_test_loss ...
# The training loss of step 73: 1549.4154546259506; the test loss of step 73: 1876.2149957989818.
# Compiling calculate_test_loss ...
# The training loss of step 74: 1540.6446758554125; the test loss of step 74: 1848.5611869558527.
# Compiling calculate_test_loss ...
# The training loss of step 75: 1531.0381355353509; the test loss of step 75: 1828.3422450872474.
# Compiling calculate_test_loss ...
# The training loss of step 76: 1525.3313071476803; the test loss of step 76: 1810.1795765964357.
# Compiling calculate_test_loss ...
# The training loss of step 77: 1521.8106549657614; the test loss of step 77: 1795.0025585042804.
# Compiling calculate_test_loss ...
# The training loss of step 78: 1521.4484337043186; the test loss of step 78: 1787.4149186570312.
# Compiling calculate_test_loss ...
# The training loss of step 79: 1521.685911778088; the test loss of step 79: 1785.624956150246.
# Compiling calculate_test_loss ...
# The training loss of step 80: 1521.2800086297275; the test loss of step 80: 1791.0541507786088.
# Compiling calculate_test_loss ...
# The training loss of step 81: 1520.1508952119234; the test loss of step 81: 1802.3704786469905.
# Compiling calculate_test_loss ...
# The training loss of step 82: 1518.3362771674279; the test loss of step 82: 1819.4468323399074.
# Compiling calculate_test_loss ...
# The training loss of step 83: 1516.8051757075807; the test loss of step 83: 1838.527600842288.
# Compiling calculate_test_loss ...
# The training loss of step 84: 1516.745742913837; the test loss of step 84: 1858.2535031626123.
# Compiling calculate_test_loss ...
# The training loss of step 85: 1517.730905342692; the test loss of step 85: 1873.2982798424114.
# Compiling calculate_test_loss ...
# The training loss of step 86: 1519.8243658283923; the test loss of step 86: 1881.9417282700863.
# Compiling calculate_test_loss ...
# The training loss of step 87: 1520.9478900346812; the test loss of step 87: 1882.8560908017973.
# Compiling calculate_test_loss ...
# The training loss of step 88: 1520.7164243437783; the test loss of step 88: 1876.2764529323879.
# Compiling calculate_test_loss ...
# The training loss of step 89: 1519.6285202360068; the test loss of step 89: 1864.1133004834871.
# Compiling calculate_test_loss ...
# The training loss of step 90: 1517.7390517331346; the test loss of step 90: 1850.729803769057.
# Compiling calculate_test_loss ...
# The training loss of step 91: 1516.2096961396596; the test loss of step 91: 1837.3662670370873.
# Compiling calculate_test_loss ...
# The training loss of step 92: 1515.7279807024802; the test loss of step 92: 1827.5897750573552.
# Compiling calculate_test_loss ...
# The training loss of step 93: 1515.631436890078; the test loss of step 93: 1821.9947693614379.
# Compiling calculate_test_loss ...
# The training loss of step 94: 1516.1551373614204; the test loss of step 94: 1813.3826151296153.
# Compiling calculate_test_loss ...
# The training loss of step 95: 1516.4713849479385; the test loss of step 95: 1811.178909772186.
# Compiling calculate_test_loss ...
# The training loss of step 96: 1516.5542530245693; the test loss of step 96: 1818.73660274322.
# Compiling calculate_test_loss ...
# The training loss of step 97: 1516.1674496292799; the test loss of step 97: 1829.8484305899945.
# Compiling calculate_test_loss ...
# The training loss of step 98: 1516.0667434541065; the test loss of step 98: 1842.0737655408861.
# Compiling calculate_test_loss ...
# The training loss of step 99: 1516.9469053235925; the test loss of step 99: 1852.235536614068.
# Compiling calculate_test_loss ...
# The training loss of step 100: 1517.9836819383409; the test loss of step 100: 1855.5297964516453.
# Compiling calculate_test_loss ...
# The training loss of step 101: 1518.6467264942373; the test loss of step 101: 1856.5467835224174.
# Compiling calculate_test_loss ...
# The training loss of step 102: 1518.9938000893576; the test loss of step 102: 1855.7332493455972.
# Compiling calculate_test_loss ...
# The training loss of step 103: 1519.0492013093326; the test loss of step 103: 1852.5838405842346.
# Compiling calculate_test_loss ...
# The training loss of step 104: 1518.8124984881556; the test loss of step 104: 1848.2660027157501.
# Compiling calculate_test_loss ...
# The training loss of step 105: 1518.47121957149; the test loss of step 105: 1843.3386373565577.
# Compiling calculate_test_loss ...
# The training loss of step 106: 1518.088915551311; the test loss of step 106: 1838.4778454896668.
# Compiling calculate_test_loss ...
# The training loss of step 107: 1517.6626858334225; the test loss of step 107: 1833.839841500336.
# Compiling calculate_test_loss ...
# The training loss of step 108: 1517.4839001962453; the test loss of step 108: 1829.5124659312607.
# Compiling calculate_test_loss ...
# The training loss of step 109: 1517.255734595829; the test loss of step 109: 1826.1938823756436.
# Compiling calculate_test_loss ...
# The training loss of step 110: 1517.244981675799; the test loss of step 110: 1824.5077842217336.
# Compiling calculate_test_loss ...
# The training loss of step 111: 1517.1896220975307; the test loss of step 111: 1825.207605172654.
# Compiling calculate_test_loss ...
# The training loss of step 112: 1517.257807542128; the test loss of step 112: 1826.9355564536236.
# Compiling calculate_test_loss ...
# The training loss of step 113: 1517.1846400604004; the test loss of step 113: 1829.073050782564.
# Compiling calculate_test_loss ...
# The training loss of step 114: 1517.3473019152766; the test loss of step 114: 1831.5429832755515.
# Compiling calculate_test_loss ...
# The training loss of step 115: 1517.57285584066; the test loss of step 115: 1834.46718961276.
# Compiling calculate_test_loss ...
# The training loss of step 116: 1517.6004390434127; the test loss of step 116: 1838.8615366796664.
# Compiling calculate_test_loss ...
# The training loss of step 117: 1517.9249608399878; the test loss of step 117: 1842.0595343401872.
# Compiling calculate_test_loss ...
# The training loss of step 118: 1517.9780854571322; the test loss of step 118: 1843.972910425382.
# Compiling calculate_test_loss ...
# The training loss of step 119: 1518.22951836821; the test loss of step 119: 1844.7830500154982.
# Compiling calculate_test_loss ...
# The training loss of step 120: 1518.4177528627276; the test loss of step 120: 1844.480017970181.
# Compiling calculate_test_loss ...
# The training loss of step 121: 1518.3015777096384; the test loss of step 121: 1843.3799782978037.
# Compiling calculate_test_loss ...
# The training loss of step 122: 1518.2910140989839; the test loss of step 122: 1841.4428232226219.
# Compiling calculate_test_loss ...
# The training loss of step 123: 1517.8431070215006; the test loss of step 123: 1838.3123738083434.
# Compiling calculate_test_loss ...
# The training loss of step 124: 1517.7147969521905; the test loss of step 124: 1833.660736183422.
# Compiling calculate_test_loss ...
# The training loss of step 125: 1517.3495301443572; the test loss of step 125: 1829.7955272692243.
# Compiling calculate_test_loss ...
# The training loss of step 126: 1517.0538264501986; the test loss of step 126: 1827.0581918966616.
# Compiling calculate_test_loss ...
# The training loss of step 127: 1516.839148697984; the test loss of step 127: 1825.3792367197261.
# Compiling calculate_test_loss ...
# The training loss of step 128: 1516.799952064836; the test loss of step 128: 1824.6966000428072.
# Compiling calculate_test_loss ...
# The training loss of step 129: 1516.7584602967283; the test loss of step 129: 1825.0279135533378.
# Compiling calculate_test_loss ...
# The training loss of step 130: 1516.7652165732388; the test loss of step 130: 1826.5078479089198.
# Compiling calculate_test_loss ...
# The training loss of step 131: 1516.7810161074094; the test loss of step 131: 1828.845006460335.
# Compiling calculate_test_loss ...
# The training loss of step 132: 1517.0063129987798; the test loss of step 132: 1831.975488479851.
# Compiling calculate_test_loss ...
# The training loss of step 133: 1517.226281457541; the test loss of step 133: 1834.9745466060035.
# Compiling calculate_test_loss ...
# The training loss of step 134: 1517.3570645495456; the test loss of step 134: 1837.605316937304.
# Compiling calculate_test_loss ...
# The training loss of step 135: 1517.4496014120314; the test loss of step 135: 1839.6632818675703.
# Compiling calculate_test_loss ...
# The training loss of step 136: 1517.6831452354816; the test loss of step 136: 1840.997094873293.
# Compiling calculate_test_loss ...
# The training loss of step 137: 1517.870981952704; the test loss of step 137: 1842.0210972915334.
# Compiling calculate_test_loss ...
# The training loss of step 138: 1517.8320871055093; the test loss of step 138: 1841.6009638801604.
# Compiling calculate_test_loss ...
# The training loss of step 139: 1517.8104951472305; the test loss of step 139: 1840.3659880459863.
# Compiling calculate_test_loss ...
# The training loss of step 140: 1517.7089346238758; the test loss of step 140: 1788.9537007433833.
# Compiling calculate_test_loss ...
# The training loss of step 141: 1520.109066965562; the test loss of step 141: 1754.8124977138816.
# Compiling calculate_test_loss ...
# The training loss of step 142: 1531.895590967032; the test loss of step 142: 1733.2400326176212.
# Compiling calculate_test_loss ...
# The training loss of step 143: 1547.52770038376; the test loss of step 143: 1720.8784664034554.
# Compiling calculate_test_loss ...
# The training loss of step 144: 1561.4397507338772; the test loss of step 144: 1714.2035516606697.
# Compiling calculate_test_loss ...
# The training loss of step 145: 1570.533910171749; the test loss of step 145: 1711.3206316015705.
# Compiling calculate_test_loss ...
# The training loss of step 146: 1574.618263604184; the test loss of step 146: 1711.6878820271286.
# Compiling calculate_test_loss ...
# The training loss of step 147: 1574.026488726843; the test loss of step 147: 1714.5235612192214.
# Compiling calculate_test_loss ...
# The training loss of step 148: 1569.173948114877; the test loss of step 148: 1720.7088249471303.
# Compiling calculate_test_loss ...
# The training loss of step 149: 1562.5347819186277; the test loss of step 149: 1731.1725278589743.
# Compiling calculate_test_loss ...
# The training loss of step 150: 1554.4688653467274; the test loss of step 150: 1746.1276874804441.
# Compiling calculate_test_loss ...
# The training loss of step 151: 1548.052465094906; the test loss of step 151: 1764.62362963544.
# Compiling calculate_test_loss ...
# The training loss of step 152: 1544.9727820655353; the test loss of step 152: 1784.798194992702.
# Compiling calculate_test_loss ...
# The training loss of step 153: 1544.4734458200824; the test loss of step 153: 1806.389261047097.
# Compiling calculate_test_loss ...
# The training loss of step 154: 1546.923472659417; the test loss of step 154: 1826.8393280714554.
# Compiling calculate_test_loss ...
# The training loss of step 155: 1551.0229832184718; the test loss of step 155: 1843.3162912553407.
# Compiling calculate_test_loss ...
# The training loss of step 156: 1554.5479447625899; the test loss of step 156: 1855.5664310784498.
# Compiling calculate_test_loss ...
# The training loss of step 157: 1556.6129216717204; the test loss of step 157: 1861.77460809654.
# Compiling calculate_test_loss ...
# The training loss of step 158: 1556.5836264855293; the test loss of step 158: 1863.0835728294755.
# Compiling calculate_test_loss ...
# The training loss of step 159: 1554.5312440504115; the test loss of step 159: 1859.697848271753.
# Compiling calculate_test_loss ...
# The training loss of step 160: 1550.1760318842705; the test loss of step 160: 1853.006269670276.
# Compiling calculate_test_loss ...
# The training loss of step 161: 1545.1457790847257; the test loss of step 161: 1844.3789203425797.
# Compiling calculate_test_loss ...
# The training loss of step 162: 1539.8372477433072; the test loss of step 162: 1834.734620089449.
# Compiling calculate_test_loss ...
# The training loss of step 163: 1534.7711385969958; the test loss of step 163: 1825.0827458456274.
# Compiling calculate_test_loss ...
# The training loss of step 164: 1530.311517184842; the test loss of step 164: 1816.127807698539.
# Compiling calculate_test_loss ...
# The training loss of step 165: 1526.7898584281409; the test loss of step 165: 1809.2370888880891.
# Compiling calculate_test_loss ...
# The training loss of step 166: 1524.441183296503; the test loss of step 166: 1803.3393156592965.
# Compiling calculate_test_loss ...
# The training loss of step 167: 1522.8077136141392; the test loss of step 167: 1799.1000976282578.
# Compiling calculate_test_loss ...
# The training loss of step 168: 1521.6693693063798; the test loss of step 168: 1796.7495740917327.
# Compiling calculate_test_loss ...
# The training loss of step 169: 1521.4103969601306; the test loss of step 169: 1796.324366494423.
# Compiling calculate_test_loss ...
# The training loss of step 170: 1520.5379536676542; the test loss of step 170: 1797.8306370739144.
# Compiling calculate_test_loss ...
# The training loss of step 171: 1519.3810688773756; the test loss of step 171: 1800.7569686921445.
# Compiling calculate_test_loss ...
# The training loss of step 172: 1518.7916974900847; the test loss of step 172: 1805.070027601342.
# Compiling calculate_test_loss ...
# The training loss of step 173: 1518.0562440272613; the test loss of step 173: 1810.5199967697017.
# Compiling calculate_test_loss ...
# The training loss of step 174: 1517.376670359391; the test loss of step 174: 1817.0393983667766.
# Compiling calculate_test_loss ...
# The training loss of step 175: 1516.7579900828428; the test loss of step 175: 1824.1582601715897.
# Compiling calculate_test_loss ...
# The training loss of step 176: 1516.8621285304066; the test loss of step 176: 1831.031474563733.
# Compiling calculate_test_loss ...
# The training loss of step 177: 1516.600850862374; the test loss of step 177: 1837.6741877399859.
# Compiling calculate_test_loss ...
# The training loss of step 178: 1516.927815994627; the test loss of step 178: 1844.2495367803815.
# Compiling calculate_test_loss ...
# The training loss of step 179: 1516.946375868844; the test loss of step 179: 1850.0544442369076.
# Compiling calculate_test_loss ...
# The training loss of step 180: 1517.322729887097; the test loss of step 180: 1854.6033806977364.
# Compiling calculate_test_loss ...
# The training loss of step 181: 1517.4928164074117; the test loss of step 181: 1846.6168274156853.
# Compiling calculate_test_loss ...
# The training loss of step 182: 1516.8287218093033; the test loss of step 182: 1839.3788682482339.
# Compiling calculate_test_loss ...
# The training loss of step 183: 1516.6498896119451; the test loss of step 183: 1832.924269702595.
# Compiling calculate_test_loss ...
# The training loss of step 184: 1516.652114873466; the test loss of step 184: 1827.949222898859.
# Compiling calculate_test_loss ...
# The training loss of step 185: 1516.5936177542517; the test loss of step 185: 1823.9082067929373.
# Compiling calculate_test_loss ...
# The training loss of step 186: 1516.6323245744527; the test loss of step 186: 1821.3381813385577.
# Compiling calculate_test_loss ...
# The training loss of step 187: 1516.5102531582984; the test loss of step 187: 1873.961041671267.
# Compiling calculate_test_loss ...
# The training loss of step 188: 1520.3791345869477; the test loss of step 188: 1929.2301492371114.
# Compiling calculate_test_loss ...
# The training loss of step 189: 1531.8833883956563; the test loss of step 189: 1982.5873320987207.
# Compiling calculate_test_loss ...
# The training loss of step 190: 1549.72479872028; the test loss of step 190: 2029.1798623774964.
# Compiling calculate_test_loss ...
# The training loss of step 191: 1568.510513439368; the test loss of step 191: 2064.3320984641564.
# Compiling calculate_test_loss ...
# The training loss of step 192: 1582.2350079052026; the test loss of step 192: 2085.5057578821506.
# Compiling calculate_test_loss ...
# The training loss of step 193: 1590.1570224364136; the test loss of step 193: 2091.1382951896153.
# Compiling calculate_test_loss ...
# The training loss of step 194: 1590.7595451475845; the test loss of step 194: 2083.152287465276.
# Compiling calculate_test_loss ...
# The training loss of step 195: 1585.4537364971673; the test loss of step 195: 2063.796079026319.
# Compiling calculate_test_loss ...
# The training loss of step 196: 1575.3441626545318; the test loss of step 196: 2034.230897900767.
# Compiling calculate_test_loss ...
# The training loss of step 197: 1561.6191635584164; the test loss of step 197: 2000.5198267334324.
# Compiling calculate_test_loss ...
# The training loss of step 198: 1547.6755116819463; the test loss of step 198: 1966.6605818303985.
# Compiling calculate_test_loss ...
# The training loss of step 199: 1535.686672199283; the test loss of step 199: 1933.7700666652865.
# Compiling calculate_test_loss ...
# The training loss of step 200: 1526.6494202894066; the test loss of step 200: 1918.5789488915375.
# Compiling calculate_test_loss ...
# The training loss of step 201: 1523.572965250804; the test loss of step 201: 1904.26332546992.
# Compiling calculate_test_loss ...
# The training loss of step 202: 1521.2586282621623; the test loss of step 202: 1891.37241159606.
# Compiling calculate_test_loss ...
# The training loss of step 203: 1519.651122558962; the test loss of step 203: 1879.8472598681842.
# Compiling calculate_test_loss ...
# The training loss of step 204: 1518.59114691207; the test loss of step 204: 1869.5818090061653.
# Compiling calculate_test_loss ...
# The training loss of step 205: 1518.0223720440747; the test loss of step 205: 1861.3080369700942.
# Compiling calculate_test_loss ...
# The training loss of step 206: 1517.4689674751394; the test loss of step 206: 1853.633500790936.
# Compiling calculate_test_loss ...
# The training loss of step 207: 1517.9406100855088; the test loss of step 207: 1847.2518527863065.
# Compiling calculate_test_loss ...
# The training loss of step 208: 1518.0949042930583; the test loss of step 208: 1841.8011790850094.
# Compiling calculate_test_loss ...
# The training loss of step 209: 1518.2413156706937; the test loss of step 209: 1837.8468933928993.
# Compiling calculate_test_loss ...
# The training loss of step 210: 1519.0651461098664; the test loss of step 210: 1835.4814499944403.
# Compiling calculate_test_loss ...
# The training loss of step 211: 1518.9942497978468; the test loss of step 211: 1833.6249943807027.
# Compiling calculate_test_loss ...
# The training loss of step 212: 1519.0515155192516; the test loss of step 212: 1832.422746332113.
# Compiling calculate_test_loss ...
# The training loss of step 213: 1518.6930197893573; the test loss of step 213: 1832.0578949680958.
# Compiling calculate_test_loss ...
# The training loss of step 214: 1518.477373498069; the test loss of step 214: 1831.956918613971.
# Compiling calculate_test_loss ...
# The training loss of step 215: 1518.0655854329045; the test loss of step 215: 1832.763483012577.
# Compiling calculate_test_loss ...
# The training loss of step 216: 1517.3192203909111; the test loss of step 216: 1834.0909180754447.
# Compiling calculate_test_loss ...
# The training loss of step 217: 1516.661137507564; the test loss of step 217: 1835.8518017652552.
# Compiling calculate_test_loss ...
# The training loss of step 218: 1516.3594082715788; the test loss of step 218: 1837.6601077415303.
# Compiling calculate_test_loss ...
# The training loss of step 219: 1515.9587676821975; the test loss of step 219: 1840.0604509426048.
# Compiling calculate_test_loss ...
# The training loss of step 220: 1515.5789009287632; the test loss of step 220: 1842.6261353915256.
# Compiling calculate_test_loss ...
# The training loss of step 221: 1515.2318946244768; the test loss of step 221: 1845.5720702918313.
# Compiling calculate_test_loss ...
# The training loss of step 222: 1515.4531215662494; the test loss of step 222: 1847.9697920288486.
# Compiling calculate_test_loss ...
# The training loss of step 223: 1515.1090307414001; the test loss of step 223: 1850.6304203459326.
# Compiling calculate_test_loss ...
# The training loss of step 224: 1514.92904985619; the test loss of step 224: 1852.884491421214.
# Compiling calculate_test_loss ...
# The training loss of step 225: 1515.2483325936246; the test loss of step 225: 1854.7772752382095.
# Compiling calculate_test_loss ...
# The training loss of step 226: 1515.8303214558673; the test loss of step 226: 1856.6901336114981.
# Compiling calculate_test_loss ...
# The training loss of step 227: 1516.0169474829318; the test loss of step 227: 1858.2804783504002.
# Compiling calculate_test_loss ...
# The training loss of step 228: 1516.3762561002854; the test loss of step 228: 1860.063660880311.
# Compiling calculate_test_loss ...
# The training loss of step 229: 1516.6056539405085; the test loss of step 229: 1861.2134165080804.
# Compiling calculate_test_loss ...
# The training loss of step 230: 1516.6423550857019; the test loss of step 230: 1861.7500929883702.
# Compiling calculate_test_loss ...
# The training loss of step 231: 1517.0403304733481; the test loss of step 231: 1861.7267797916538.
# Compiling calculate_test_loss ...
# The training loss of step 232: 1517.26538538423; the test loss of step 232: 1861.44554280311.
# Compiling calculate_test_loss ...
# The training loss of step 233: 1517.3524918973367; the test loss of step 233: 1860.8574673477262.
# Compiling calculate_test_loss ...
# The training loss of step 234: 1517.4734197572793; the test loss of step 234: 1859.5767208827654.
# Compiling calculate_test_loss ...
# The training loss of step 235: 1517.3908504929339; the test loss of step 235: 1858.0132739381647.
# Compiling calculate_test_loss ...
# The training loss of step 236: 1517.1876471896135; the test loss of step 236: 1856.2907886320088.
# Compiling calculate_test_loss ...
# The training loss of step 237: 1517.1849388047895; the test loss of step 237: 1854.2858465915417.
# Compiling calculate_test_loss ...
# The training loss of step 238: 1517.0490087161052; the test loss of step 238: 1852.1702884089889.
# Compiling calculate_test_loss ...
# The training loss of step 239: 1517.0564669591881; the test loss of step 239: 1850.1736396578724.
# Compiling calculate_test_loss ...
# The training loss of step 240: 1517.0054672740116; the test loss of step 240: 1848.1493558668562.
# Compiling calculate_test_loss ...
# The training loss of step 241: 1516.8884955040899; the test loss of step 241: 1846.1018214080711.
# Compiling calculate_test_loss ...
# The training loss of step 242: 1516.9500989024343; the test loss of step 242: 1843.88777573312.
# Compiling calculate_test_loss ...
# The training loss of step 243: 1516.796521487059; the test loss of step 243: 1841.972475104159.
# Compiling calculate_test_loss ...
# The training loss of step 244: 1517.0363462936102; the test loss of step 244: 1840.3446833792157.
# Compiling calculate_test_loss ...
# The training loss of step 245: 1516.8342218071693; the test loss of step 245: 1838.5913038370568.
# Compiling calculate_test_loss ...
# The training loss of step 246: 1516.706131356102; the test loss of step 246: 1837.6246156269287.
# Compiling calculate_test_loss ...
# The training loss of step 247: 1516.6404556456214; the test loss of step 247: 1836.6794272284053.
# Compiling calculate_test_loss ...
# The training loss of step 248: 1516.6603590697653; the test loss of step 248: 1835.906655332319.
# Compiling calculate_test_loss ...
# The training loss of step 249: 1516.7468307897202; the test loss of step 249: 1835.1322660874184.
# Compiling calculate_test_loss ...
# The training loss of step 250: 1516.6513665664986; the test loss of step 250: 1834.6743317747923.
# Compiling calculate_test_loss ...
# The training loss of step 251: 1516.711939772776; the test loss of step 251: 1834.0411035622317.
# Compiling calculate_test_loss ...
# The training loss of step 252: 1516.788748199774; the test loss of step 252: 1833.7410082417616.
# Compiling calculate_test_loss ...
# The training loss of step 253: 1516.8122527929836; the test loss of step 253: 1833.3412748919343.
# Compiling calculate_test_loss ...
# The training loss of step 254: 1516.8190418371473; the test loss of step 254: 1832.872900095135.
# Compiling calculate_test_loss ...
# The training loss of step 255: 1516.818080805379; the test loss of step 255: 1832.575118686957.
# Compiling calculate_test_loss ...
# The training loss of step 256: 1516.9329106449372; the test loss of step 256: 1832.5863117161246.
# Compiling calculate_test_loss ...
# The training loss of step 257: 1517.0526232345337; the test loss of step 257: 1832.6010550660728.
# Compiling calculate_test_loss ...
# The training loss of step 258: 1517.1873890436873; the test loss of step 258: 1832.9375540631622.
# Compiling calculate_test_loss ...
# The training loss of step 259: 1517.2491309811678; the test loss of step 259: 1833.013548260813.
# Compiling calculate_test_loss ...
# The training loss of step 260: 1517.357725053248; the test loss of step 260: 1833.1374227698848.
# Compiling calculate_test_loss ...
# The training loss of step 261: 1517.3230430301537; the test loss of step 261: 1833.488894024247.
# Compiling calculate_test_loss ...
# The training loss of step 262: 1517.4009783257006; the test loss of step 262: 1833.7333672805657.
# Compiling calculate_test_loss ...
# The training loss of step 263: 1517.369694431976; the test loss of step 263: 1834.0018175846922.
# Compiling calculate_test_loss ...
# The training loss of step 264: 1517.380875722978; the test loss of step 264: 1834.2958971509975.
# Compiling calculate_test_loss ...
# The training loss of step 265: 1517.3500779021015; the test loss of step 265: 1834.4807741140337.
# Compiling calculate_test_loss ...
# The training loss of step 266: 1517.3692931945077; the test loss of step 266: 1834.5824493621378.
# Compiling calculate_test_loss ...
# The training loss of step 267: 1517.3828954761188; the test loss of step 267: 1834.7580207452052.
# Compiling calculate_test_loss ...
# The training loss of step 268: 1517.3747048172427; the test loss of step 268: 1834.8812268660952.
# Compiling calculate_test_loss ...
# The training loss of step 269: 1517.3400255865495; the test loss of step 269: 1834.9365818828294.
# Compiling calculate_test_loss ...
# The training loss of step 270: 1517.3700109807469; the test loss of step 270: 1835.0532946928652.
# Compiling calculate_test_loss ...
# The training loss of step 271: 1517.3905612849453; the test loss of step 271: 1835.1096423769202.
# Compiling calculate_test_loss ...
# The training loss of step 272: 1517.4133214427054; the test loss of step 272: 1834.9977984246698.
# Compiling calculate_test_loss ...
# The training loss of step 273: 1517.4155112500284; the test loss of step 273: 1834.9300350036333.
# Compiling calculate_test_loss ...
# The training loss of step 274: 1517.4099661746827; the test loss of step 274: 1834.981250939384.
# Compiling calculate_test_loss ...
# The training loss of step 275: 1517.3844497146306; the test loss of step 275: 1834.9804595034282.
# Compiling calculate_test_loss ...
# The training loss of step 276: 1517.445226200321; the test loss of step 276: 1834.9909832711085.
# Compiling calculate_test_loss ...
# The training loss of step 277: 1517.4513614301518; the test loss of step 277: 1834.8904122538881.
# Compiling calculate_test_loss ...
# The training loss of step 278: 1517.3261441860209; the test loss of step 278: 1834.960338638598.
# Compiling calculate_test_loss ...
# The training loss of step 279: 1517.3895418453744; the test loss of step 279: 1835.0345158744483.
# Compiling calculate_test_loss ...
# The training loss of step 280: 1517.3950817331179; the test loss of step 280: 1835.1527444418623.
# Compiling calculate_test_loss ...
# The training loss of step 281: 1517.425775375078; the test loss of step 281: 1835.9281268009975.
# Compiling calculate_test_loss ...
# The training loss of step 282: 1517.4154525859585; the test loss of step 282: 1836.819710223623.
# Compiling calculate_test_loss ...
# The training loss of step 283: 1517.4817954755188; the test loss of step 283: 1837.7313029495363.
# Compiling calculate_test_loss ...
# The training loss of step 284: 1517.3994478059062; the test loss of step 284: 1838.030678004713.
# Compiling calculate_test_loss ...
# The training loss of step 285: 1517.4110070598394; the test loss of step 285: 1838.338381033088.
# Compiling calculate_test_loss ...
# The training loss of step 286: 1517.3857639157668; the test loss of step 286: 1838.4438797853609.
# Compiling calculate_test_loss ...
# The training loss of step 287: 1517.3722269980485; the test loss of step 287: 1838.316964397032.
# Compiling calculate_test_loss ...
# The training loss of step 288: 1517.3266676461285; the test loss of step 288: 1838.1316927523726.
# Compiling calculate_test_loss ...
# The training loss of step 289: 1517.2323073446032; the test loss of step 289: 1837.8821890281629.
# Compiling calculate_test_loss ...
# The training loss of step 290: 1517.2829148911087; the test loss of step 290: 1837.4917758379854.
# Compiling calculate_test_loss ...
# The training loss of step 291: 1517.265038535494; the test loss of step 291: 1837.268640025072.
# Compiling calculate_test_loss ...
# The training loss of step 292: 1517.2236519663197; the test loss of step 292: 1836.708390668966.
# Compiling calculate_test_loss ...
# The training loss of step 293: 1517.3403304963538; the test loss of step 293: 1835.1064531848936.
# Compiling calculate_test_loss ...
# The training loss of step 294: 1517.4005447361146; the test loss of step 294: 1833.5532685058988.
# Compiling calculate_test_loss ...
# The training loss of step 295: 1517.2200920832083; the test loss of step 295: 1832.2100176057081.
# Compiling calculate_test_loss ...
# The training loss of step 296: 1517.1055681755029; the test loss of step 296: 1831.0627248381736.
# Compiling calculate_test_loss ...
# The training loss of step 297: 1517.0248665233205; the test loss of step 297: 1830.1872555618706.
# Compiling calculate_test_loss ...
# The training loss of step 298: 1517.0752749486605; the test loss of step 298: 1828.0941222354188.
# Compiling calculate_test_loss ...
# The training loss of step 299: 1516.861977202013; the test loss of step 299: 1826.5375152467666.

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.plot(loss_train_set, label="Train")
ax.plot(loss_test_set, label="Test")
ax.set(xlabel="Epochs", ylabel="L2", title="Loss function", yscale="linear")
ax.legend()

# %% [markdown]
# ## Rerun the model using the estimated parameters

# %% [markdown]
# ### Calibration period

# %%
states, drivers = canveg_eqx_new(met)
(
    met_new,
    prof_new,
    ir_new,
    qin_new,
    sun_new,
    shade_new,
    soil_new,
    veg_new,
    can_new,
) = states
# quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canveg_in_batch(batched_met, canoak_eqx_ift)

# %%
plot_obs_comparison(obs, can_new);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can_new.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %% [markdown]
# ### Test period

# %%
states_test, drivers_test = canoak_eqx_new(met_test)
(
    _,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test

# %%
plot_obs_comparison(obs_test, can_test);

# %%
plot_timeseries_obs_1to1(
    obs_test.LE,
    can_test.LE,
    lim=[-100, 1000],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
);

# %%
metrics = compute_metrics(obs.LE, can_new.LE)
metrics_test = compute_metrics(obs_test.LE, can_test.LE)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 38.94716182552766, 'mse': 1516.881414263839, 'r2': 0.8672314199315405, 'kge': 0.9147115473627282, 'nse': 0.8536300750707868, 'mkge': 0.919966694391457, 'cc': 0.9315068217359189, 'alpha': 1.0092450264846402, 'beta': 1.0403552229979411}
# {'rmse': 42.738010192880594, 'mse': 1826.5375152467657, 'r2': 0.8470207405417763, 'kge': 0.8135297968148136, 'nse': 0.7968541649369544, 'mkge': 0.8706873871235717, 'cc': 0.9230740821440496, 'alpha': 1.0751023765132681, 'beta': 1.0718595021761763}

# %% [markdown]
# # Save the models

# %%
config = {
    "site": site,
    "key": key,
    "f_forcing": f_forcing,
    "f_obs": f_obs,
    "f_forcing_test": f_forcing_test,
    "f_obs_test": f_obs_test,
}

train = {
    "loss": loss_train_set,
    "time": timesteps,
    "can.LE": can_new.LE,
    "sun.gs": sun_new.gs,
    "shade.gs": shade_new.gs,
    "sun.Ps": sun_new.Ps,
    "shade.Ps": shade_new.Ps,
    "can.H": can_new.H,
    "can.rnet": can_new.rnet,
    "can.gsoil": can_new.gsoil,
    "sun.Tlk": sun_new.Tsfc,
    "shade.Tlk": shade_new.Tsfc,
    "sun.Leaf_RH": sun_new.Leaf_RH,
    "shade.Leaf_RH": shade_new.Leaf_RH,
    "soil.Tsoil": soil_new.T_soil,
}

test = {
    "loss": loss_test_set,
    "time": timesteps_test,
    "can.LE": can_test.LE,
    "sun.gs": sun_test.gs,
    "shade.gs": shade_test.gs,
    "sun.Ps": sun_test.Ps,
    "shade.Ps": shade_test.Ps,
    "can.H": can_test.H,
    "can.rnet": can_test.rnet,
    "can.gsoil": can_test.gsoil,
    "sun.Tlk": sun_test.Tsfc,
    "shade.Tlk": shade_test.Tsfc,
    "sun.Leaf_RH": sun_test.Leaf_RH,
    "shade.Leaf_RH": shade_test.Leaf_RH,
    "soil.Tsoil": soil_test.T_soil,
}

out = {"train": train, "test": test, "config": config}
pickle.dump(out, open(f"{site}_{key}.pkl", "wb"), pickle.HIGHEST_PROTOCOL)

# %%
# Save the model
hyperparams = dict(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    niter=niter,
)

save_model(f_model, hyperparams, canveg_eqx_new)
