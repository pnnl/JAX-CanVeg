# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# TODO: A more generic way is needed here to load the path
import sys

sys.path.append(
    "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
    # "/global/homes/p/peishi89/jax-watershed/src"
)

# %%
import time

from typing import List

import optax
import equinox as eqx

import torch
from torch.utils.data import Dataset, DataLoader

from sklearn import preprocessing

import numpy as np
import jax
import jax.numpy as jnp

from jax_canoak.subjects import get_met_forcings, get_obs
from jax_canoak.shared_utilities.plot import get_time
from jax_canoak.shared_utilities import compute_metrics

import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_timeseries_obs_1to1,
)

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_debug_nans", False)
jax.config.update("jax_debug_infs", False)

# %load_ext autoreload
# %autoreload 2

# %%
small_size = 15
medium_size = 25
bigger_size = 30
plt.rc("font", size=small_size)  # controls default text sizes
plt.rc("axes", titlesize=small_size)  # fontsize of the axes title
plt.rc("axes", labelsize=small_size)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=small_size)  # fontsize of the tick labels
plt.rc("ytick", labelsize=small_size)  # fontsize of the tick labels
plt.rc("legend", fontsize=small_size)  # legend fontsize
plt.rc("figure", titlesize=small_size)  # fontsize of the figure title
plt.rc("text", usetex=False)

# %% [markdown]
# # Files / directories / DL hyperparameters

# %%
site, key = "US-Bi1", "dl"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-test.csv"

# %%
# Hyperparameters
batch_size = 64
initial_lr = 2e-1
nsteps = 500
seed = 5678

key = jax.random.PRNGKey(seed)

# %% [markdown]
# # Load forcings and outputs

# %%
varns = [
    "T_air",
    "rglobal",
    "eair",
    "wind",
    "CO2",
    "P_kPa",
    "ustar",
    "soilmoisture",
    "lai",
]

# %%
# Calibration period
met, n_time = get_met_forcings(f_forcing)
timesteps = get_time(met)
obs = get_obs(f_obs)
x = np.array(
    [
        met.T_air,
        met.rglobal,
        met.eair,
        met.wind,
        met.CO2,
        met.P_kPa,
        met.ustar,
        met.soilmoisture,
        met.lai,
    ]
).T
y = obs.LE
y = np.expand_dims(y, axis=-1)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %%
# Test period
met_test, n_time_test = get_met_forcings(f_forcing_test)
timesteps_test = get_time(met_test)
obs_test = get_obs(f_obs_test)
x_test = np.array(
    [
        met_test.T_air,
        met_test.rglobal,
        met_test.eair,
        met_test.wind,
        met_test.CO2,
        met_test.P_kPa,
        met_test.ustar,
        met_test.soilmoisture,
        met_test.lai,
    ]
).T
y_test = obs_test.LE
y_test = np.expand_dims(y_test, axis=-1)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Normalize the data

# %%
scaler_x = preprocessing.StandardScaler().fit(x)
scaler_y = preprocessing.StandardScaler().fit(y)

# %%
x_norm = scaler_x.transform(x)
y_norm = scaler_y.transform(y)
x_test_norm = scaler_x.transform(x_test)
y_test_norm = scaler_y.transform(y_test)

# %%
# x_norm = jax.nn.standardize(x,axis=0)
# y_norm = jax.nn.standardize(y,axis=0)
# x_test_norm = jax.nn.standardize(x_test,axis=0)
# y_test_norm = jax.nn.standardize(y_test,axis=0)

# %% [markdown]
# # MLP

# %% [markdown]
# ## Create dataset and dataloader

# %%
class CustomDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        # Return the size of the dataset, which is the length of one of the arrays
        return len(self.x)

    def __getitem__(self, idx):
        # Retrieve and return the corresponding elements from both arrays
        sample1 = self.x[idx]
        sample2 = self.y[idx]
        return sample1, sample2

# %%
# train_dataset = CustomDataset(x_norm, y_norm)
# test_dataset = CustomDataset(x_test_norm, y_test_norm)
train_dataset = CustomDataset(np.array(x_norm), np.array(y_norm))
test_dataset = CustomDataset(np.array(x_test_norm), np.array(y_test_norm))
trainloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)
testloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# ## Train a MLP model

# %%
# Define a deep learning model
n_input, n_output = x.shape[1], y.shape[1]
model = eqx.nn.MLP(n_input, n_output, 6, 6, activation=jax.nn.tanh, key=key)

# %%
# Training setup
scheduler = optax.piecewise_constant_schedule(
    initial_lr, boundaries_and_scales={50: 0.1, 100: 0.1, 200: 0.1}
)
# scheduler = optax.constant_schedule(initial_lr)
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer

# %%
# Loss function
@eqx.filter_jit
def loss_func(model, x_batch, y_batch):
    pred_y_batch = jax.vmap(model)(x_batch)
    return jnp.mean((y_batch - pred_y_batch) ** 2)

# %%
opt_state = optim.init(eqx.filter(model, eqx.is_array))


@eqx.filter_jit
def make_step(model, opt_state, x_batch, y_batch):
    loss_value, grads = eqx.filter_value_and_grad(loss_func)(model, x_batch, y_batch)
    updates, opt_state = optim.update(grads, opt_state, model)
    model = eqx.apply_updates(model, updates)
    return model, opt_state, loss_value


loss_train_all = []
loss_test_all = []
for step in range(nsteps):
    start_time = time.time()
    for x_batch_tensor, y_batch_tensor in trainloader:
        x_batch, y_batch = jnp.array(x_batch_tensor), jnp.array(y_batch_tensor)
        model, opt_state, loss_batch = make_step(model, opt_state, x_batch, y_batch)
    epoch_time = time.time() - start_time

    loss_train = loss_func(model, x_norm, y_norm)
    loss_test = loss_func(model, x_test_norm, y_test_norm)
    loss_train_all.append(loss_train)
    loss_test_all.append(loss_test)
    print("Epoch {} in {:0.2f} sec".format(step, epoch_time))
    # print("Training set loss: {}".format(loss_train))
    # print("Test set loss {}".format(loss_test))
# Out:
# Epoch 0 in 3.18 sec
# Epoch 1 in 2.38 sec
# Epoch 2 in 2.37 sec
# Epoch 3 in 2.37 sec
# Epoch 4 in 2.36 sec
# Epoch 5 in 2.36 sec
# Epoch 6 in 2.36 sec
# Epoch 7 in 2.37 sec
# Epoch 8 in 2.36 sec
# Epoch 9 in 2.36 sec
# Epoch 10 in 2.36 sec
# Epoch 11 in 2.36 sec
# Epoch 12 in 2.37 sec
# Epoch 13 in 2.36 sec
# Epoch 14 in 2.36 sec
# Epoch 15 in 2.36 sec
# Epoch 16 in 2.36 sec
# Epoch 17 in 2.36 sec
# Epoch 18 in 2.36 sec
# Epoch 19 in 2.35 sec
# Epoch 20 in 2.35 sec
# Epoch 21 in 2.37 sec
# Epoch 22 in 2.37 sec
# Epoch 23 in 2.32 sec
# Epoch 24 in 2.35 sec
# Epoch 25 in 2.35 sec
# Epoch 26 in 2.35 sec
# Epoch 27 in 2.25 sec
# Epoch 28 in 2.32 sec
# Epoch 29 in 2.36 sec
# Epoch 30 in 2.36 sec
# Epoch 31 in 2.32 sec
# Epoch 32 in 2.35 sec
# Epoch 33 in 2.34 sec
# Epoch 34 in 2.28 sec
# Epoch 35 in 2.33 sec
# Epoch 36 in 2.28 sec
# Epoch 37 in 2.35 sec
# Epoch 38 in 2.34 sec
# Epoch 39 in 2.36 sec
# Epoch 40 in 2.36 sec
# Epoch 41 in 2.33 sec
# Epoch 42 in 2.36 sec
# Epoch 43 in 2.36 sec
# Epoch 44 in 2.35 sec
# Epoch 45 in 2.33 sec
# Epoch 46 in 2.34 sec
# Epoch 47 in 2.34 sec
# Epoch 48 in 2.35 sec
# Epoch 49 in 2.35 sec
# Epoch 50 in 2.31 sec
# Epoch 51 in 2.30 sec
# Epoch 52 in 2.30 sec
# Epoch 53 in 2.34 sec
# Epoch 54 in 2.30 sec
# Epoch 55 in 2.35 sec
# Epoch 56 in 2.35 sec
# Epoch 57 in 2.34 sec
# Epoch 58 in 2.34 sec
# Epoch 59 in 2.32 sec
# Epoch 60 in 2.32 sec
# Epoch 61 in 2.33 sec
# Epoch 62 in 2.35 sec
# Epoch 63 in 2.33 sec
# Epoch 64 in 2.30 sec
# Epoch 65 in 2.33 sec
# Epoch 66 in 2.22 sec
# Epoch 67 in 2.34 sec
# Epoch 68 in 2.32 sec
# Epoch 69 in 2.34 sec
# Epoch 70 in 2.35 sec
# Epoch 71 in 2.34 sec
# Epoch 72 in 2.35 sec
# Epoch 73 in 2.32 sec
# Epoch 74 in 2.36 sec
# Epoch 75 in 2.35 sec
# Epoch 76 in 2.33 sec
# Epoch 77 in 2.27 sec
# Epoch 78 in 2.32 sec
# Epoch 79 in 2.28 sec
# Epoch 80 in 2.29 sec
# Epoch 81 in 2.29 sec
# Epoch 82 in 2.36 sec
# Epoch 83 in 2.36 sec
# Epoch 84 in 2.35 sec
# Epoch 85 in 2.34 sec
# Epoch 86 in 2.35 sec
# Epoch 87 in 2.34 sec
# Epoch 88 in 2.34 sec
# Epoch 89 in 2.35 sec
# Epoch 90 in 2.35 sec
# Epoch 91 in 2.39 sec
# Epoch 92 in 2.37 sec
# Epoch 93 in 2.29 sec
# Epoch 94 in 2.32 sec
# Epoch 95 in 2.37 sec
# Epoch 96 in 2.37 sec
# Epoch 97 in 2.36 sec
# Epoch 98 in 2.35 sec
# Epoch 99 in 2.36 sec
# Epoch 100 in 2.37 sec
# Epoch 101 in 2.29 sec
# Epoch 102 in 2.30 sec
# Epoch 103 in 2.37 sec
# Epoch 104 in 2.31 sec
# Epoch 105 in 2.29 sec
# Epoch 106 in 2.31 sec
# Epoch 107 in 2.32 sec
# Epoch 108 in 2.30 sec
# Epoch 109 in 2.33 sec
# Epoch 110 in 2.27 sec
# Epoch 111 in 2.27 sec
# Epoch 112 in 2.29 sec
# Epoch 113 in 2.36 sec
# Epoch 114 in 2.37 sec
# Epoch 115 in 2.35 sec
# Epoch 116 in 2.33 sec
# Epoch 117 in 2.30 sec
# Epoch 118 in 2.28 sec
# Epoch 119 in 2.31 sec
# Epoch 120 in 2.32 sec
# Epoch 121 in 2.29 sec
# Epoch 122 in 2.33 sec
# Epoch 123 in 2.33 sec
# Epoch 124 in 2.33 sec
# Epoch 125 in 2.30 sec
# Epoch 126 in 2.33 sec
# Epoch 127 in 2.33 sec
# Epoch 128 in 2.33 sec
# Epoch 129 in 2.33 sec
# Epoch 130 in 2.34 sec
# Epoch 131 in 2.34 sec
# Epoch 132 in 2.33 sec
# Epoch 133 in 2.33 sec
# Epoch 134 in 2.34 sec
# Epoch 135 in 2.34 sec
# Epoch 136 in 2.34 sec
# Epoch 137 in 2.34 sec
# Epoch 138 in 2.34 sec
# Epoch 139 in 2.35 sec
# Epoch 140 in 2.35 sec
# Epoch 141 in 2.35 sec
# Epoch 142 in 2.35 sec
# Epoch 143 in 2.33 sec
# Epoch 144 in 2.33 sec
# Epoch 145 in 2.33 sec
# Epoch 146 in 2.33 sec
# Epoch 147 in 2.34 sec
# Epoch 148 in 2.33 sec
# Epoch 149 in 2.32 sec
# Epoch 150 in 2.31 sec
# Epoch 151 in 2.34 sec
# Epoch 152 in 2.34 sec
# Epoch 153 in 2.33 sec
# Epoch 154 in 2.35 sec
# Epoch 155 in 2.35 sec
# Epoch 156 in 2.34 sec
# Epoch 157 in 2.31 sec
# Epoch 158 in 2.33 sec
# Epoch 159 in 2.32 sec
# Epoch 160 in 2.34 sec
# Epoch 161 in 2.36 sec
# Epoch 162 in 2.35 sec
# Epoch 163 in 2.35 sec
# Epoch 164 in 2.35 sec
# Epoch 165 in 2.37 sec
# Epoch 166 in 2.38 sec
# Epoch 167 in 2.38 sec
# Epoch 168 in 2.37 sec
# Epoch 169 in 2.36 sec
# Epoch 170 in 2.31 sec
# Epoch 171 in 2.31 sec
# Epoch 172 in 2.38 sec
# Epoch 173 in 2.34 sec
# Epoch 174 in 2.34 sec
# Epoch 175 in 2.37 sec
# Epoch 176 in 2.37 sec
# Epoch 177 in 2.33 sec
# Epoch 178 in 2.30 sec
# Epoch 179 in 2.31 sec
# Epoch 180 in 2.35 sec
# Epoch 181 in 2.34 sec
# Epoch 182 in 2.33 sec
# Epoch 183 in 2.33 sec
# Epoch 184 in 2.37 sec
# Epoch 185 in 2.36 sec
# Epoch 186 in 2.34 sec
# Epoch 187 in 2.34 sec
# Epoch 188 in 2.39 sec
# Epoch 189 in 2.39 sec
# Epoch 190 in 2.37 sec
# Epoch 191 in 2.29 sec
# Epoch 192 in 2.42 sec
# Epoch 193 in 2.35 sec
# Epoch 194 in 2.42 sec
# Epoch 195 in 2.35 sec
# Epoch 196 in 2.33 sec
# Epoch 197 in 2.34 sec
# Epoch 198 in 2.35 sec
# Epoch 199 in 2.34 sec
# Epoch 200 in 2.32 sec
# Epoch 201 in 2.35 sec
# Epoch 202 in 2.34 sec
# Epoch 203 in 2.31 sec
# Epoch 204 in 2.35 sec
# Epoch 205 in 2.35 sec
# Epoch 206 in 2.38 sec
# Epoch 207 in 2.37 sec
# Epoch 208 in 2.38 sec
# Epoch 209 in 2.34 sec
# Epoch 210 in 2.36 sec
# Epoch 211 in 2.29 sec
# Epoch 212 in 2.34 sec
# Epoch 213 in 2.36 sec
# Epoch 214 in 2.35 sec
# Epoch 215 in 2.34 sec
# Epoch 216 in 2.35 sec
# Epoch 217 in 2.32 sec
# Epoch 218 in 2.24 sec
# Epoch 219 in 2.33 sec
# Epoch 220 in 2.33 sec
# Epoch 221 in 2.26 sec
# Epoch 222 in 2.26 sec
# Epoch 223 in 2.31 sec
# Epoch 224 in 2.38 sec
# Epoch 225 in 2.35 sec
# Epoch 226 in 2.39 sec
# Epoch 227 in 2.30 sec
# Epoch 228 in 2.29 sec
# Epoch 229 in 2.32 sec
# Epoch 230 in 2.32 sec
# Epoch 231 in 2.30 sec
# Epoch 232 in 2.31 sec
# Epoch 233 in 2.33 sec
# Epoch 234 in 2.32 sec
# Epoch 235 in 2.39 sec
# Epoch 236 in 2.33 sec
# Epoch 237 in 2.28 sec
# Epoch 238 in 2.28 sec
# Epoch 239 in 2.24 sec
# Epoch 240 in 2.14 sec
# Epoch 241 in 2.29 sec
# Epoch 242 in 2.42 sec
# Epoch 243 in 2.35 sec
# Epoch 244 in 2.35 sec
# Epoch 245 in 2.35 sec
# Epoch 246 in 2.38 sec
# Epoch 247 in 2.36 sec
# Epoch 248 in 2.35 sec
# Epoch 249 in 2.39 sec
# Epoch 250 in 2.37 sec
# Epoch 251 in 2.34 sec
# Epoch 252 in 2.35 sec
# Epoch 253 in 2.34 sec
# Epoch 254 in 2.34 sec
# Epoch 255 in 2.35 sec
# Epoch 256 in 2.37 sec
# Epoch 257 in 2.35 sec
# Epoch 258 in 2.34 sec
# Epoch 259 in 2.32 sec
# Epoch 260 in 2.31 sec
# Epoch 261 in 2.34 sec
# Epoch 262 in 2.42 sec
# Epoch 263 in 2.35 sec
# Epoch 264 in 2.35 sec
# Epoch 265 in 2.30 sec
# Epoch 266 in 2.37 sec
# Epoch 267 in 2.42 sec
# Epoch 268 in 2.42 sec
# Epoch 269 in 2.38 sec
# Epoch 270 in 2.33 sec
# Epoch 271 in 2.34 sec
# Epoch 272 in 2.32 sec
# Epoch 273 in 2.28 sec
# Epoch 274 in 2.29 sec
# Epoch 275 in 2.30 sec
# Epoch 276 in 2.28 sec
# Epoch 277 in 2.36 sec
# Epoch 278 in 2.32 sec
# Epoch 279 in 2.31 sec
# Epoch 280 in 2.31 sec
# Epoch 281 in 2.37 sec
# Epoch 282 in 2.33 sec
# Epoch 283 in 2.36 sec
# Epoch 284 in 2.32 sec
# Epoch 285 in 2.27 sec
# Epoch 286 in 2.34 sec
# Epoch 287 in 2.33 sec
# Epoch 288 in 2.30 sec
# Epoch 289 in 2.28 sec
# Epoch 290 in 2.35 sec
# Epoch 291 in 2.30 sec
# Epoch 292 in 2.29 sec
# Epoch 293 in 2.32 sec
# Epoch 294 in 2.36 sec
# Epoch 295 in 2.35 sec
# Epoch 296 in 2.32 sec
# Epoch 297 in 2.34 sec
# Epoch 298 in 2.33 sec
# Epoch 299 in 2.32 sec
# Epoch 300 in 2.36 sec
# Epoch 301 in 2.36 sec
# Epoch 302 in 2.35 sec
# Epoch 303 in 2.34 sec
# Epoch 304 in 2.34 sec
# Epoch 305 in 2.34 sec
# Epoch 306 in 2.35 sec
# Epoch 307 in 2.34 sec
# Epoch 308 in 2.31 sec
# Epoch 309 in 2.34 sec
# Epoch 310 in 2.35 sec
# Epoch 311 in 2.34 sec
# Epoch 312 in 2.34 sec
# Epoch 313 in 2.36 sec
# Epoch 314 in 2.36 sec
# Epoch 315 in 2.37 sec
# Epoch 316 in 2.37 sec
# Epoch 317 in 2.35 sec
# Epoch 318 in 2.35 sec
# Epoch 319 in 2.35 sec
# Epoch 320 in 2.33 sec
# Epoch 321 in 2.35 sec
# Epoch 322 in 2.35 sec
# Epoch 323 in 2.34 sec
# Epoch 324 in 2.35 sec
# Epoch 325 in 2.34 sec
# Epoch 326 in 2.34 sec
# Epoch 327 in 2.34 sec
# Epoch 328 in 2.35 sec
# Epoch 329 in 2.35 sec
# Epoch 330 in 2.35 sec
# Epoch 331 in 2.35 sec
# Epoch 332 in 2.36 sec
# Epoch 333 in 2.36 sec
# Epoch 334 in 2.35 sec
# Epoch 335 in 2.34 sec
# Epoch 336 in 2.34 sec
# Epoch 337 in 2.28 sec
# Epoch 338 in 2.35 sec
# Epoch 339 in 2.33 sec
# Epoch 340 in 2.37 sec
# Epoch 341 in 2.36 sec
# Epoch 342 in 2.36 sec
# Epoch 343 in 2.34 sec
# Epoch 344 in 2.34 sec
# Epoch 345 in 2.35 sec
# Epoch 346 in 2.35 sec
# Epoch 347 in 2.35 sec
# Epoch 348 in 2.35 sec
# Epoch 349 in 2.34 sec
# Epoch 350 in 2.35 sec
# Epoch 351 in 2.34 sec
# Epoch 352 in 2.35 sec
# Epoch 353 in 2.35 sec
# Epoch 354 in 2.35 sec
# Epoch 355 in 2.35 sec
# Epoch 356 in 2.35 sec
# Epoch 357 in 2.35 sec
# Epoch 358 in 2.34 sec
# Epoch 359 in 2.35 sec
# Epoch 360 in 2.38 sec
# Epoch 361 in 2.37 sec
# Epoch 362 in 2.36 sec
# Epoch 363 in 2.35 sec
# Epoch 364 in 2.34 sec
# Epoch 365 in 2.36 sec
# Epoch 366 in 2.36 sec
# Epoch 367 in 2.35 sec
# Epoch 368 in 2.34 sec
# Epoch 369 in 2.35 sec
# Epoch 370 in 2.34 sec
# Epoch 371 in 2.34 sec
# Epoch 372 in 2.35 sec
# Epoch 373 in 2.34 sec
# Epoch 374 in 2.34 sec
# Epoch 375 in 2.33 sec
# Epoch 376 in 2.34 sec
# Epoch 377 in 2.33 sec
# Epoch 378 in 2.35 sec
# Epoch 379 in 2.30 sec
# Epoch 380 in 2.28 sec
# Epoch 381 in 2.26 sec
# Epoch 382 in 2.26 sec
# Epoch 383 in 2.27 sec
# Epoch 384 in 2.42 sec
# Epoch 385 in 2.36 sec
# Epoch 386 in 2.33 sec
# Epoch 387 in 2.24 sec
# Epoch 388 in 2.21 sec
# Epoch 389 in 2.22 sec
# Epoch 390 in 2.32 sec
# Epoch 391 in 2.33 sec
# Epoch 392 in 2.34 sec
# Epoch 393 in 2.33 sec
# Epoch 394 in 2.35 sec
# Epoch 395 in 2.34 sec
# Epoch 396 in 2.32 sec
# Epoch 397 in 2.36 sec
# Epoch 398 in 2.37 sec
# Epoch 399 in 2.34 sec
# Epoch 400 in 2.32 sec
# Epoch 401 in 2.33 sec
# Epoch 402 in 2.31 sec
# Epoch 403 in 2.39 sec
# Epoch 404 in 2.36 sec
# Epoch 405 in 2.35 sec
# Epoch 406 in 2.27 sec
# Epoch 407 in 2.25 sec
# Epoch 408 in 2.26 sec
# Epoch 409 in 2.25 sec
# Epoch 410 in 2.28 sec
# Epoch 411 in 2.35 sec
# Epoch 412 in 2.31 sec
# Epoch 413 in 2.29 sec
# Epoch 414 in 2.29 sec
# Epoch 415 in 2.27 sec
# Epoch 416 in 2.31 sec
# Epoch 417 in 2.31 sec
# Epoch 418 in 2.30 sec
# Epoch 419 in 2.33 sec
# Epoch 420 in 2.31 sec
# Epoch 421 in 2.31 sec
# Epoch 422 in 2.34 sec
# Epoch 423 in 2.35 sec
# Epoch 424 in 2.36 sec
# Epoch 425 in 2.36 sec
# Epoch 426 in 2.35 sec
# Epoch 427 in 2.35 sec
# Epoch 428 in 2.35 sec
# Epoch 429 in 2.35 sec
# Epoch 430 in 2.34 sec
# Epoch 431 in 2.35 sec
# Epoch 432 in 2.35 sec
# Epoch 433 in 2.35 sec
# Epoch 434 in 2.35 sec
# Epoch 435 in 2.35 sec
# Epoch 436 in 2.35 sec
# Epoch 437 in 2.35 sec
# Epoch 438 in 2.35 sec
# Epoch 439 in 2.34 sec
# Epoch 440 in 2.35 sec
# Epoch 441 in 2.34 sec
# Epoch 442 in 2.35 sec
# Epoch 443 in 2.35 sec
# Epoch 444 in 2.34 sec
# Epoch 445 in 2.33 sec
# Epoch 446 in 2.34 sec
# Epoch 447 in 2.33 sec
# Epoch 448 in 2.33 sec
# Epoch 449 in 2.33 sec
# Epoch 450 in 2.34 sec
# Epoch 451 in 2.32 sec
# Epoch 452 in 2.32 sec
# Epoch 453 in 2.32 sec
# Epoch 454 in 2.30 sec
# Epoch 455 in 2.31 sec
# Epoch 456 in 2.30 sec
# Epoch 457 in 2.33 sec
# Epoch 458 in 2.35 sec
# Epoch 459 in 2.34 sec
# Epoch 460 in 2.34 sec
# Epoch 461 in 2.36 sec
# Epoch 462 in 2.36 sec
# Epoch 463 in 2.34 sec
# Epoch 464 in 2.34 sec
# Epoch 465 in 2.30 sec
# Epoch 466 in 2.32 sec
# Epoch 467 in 2.41 sec
# Epoch 468 in 2.35 sec
# Epoch 469 in 2.33 sec
# Epoch 470 in 2.34 sec
# Epoch 471 in 2.33 sec
# Epoch 472 in 2.34 sec
# Epoch 473 in 2.40 sec
# Epoch 474 in 2.43 sec
# Epoch 475 in 2.38 sec
# Epoch 476 in 2.34 sec
# Epoch 477 in 2.34 sec
# Epoch 478 in 2.29 sec
# Epoch 479 in 2.29 sec
# Epoch 480 in 2.34 sec
# Epoch 481 in 2.29 sec
# Epoch 482 in 2.28 sec
# Epoch 483 in 2.23 sec
# Epoch 484 in 2.25 sec
# Epoch 485 in 2.27 sec
# Epoch 486 in 2.27 sec
# Epoch 487 in 2.30 sec
# Epoch 488 in 2.35 sec
# Epoch 489 in 2.31 sec
# Epoch 490 in 2.33 sec
# Epoch 491 in 2.30 sec
# Epoch 492 in 2.23 sec
# Epoch 493 in 2.23 sec
# Epoch 494 in 2.20 sec
# Epoch 495 in 2.22 sec
# Epoch 496 in 2.18 sec
# Epoch 497 in 2.12 sec
# Epoch 498 in 2.19 sec
# Epoch 499 in 2.15 sec

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.plot(loss_train_all, label="Calibration period")
ax.plot(loss_test_all, label="Test period")
ax.legend()

# %% [markdown]
# # LSTM

# %% [markdown]
# ## Create dataset and dataloader

# %%
n_step_lstm = 12  # 6hr

y_lstm, y_test_lstm = y[n_step_lstm - 1 : -1], y_test[n_step_lstm - 1 : -1]

# Reorganize the data to be fitted into the LSTM model
x_norm_lstm = np.array(
    [x_norm[i : i + n_step_lstm, :] for i in range(n_time - n_step_lstm)]
)
y_norm_lstm = np.array(y_norm[n_step_lstm - 1 : -1, :])
x_test_norm_lstm = np.array(
    [x_test_norm[i : i + n_step_lstm, :] for i in range(n_time_test - n_step_lstm)]
)
y_test_norm_lstm = np.array(y_test_norm[n_step_lstm - 1 : -1, :])

# %%
# train_dataset = CustomDataset(x_norm, y_norm)
# test_dataset = CustomDataset(x_test_norm, y_test_norm)
train_lstm_dataset = CustomDataset(np.array(x_norm_lstm), np.array(y_norm_lstm))
test_lstm_dataset = CustomDataset(
    np.array(x_test_norm_lstm), np.array(y_test_norm_lstm)
)
trainloader_lstm = torch.utils.data.DataLoader(
    train_lstm_dataset, batch_size=batch_size, shuffle=True
)
testloader_lstm = torch.utils.data.DataLoader(
    test_lstm_dataset, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# ## Train a LSTM model

# %%
class LSTM(eqx.Module):
    # cell_layers: List[eqx.nn.LSTMCell]
    cell_layer: eqx.nn.LSTMCell
    output_layer: eqx.nn.MLP

    def __init__(self, input_size, hidden_size, output_size, key):
        # self.cell_layers = [eqx.nn.LSTMCell(input_size, hidden_size) for i in range(n_cell)]
        self.cell_layer = eqx.nn.LSTMCell(input_size, hidden_size, key=key)
        self.output_layer = eqx.nn.MLP(
            hidden_size,
            output_size,
            int((hidden_size + output_size) / 2),
            1,
            activation=jax.nn.tanh,
            key=key,
        )

    def __call__(self, xs):
        scan_fn = lambda state, input: (self.cell_layer(input, state), None)
        init_state = (
            jnp.zeros(self.cell_layer.hidden_size),
            jnp.zeros(self.cell_layer.hidden_size),
        )
        final_state, _ = jax.lax.scan(scan_fn, init_state, xs)
        hidden_state = final_state[0]
        output = self.output_layer(hidden_state)
        return output

# %%
n_input, n_output, n_hidden = x.shape[-1], y.shape[-1], 10
model2 = LSTM(n_input, n_hidden, n_output, key)

# %%
# Training setup
scheduler = optax.piecewise_constant_schedule(
    initial_lr, boundaries_and_scales={50: 0.1, 100: 0.1, 200: 0.1}
)
# scheduler = optax.constant_schedule(initial_lr)
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer

# %%
# Loss function
@eqx.filter_jit
def loss_func(model, x_batch, y_batch):
    pred_y_batch = jax.vmap(model)(x_batch)
    return jnp.mean((y_batch - pred_y_batch) ** 2)

# %%
opt_state = optim.init(eqx.filter(model2, eqx.is_array))


@eqx.filter_jit
def make_step(model, opt_state, x_batch, y_batch):
    loss_value, grads = eqx.filter_value_and_grad(loss_func)(model, x_batch, y_batch)
    updates, opt_state = optim.update(grads, opt_state, model)
    model = eqx.apply_updates(model, updates)
    return model, opt_state, loss_value


loss_lstm_train_all = []
loss_lstm_test_all = []
for step in range(nsteps):
    start_time = time.time()
    for x_batch_tensor, y_batch_tensor in trainloader_lstm:
        x_batch, y_batch = jnp.array(x_batch_tensor), jnp.array(y_batch_tensor)
        model2, opt_state, loss_batch = make_step(model2, opt_state, x_batch, y_batch)
    epoch_time = time.time() - start_time

    loss_train = loss_func(model2, x_norm_lstm, y_norm_lstm)
    loss_test = loss_func(model2, x_test_norm_lstm, y_test_norm_lstm)
    loss_lstm_train_all.append(loss_train)
    loss_lstm_test_all.append(loss_test)
    print("Epoch {} in {:0.2f} sec".format(step, epoch_time))
# Out:
# Epoch 0 in 4.32 sec
# Epoch 1 in 2.90 sec
# Epoch 2 in 2.84 sec
# Epoch 3 in 2.84 sec
# Epoch 4 in 2.85 sec
# Epoch 5 in 2.86 sec
# Epoch 6 in 2.90 sec
# Epoch 7 in 2.89 sec
# Epoch 8 in 2.87 sec
# Epoch 9 in 2.88 sec
# Epoch 10 in 2.88 sec
# Epoch 11 in 2.84 sec
# Epoch 12 in 2.69 sec
# Epoch 13 in 2.69 sec
# Epoch 14 in 2.83 sec
# Epoch 15 in 2.86 sec
# Epoch 16 in 2.89 sec
# Epoch 17 in 2.86 sec
# Epoch 18 in 2.90 sec
# Epoch 19 in 2.85 sec
# Epoch 20 in 2.78 sec
# Epoch 21 in 2.81 sec
# Epoch 22 in 2.79 sec
# Epoch 23 in 2.78 sec
# Epoch 24 in 2.82 sec
# Epoch 25 in 2.86 sec
# Epoch 26 in 2.83 sec
# Epoch 27 in 2.86 sec
# Epoch 28 in 2.85 sec
# Epoch 29 in 2.83 sec
# Epoch 30 in 2.84 sec
# Epoch 31 in 2.87 sec
# Epoch 32 in 2.83 sec
# Epoch 33 in 2.86 sec
# Epoch 34 in 2.87 sec
# Epoch 35 in 2.87 sec
# Epoch 36 in 2.92 sec
# Epoch 37 in 2.89 sec
# Epoch 38 in 2.90 sec
# Epoch 39 in 2.92 sec
# Epoch 40 in 2.91 sec
# Epoch 41 in 2.82 sec
# Epoch 42 in 2.82 sec
# Epoch 43 in 2.83 sec
# Epoch 44 in 2.78 sec
# Epoch 45 in 2.74 sec
# Epoch 46 in 2.81 sec
# Epoch 47 in 2.80 sec
# Epoch 48 in 2.81 sec
# Epoch 49 in 2.80 sec
# Epoch 50 in 2.81 sec
# Epoch 51 in 2.72 sec
# Epoch 52 in 2.72 sec
# Epoch 53 in 2.76 sec
# Epoch 54 in 2.93 sec
# Epoch 55 in 2.78 sec
# Epoch 56 in 2.74 sec
# Epoch 57 in 2.71 sec
# Epoch 58 in 2.73 sec
# Epoch 59 in 2.81 sec
# Epoch 60 in 2.81 sec
# Epoch 61 in 2.80 sec
# Epoch 62 in 2.72 sec
# Epoch 63 in 2.77 sec
# Epoch 64 in 2.79 sec
# Epoch 65 in 2.76 sec
# Epoch 66 in 2.74 sec
# Epoch 67 in 2.80 sec
# Epoch 68 in 2.72 sec
# Epoch 69 in 2.77 sec
# Epoch 70 in 2.85 sec
# Epoch 71 in 2.95 sec
# Epoch 72 in 2.80 sec
# Epoch 73 in 2.82 sec
# Epoch 74 in 2.82 sec
# Epoch 75 in 2.81 sec
# Epoch 76 in 2.82 sec
# Epoch 77 in 2.82 sec
# Epoch 78 in 2.81 sec
# Epoch 79 in 2.83 sec
# Epoch 80 in 2.81 sec
# Epoch 81 in 2.80 sec
# Epoch 82 in 2.82 sec
# Epoch 83 in 2.76 sec
# Epoch 84 in 2.82 sec
# Epoch 85 in 2.81 sec
# Epoch 86 in 2.95 sec
# Epoch 87 in 2.91 sec
# Epoch 88 in 2.93 sec
# Epoch 89 in 2.96 sec
# Epoch 90 in 2.97 sec
# Epoch 91 in 2.97 sec
# Epoch 92 in 2.94 sec
# Epoch 93 in 2.90 sec
# Epoch 94 in 2.87 sec
# Epoch 95 in 2.88 sec
# Epoch 96 in 2.89 sec
# Epoch 97 in 2.94 sec
# Epoch 98 in 2.92 sec
# Epoch 99 in 2.83 sec
# Epoch 100 in 2.79 sec
# Epoch 101 in 2.89 sec
# Epoch 102 in 2.84 sec
# Epoch 103 in 2.76 sec
# Epoch 104 in 2.76 sec
# Epoch 105 in 2.76 sec
# Epoch 106 in 2.80 sec
# Epoch 107 in 2.85 sec
# Epoch 108 in 2.81 sec
# Epoch 109 in 2.86 sec
# Epoch 110 in 2.82 sec
# Epoch 111 in 2.86 sec
# Epoch 112 in 2.89 sec
# Epoch 113 in 2.81 sec
# Epoch 114 in 2.83 sec
# Epoch 115 in 2.81 sec
# Epoch 116 in 2.83 sec
# Epoch 117 in 2.80 sec
# Epoch 118 in 2.79 sec
# Epoch 119 in 2.77 sec
# Epoch 120 in 2.77 sec
# Epoch 121 in 2.80 sec
# Epoch 122 in 2.78 sec
# Epoch 123 in 2.82 sec
# Epoch 124 in 2.79 sec
# Epoch 125 in 2.80 sec
# Epoch 126 in 2.85 sec
# Epoch 127 in 2.84 sec
# Epoch 128 in 2.76 sec
# Epoch 129 in 2.82 sec
# Epoch 130 in 2.83 sec
# Epoch 131 in 2.81 sec
# Epoch 132 in 2.72 sec
# Epoch 133 in 2.68 sec
# Epoch 134 in 2.79 sec
# Epoch 135 in 2.74 sec
# Epoch 136 in 2.80 sec
# Epoch 137 in 2.82 sec
# Epoch 138 in 2.80 sec
# Epoch 139 in 2.81 sec
# Epoch 140 in 2.80 sec
# Epoch 141 in 2.83 sec
# Epoch 142 in 2.79 sec
# Epoch 143 in 2.76 sec
# Epoch 144 in 2.78 sec
# Epoch 145 in 2.81 sec
# Epoch 146 in 2.79 sec
# Epoch 147 in 2.85 sec
# Epoch 148 in 2.84 sec
# Epoch 149 in 2.84 sec
# Epoch 150 in 2.84 sec
# Epoch 151 in 2.84 sec
# Epoch 152 in 2.84 sec
# Epoch 153 in 2.84 sec
# Epoch 154 in 2.85 sec
# Epoch 155 in 2.84 sec
# Epoch 156 in 2.88 sec
# Epoch 157 in 2.86 sec
# Epoch 158 in 2.90 sec
# Epoch 159 in 2.90 sec
# Epoch 160 in 2.90 sec
# Epoch 161 in 2.90 sec
# Epoch 162 in 2.90 sec
# Epoch 163 in 2.87 sec
# Epoch 164 in 2.87 sec
# Epoch 165 in 2.92 sec
# Epoch 166 in 2.96 sec
# Epoch 167 in 2.86 sec
# Epoch 168 in 2.86 sec
# Epoch 169 in 2.91 sec
# Epoch 170 in 2.77 sec
# Epoch 171 in 2.53 sec
# Epoch 172 in 2.53 sec
# Epoch 173 in 2.65 sec
# Epoch 174 in 2.60 sec
# Epoch 175 in 2.65 sec
# Epoch 176 in 2.58 sec
# Epoch 177 in 2.59 sec
# Epoch 178 in 2.75 sec
# Epoch 179 in 2.77 sec
# Epoch 180 in 2.80 sec
# Epoch 181 in 2.84 sec
# Epoch 182 in 2.81 sec
# Epoch 183 in 2.81 sec
# Epoch 184 in 2.83 sec
# Epoch 185 in 2.84 sec
# Epoch 186 in 2.92 sec
# Epoch 187 in 2.74 sec
# Epoch 188 in 2.65 sec
# Epoch 189 in 2.75 sec
# Epoch 190 in 2.72 sec
# Epoch 191 in 2.88 sec
# Epoch 192 in 2.71 sec
# Epoch 193 in 2.62 sec
# Epoch 194 in 2.63 sec
# Epoch 195 in 2.72 sec
# Epoch 196 in 2.75 sec
# Epoch 197 in 2.71 sec
# Epoch 198 in 2.77 sec
# Epoch 199 in 2.66 sec
# Epoch 200 in 2.69 sec
# Epoch 201 in 2.72 sec
# Epoch 202 in 2.87 sec
# Epoch 203 in 2.79 sec
# Epoch 204 in 2.81 sec
# Epoch 205 in 2.73 sec
# Epoch 206 in 2.72 sec
# Epoch 207 in 2.79 sec
# Epoch 208 in 2.64 sec
# Epoch 209 in 2.63 sec
# Epoch 210 in 2.67 sec
# Epoch 211 in 2.72 sec
# Epoch 212 in 2.72 sec
# Epoch 213 in 2.85 sec
# Epoch 214 in 2.77 sec
# Epoch 215 in 2.65 sec
# Epoch 216 in 2.71 sec
# Epoch 217 in 2.73 sec
# Epoch 218 in 2.66 sec
# Epoch 219 in 2.80 sec
# Epoch 220 in 2.78 sec
# Epoch 221 in 2.75 sec
# Epoch 222 in 2.74 sec
# Epoch 223 in 2.75 sec
# Epoch 224 in 2.76 sec
# Epoch 225 in 2.77 sec
# Epoch 226 in 2.79 sec
# Epoch 227 in 2.74 sec
# Epoch 228 in 2.78 sec
# Epoch 229 in 2.72 sec
# Epoch 230 in 2.69 sec
# Epoch 231 in 2.69 sec
# Epoch 232 in 2.74 sec
# Epoch 233 in 2.75 sec
# Epoch 234 in 2.73 sec
# Epoch 235 in 2.77 sec
# Epoch 236 in 2.76 sec
# Epoch 237 in 2.82 sec
# Epoch 238 in 2.82 sec
# Epoch 239 in 2.82 sec
# Epoch 240 in 2.80 sec
# Epoch 241 in 2.78 sec
# Epoch 242 in 2.76 sec
# Epoch 243 in 2.79 sec
# Epoch 244 in 2.86 sec
# Epoch 245 in 2.85 sec
# Epoch 246 in 2.80 sec
# Epoch 247 in 2.87 sec
# Epoch 248 in 2.93 sec
# Epoch 249 in 2.98 sec
# Epoch 250 in 2.97 sec
# Epoch 251 in 2.93 sec
# Epoch 252 in 2.94 sec
# Epoch 253 in 2.91 sec
# Epoch 254 in 2.92 sec
# Epoch 255 in 2.90 sec
# Epoch 256 in 2.88 sec
# Epoch 257 in 2.83 sec
# Epoch 258 in 2.82 sec
# Epoch 259 in 2.83 sec
# Epoch 260 in 2.85 sec
# Epoch 261 in 2.85 sec
# Epoch 262 in 2.84 sec
# Epoch 263 in 2.85 sec
# Epoch 264 in 2.90 sec
# Epoch 265 in 2.85 sec
# Epoch 266 in 2.92 sec
# Epoch 267 in 2.94 sec
# Epoch 268 in 2.88 sec
# Epoch 269 in 2.80 sec
# Epoch 270 in 2.80 sec
# Epoch 271 in 2.72 sec
# Epoch 272 in 2.80 sec
# Epoch 273 in 2.79 sec
# Epoch 274 in 2.80 sec
# Epoch 275 in 2.76 sec
# Epoch 276 in 2.78 sec
# Epoch 277 in 2.74 sec
# Epoch 278 in 2.74 sec
# Epoch 279 in 2.70 sec
# Epoch 280 in 2.70 sec
# Epoch 281 in 2.77 sec
# Epoch 282 in 2.71 sec
# Epoch 283 in 2.72 sec
# Epoch 284 in 2.72 sec
# Epoch 285 in 2.75 sec
# Epoch 286 in 2.74 sec
# Epoch 287 in 2.77 sec
# Epoch 288 in 2.68 sec
# Epoch 289 in 2.64 sec
# Epoch 290 in 2.73 sec
# Epoch 291 in 2.74 sec
# Epoch 292 in 2.75 sec
# Epoch 293 in 2.72 sec
# Epoch 294 in 2.76 sec
# Epoch 295 in 2.74 sec
# Epoch 296 in 2.75 sec
# Epoch 297 in 2.69 sec
# Epoch 298 in 2.63 sec
# Epoch 299 in 2.64 sec
# Epoch 300 in 2.65 sec
# Epoch 301 in 2.66 sec
# Epoch 302 in 2.67 sec
# Epoch 303 in 2.71 sec
# Epoch 304 in 2.66 sec
# Epoch 305 in 2.68 sec
# Epoch 306 in 2.61 sec
# Epoch 307 in 2.57 sec
# Epoch 308 in 2.58 sec
# Epoch 309 in 2.59 sec
# Epoch 310 in 2.61 sec
# Epoch 311 in 2.65 sec
# Epoch 312 in 2.60 sec
# Epoch 313 in 2.60 sec
# Epoch 314 in 2.62 sec
# Epoch 315 in 2.62 sec
# Epoch 316 in 2.62 sec
# Epoch 317 in 2.68 sec
# Epoch 318 in 2.70 sec
# Epoch 319 in 2.68 sec
# Epoch 320 in 2.65 sec
# Epoch 321 in 2.80 sec
# Epoch 322 in 2.71 sec
# Epoch 323 in 2.69 sec
# Epoch 324 in 2.71 sec
# Epoch 325 in 2.70 sec
# Epoch 326 in 2.68 sec
# Epoch 327 in 2.68 sec
# Epoch 328 in 2.75 sec
# Epoch 329 in 2.67 sec
# Epoch 330 in 2.63 sec
# Epoch 331 in 2.70 sec
# Epoch 332 in 2.67 sec
# Epoch 333 in 2.69 sec
# Epoch 334 in 2.71 sec
# Epoch 335 in 2.66 sec
# Epoch 336 in 2.69 sec
# Epoch 337 in 2.68 sec
# Epoch 338 in 2.69 sec
# Epoch 339 in 2.73 sec
# Epoch 340 in 2.70 sec
# Epoch 341 in 2.66 sec
# Epoch 342 in 2.69 sec
# Epoch 343 in 2.74 sec
# Epoch 344 in 2.72 sec
# Epoch 345 in 2.74 sec
# Epoch 346 in 2.67 sec
# Epoch 347 in 2.69 sec
# Epoch 348 in 2.67 sec
# Epoch 349 in 2.66 sec
# Epoch 350 in 2.69 sec
# Epoch 351 in 2.60 sec
# Epoch 352 in 2.60 sec
# Epoch 353 in 2.70 sec
# Epoch 354 in 2.73 sec
# Epoch 355 in 2.73 sec
# Epoch 356 in 2.70 sec
# Epoch 357 in 2.71 sec
# Epoch 358 in 2.70 sec
# Epoch 359 in 2.72 sec
# Epoch 360 in 2.70 sec
# Epoch 361 in 2.70 sec
# Epoch 362 in 2.69 sec
# Epoch 363 in 2.69 sec
# Epoch 364 in 2.73 sec
# Epoch 365 in 2.74 sec
# Epoch 366 in 2.74 sec
# Epoch 367 in 2.75 sec
# Epoch 368 in 2.80 sec
# Epoch 369 in 2.86 sec
# Epoch 370 in 2.83 sec
# Epoch 371 in 2.77 sec
# Epoch 372 in 2.77 sec
# Epoch 373 in 2.75 sec
# Epoch 374 in 2.67 sec
# Epoch 375 in 2.71 sec
# Epoch 376 in 2.80 sec
# Epoch 377 in 2.75 sec
# Epoch 378 in 2.70 sec
# Epoch 379 in 2.72 sec
# Epoch 380 in 2.71 sec
# Epoch 381 in 2.71 sec
# Epoch 382 in 2.65 sec
# Epoch 383 in 2.74 sec
# Epoch 384 in 2.70 sec
# Epoch 385 in 2.72 sec
# Epoch 386 in 2.85 sec
# Epoch 387 in 2.74 sec
# Epoch 388 in 2.68 sec
# Epoch 389 in 2.66 sec
# Epoch 390 in 2.75 sec
# Epoch 391 in 2.75 sec
# Epoch 392 in 2.77 sec
# Epoch 393 in 2.78 sec
# Epoch 394 in 2.77 sec
# Epoch 395 in 2.77 sec
# Epoch 396 in 2.75 sec
# Epoch 397 in 2.73 sec
# Epoch 398 in 2.78 sec
# Epoch 399 in 2.80 sec
# Epoch 400 in 2.79 sec
# Epoch 401 in 2.77 sec
# Epoch 402 in 2.81 sec
# Epoch 403 in 2.78 sec
# Epoch 404 in 2.77 sec
# Epoch 405 in 2.80 sec
# Epoch 406 in 2.70 sec
# Epoch 407 in 2.73 sec
# Epoch 408 in 2.81 sec
# Epoch 409 in 2.89 sec
# Epoch 410 in 2.86 sec
# Epoch 411 in 2.91 sec
# Epoch 412 in 2.85 sec
# Epoch 413 in 2.86 sec
# Epoch 414 in 2.79 sec
# Epoch 415 in 2.83 sec
# Epoch 416 in 2.82 sec
# Epoch 417 in 2.82 sec
# Epoch 418 in 2.84 sec
# Epoch 419 in 2.81 sec
# Epoch 420 in 2.84 sec
# Epoch 421 in 2.71 sec
# Epoch 422 in 2.64 sec
# Epoch 423 in 2.63 sec
# Epoch 424 in 2.68 sec
# Epoch 425 in 2.72 sec
# Epoch 426 in 2.77 sec
# Epoch 427 in 2.77 sec
# Epoch 428 in 2.77 sec
# Epoch 429 in 2.76 sec
# Epoch 430 in 2.79 sec
# Epoch 431 in 2.77 sec
# Epoch 432 in 2.64 sec
# Epoch 433 in 2.67 sec
# Epoch 434 in 2.74 sec
# Epoch 435 in 2.80 sec
# Epoch 436 in 2.80 sec
# Epoch 437 in 2.74 sec
# Epoch 438 in 2.67 sec
# Epoch 439 in 2.76 sec
# Epoch 440 in 2.77 sec
# Epoch 441 in 2.79 sec
# Epoch 442 in 2.76 sec
# Epoch 443 in 2.76 sec
# Epoch 444 in 2.77 sec
# Epoch 445 in 2.82 sec
# Epoch 446 in 2.78 sec
# Epoch 447 in 2.78 sec
# Epoch 448 in 2.77 sec
# Epoch 449 in 2.77 sec
# Epoch 450 in 2.81 sec
# Epoch 451 in 2.86 sec
# Epoch 452 in 2.89 sec
# Epoch 453 in 2.86 sec
# Epoch 454 in 2.87 sec
# Epoch 455 in 2.71 sec
# Epoch 456 in 2.72 sec
# Epoch 457 in 2.64 sec
# Epoch 458 in 2.69 sec
# Epoch 459 in 2.77 sec
# Epoch 460 in 2.70 sec
# Epoch 461 in 2.66 sec
# Epoch 462 in 2.68 sec
# Epoch 463 in 2.73 sec
# Epoch 464 in 2.68 sec
# Epoch 465 in 2.72 sec
# Epoch 466 in 2.84 sec
# Epoch 467 in 2.77 sec
# Epoch 468 in 2.71 sec
# Epoch 469 in 2.78 sec
# Epoch 470 in 2.80 sec
# Epoch 471 in 2.74 sec
# Epoch 472 in 2.77 sec
# Epoch 473 in 2.77 sec
# Epoch 474 in 2.87 sec
# Epoch 475 in 2.84 sec
# Epoch 476 in 2.85 sec
# Epoch 477 in 2.68 sec
# Epoch 478 in 2.77 sec
# Epoch 479 in 2.70 sec
# Epoch 480 in 2.72 sec
# Epoch 481 in 2.71 sec
# Epoch 482 in 2.72 sec
# Epoch 483 in 2.76 sec
# Epoch 484 in 2.73 sec
# Epoch 485 in 2.72 sec
# Epoch 486 in 2.72 sec
# Epoch 487 in 2.70 sec
# Epoch 488 in 2.70 sec
# Epoch 489 in 2.72 sec
# Epoch 490 in 2.72 sec
# Epoch 491 in 2.73 sec
# Epoch 492 in 2.69 sec
# Epoch 493 in 2.72 sec
# Epoch 494 in 2.75 sec
# Epoch 495 in 2.74 sec
# Epoch 496 in 2.70 sec
# Epoch 497 in 2.73 sec
# Epoch 498 in 2.67 sec
# Epoch 499 in 2.72 sec

# %% [markdown]
# # Predictions on both training and test datasets

# %%
def l2_func(y, y_true):
    return np.mean((y - y_true) ** 2)

# %%
# Sensitivity analysis
def model_scaler(x, model):
    return model(x)[0]

# %% [markdown]
# ## MLP

# %% [markdown]
# ### Sensitivity analysis

# %%
grad = jax.vmap(jax.grad(model_scaler), in_axes=[0, None])(x_norm, model)
grad_test = jax.vmap(jax.grad(model_scaler), in_axes=[0, None])(x_test_norm, model)

# %%
# fig, axes = plt.subplots(len(varns), 1, figsize = (20, 20))
# for i,ax in enumerate(axes):
#     ax.plot(grad[:,i])
#     ax.set(ylabel=varns[i])
# # grad.mean(axis=0), grad_test.mean(axis=0)

# %%
# fig, axes = plt.subplots(len(varns), 1, figsize = (20, 20))
# for i,ax in enumerate(axes):
#     ax.plot(grad_test[:,i])
#     ax.set(ylabel=varns[i])
# # grad.mean(axis=0), grad_test.mean(axis=0)

# %% [markdown]
# ### Predictions

# %%
pred_y_norm_calib = jax.vmap(model)(x_norm)
pred_y_norm_test = jax.vmap(model)(x_test_norm)

pred_y_calib = scaler_y.inverse_transform(pred_y_norm_calib)
pred_y_test = scaler_y.inverse_transform(pred_y_norm_test)

l2_calib = l2_func(pred_y_calib, y)
l2_test = l2_func(pred_y_test, y_test)

# %%
metrics = compute_metrics(pred_y_calib, y)
metrics_test = compute_metrics(pred_y_test, y_test)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 28.349907269718756, 'mse': 803.7172422016523, 'r2': 0.9251032031011316, 'kge': 0.9526770694478446, 'nse': 0.9296527757409181, 'mkge': 0.9510797854231168, 'cc': 0.9641991521063058, 'alpha': 1.0024809311741636, 'beta': 0.966753471386475}
# {'rmse': 36.97749914778819, 'mse': 1367.335443224676, 'r2': 0.8420810402406669, 'kge': 0.8178300520241519, 'nse': 0.8854806091911923, 'mkge': 0.8773328189180701, 'cc': 0.947709741766055, 'alpha': 0.9082321838502797, 'beta': 0.9376170365602479}

# %%
plot_timeseries_obs_1to1(
    y,
    pred_y_calib,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2], Test period",
)

plot_timeseries_obs_1to1(
    y_test,
    pred_y_test,
    lim=[-100, 1000],
    met=met_test,
    varn="Latent heat fluxes [W m-2], Test period",
);

# %%
# fig, axes = plt.subplots(2, 1, figsize=(12, 8))
# ax = axes[0]
# ax.plot(timesteps, y, label="obs")
# ax.plot(timesteps, pred_y_calib, label="DNN")
# ax.set(
#     title=f"Calibration period (L2: {l2_calib})", ylabel="Latent heat fluxes [W m-2]"
# )
# ax.legend()

# ax = axes[1]
# ax.plot(timesteps_test, y_test, label="obs")
# ax.plot(timesteps_test, pred_y_test, label="DNN")
# ax.set(title=f"Test period (L2: {l2_test})", ylabel="Latent heat fluxes [W m-2]")
# ax.legend()

# %% [markdown]
# ### Save the predictions

# %%
import pickle

train = {"time": timesteps, "LE": pred_y_calib.flatten()}
test = {"time": timesteps_test, "LE": pred_y_test.flatten()}
out = {"train": train, "test": test}
pickle.dump(out, open(f"{site}_{key}.pkl", "wb"), pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## LSTM

# %%
pred_y_norm_lstm_calib = jax.vmap(model2)(x_norm_lstm)
pred_y_norm_lstm_test = jax.vmap(model2)(x_test_norm_lstm)

pred_y_lstm_calib = scaler_y.inverse_transform(pred_y_norm_lstm_calib)
pred_y_lstm_test = scaler_y.inverse_transform(pred_y_norm_lstm_test)

l2_calib_lstm = l2_func(pred_y_lstm_calib, y_lstm)
l2_test_lstm = l2_func(pred_y_lstm_test, y_test_lstm)

# %%
fig, ax1, ax2 = plot_timeseries_obs_1to1(
    y_lstm,
    pred_y_lstm_calib,
    lim=[-150, 350],
    met=met,
    varn="Latent heat fluxes [W m-2]",
    # linestyle=".",
)
# ax1.set(ylabel="[W m-2]")
# ax12 = ax1.twinx()
# ax12.invert_yaxis()
# ax12.plot(timesteps_test, obs_test.P, "k")
# ax12.set(ylim=[10, 0], ylabel="Rainfall [mm]")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb Cell 43 line 1
# ----> <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> fig, ax1, ax2 = plot_timeseries_obs_1to1(
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a>     y_lstm,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a>     pred_y_lstm_calib,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a>     lim=[-150, 350],
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=4'>5</a>     met=met,
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=5'>6</a>     varn="Latent heat fluxes [W m-2]",
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=6'>7</a>     # linestyle=".",
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=7'>8</a> )
#       <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=8'>9</a> # ax1.set(ylabel="[W m-2]")
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=9'>10</a> # ax12 = ax1.twinx()
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=10'>11</a> # ax12.invert_yaxis()
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=11'>12</a> # ax12.plot(timesteps_test, obs_test.P, "k")
#      <a href='vscode-notebook-cell:/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/examples/dnn_US-Hn1.ipynb#Y106sZmlsZQ%3D%3D?line=12'>13</a> # ax12.set(ylim=[10, 0], ylabel="Rainfall [mm]")
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/plot.py:224, in plot_timeseries_obs_1to1(obs, sim, lim, met, timesteps, varn, axes, linestyle)
#     222 if met is not None:
#     223     timesteps = get_time(met)
# --> 224 plot_timeseries(
#     225     obs,
#     226     timesteps=timesteps,
#     227     ax=ax1,
#     228     title=None,
#     229     label="observation",
#     230     tunit="",
#     231     linestyle=linestyle,
#     232 )
#     233 plot_timeseries(
#     234     sim,
#     235     timesteps=timesteps,
#    (...)
#     241     linestyle=linestyle,
#     242 )
#     243 ax1.legend()
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src/jax_canoak/shared_utilities/plot.py:51, in plot_timeseries(array, timesteps, ax, title, label, tunit, alpha, xticks, linestyle)
#      49     ax.plot(array, linestyle, label=label, alpha=alpha, markersize=3)
#      50 else:
# ---> 51     ax.plot(timesteps, array, linestyle, label=label, alpha=alpha, markersize=3)
#      52 if xticks is None:
#      53     ax.set(
#      54         xlabel=f"Time {tunit}",
#      55         title=title,
#      56         xlim=[timesteps[0], timesteps[-1]] if timesteps is not None else None,
#      57     )
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/jax-watershed/lib/python3.10/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (18960,) and (18948, 1)

# %%
fig, ax1, ax2 = plot_timeseries_obs_1to1(
    y_test_lstm,
    pred_y_lstm_test,
    lim=[-150, 350],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
    # linestyle=".",
)
ax1.set(ylabel="[W m-2]")
ax12 = ax1.twinx()
ax12.invert_yaxis()
ax12.plot(timesteps_test[n_step_lstm - 1 : -1], obs_test.P, "k")
ax12.set(ylim=[10, 0], ylabel="Rainfall [mm]")


ax = axes[1]
ax.plot(timesteps_test[n_step_lstm - 1 : -1], y_test_lstm, label="obs")
ax.plot(timesteps_test[n_step_lstm - 1 : -1], pred_y_lstm_test, label="DNN")
ax.set(title=f"Test period (L2: {l2_test_lstm})", ylabel="Latent heat fluxes [W m-2]")
ax.legend()

# %% [markdown]
# ## Plot

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 8))
ax = axes[0]
ax.plot(timesteps, y, label="obs")
ax.plot(timesteps, pred_y_calib, label="DNN")
ax.set(
    title=f"Calibration period (L2: {l2_calib})", ylabel="Latent heat fluxes [W m-2]"
)
ax.legend()

ax = axes[1]
ax.plot(timesteps_test, y_test, label="obs")
ax.plot(timesteps_test, pred_y_test, label="DNN")
ax.set(title=f"Test period (L2: {l2_test})", ylabel="Latent heat fluxes [W m-2]")
ax.legend()
