# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# # TODO: A more generic way is needed here to load the path
# import sys

# sys.path.append(
#     "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
#     # "/global/homes/p/peishi89/jax-watershed/src"
# )

# %%
import time

from typing import List

import optax
import equinox as eqx

import torch
from torch.utils.data import Dataset, DataLoader

from sklearn import preprocessing

import numpy as np
import jax
import jax.numpy as jnp

from jax_canoak.subjects import get_met_forcings, get_obs
from jax_canoak.shared_utilities.plot import get_time
from jax_canoak.shared_utilities import compute_metrics

import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_timeseries_obs_1to1,
)

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_debug_nans", False)
jax.config.update("jax_debug_infs", False)

# %load_ext autoreload
# %autoreload 2

# %%
small_size = 15
medium_size = 25
bigger_size = 30
plt.rc("font", size=small_size)  # controls default text sizes
plt.rc("axes", titlesize=small_size)  # fontsize of the axes title
plt.rc("axes", labelsize=small_size)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=small_size)  # fontsize of the tick labels
plt.rc("ytick", labelsize=small_size)  # fontsize of the tick labels
plt.rc("legend", fontsize=small_size)  # legend fontsize
plt.rc("figure", titlesize=small_size)  # fontsize of the figure title
plt.rc("text", usetex=False)

# %% [markdown]
# # Files / directories / DL hyperparameters

# %%
site, key = "US-Bi1", "dl"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-test.csv"

# Models
f_model = f"{site}_{key}_model.eqx"

# %%
# Hyperparameters
batch_size = 64
# initial_lr = 2e-2
initial_lr = 2e-1
nsteps = 300
seed = 5678

key = jax.random.PRNGKey(seed)

# %% [markdown]
# # Load forcings and outputs

# %%
varns = [
    "T_air",
    "rglobal",
    "eair",
    "wind",
    "CO2",
    "P_kPa",
    "ustar",
    "soilmoisture",
    "lai",
]

# %%
# Calibration period
met, n_time = get_met_forcings(f_forcing)
timesteps = get_time(met)
obs = get_obs(f_obs)
x = np.array(
    [
        met.T_air,
        met.rglobal,
        met.eair,
        met.wind,
        met.CO2,
        met.P_kPa,
        met.ustar,
        met.soilmoisture,
        met.lai,
    ]
).T
y = obs.LE
y = np.expand_dims(y, axis=-1)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %%
# Test period
met_test, n_time_test = get_met_forcings(f_forcing_test)
timesteps_test = get_time(met_test)
obs_test = get_obs(f_obs_test)
x_test = np.array(
    [
        met_test.T_air,
        met_test.rglobal,
        met_test.eair,
        met_test.wind,
        met_test.CO2,
        met_test.P_kPa,
        met_test.ustar,
        met_test.soilmoisture,
        met_test.lai,
    ]
).T
y_test = obs_test.LE
y_test = np.expand_dims(y_test, axis=-1)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Normalize the data

# %%
scaler_x = preprocessing.StandardScaler().fit(x)
scaler_y = preprocessing.StandardScaler().fit(y)

# %%
x_norm = scaler_x.transform(x)
y_norm = scaler_y.transform(y)
x_test_norm = scaler_x.transform(x_test)
y_test_norm = scaler_y.transform(y_test)

# %%
scaler_y.var_
# Out:
# array([11425.00291471])

# %%
y.std()
# Out:
# 106.88780526658947

# %%
# x_norm = jax.nn.standardize(x,axis=0)
# y_norm = jax.nn.standardize(y,axis=0)
# x_test_norm = jax.nn.standardize(x_test,axis=0)
# y_test_norm = jax.nn.standardize(y_test,axis=0)

# %% [markdown]
# # MLP

# %%
# Ensure reproducibility
torch.manual_seed(14026282050284255032)

# %% [markdown]
# ## Create dataset and dataloader

# %%
class CustomDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        # Return the size of the dataset, which is the length of one of the arrays
        return len(self.x)

    def __getitem__(self, idx):
        # Retrieve and return the corresponding elements from both arrays
        sample1 = self.x[idx]
        sample2 = self.y[idx]
        return sample1, sample2

# %%
# train_dataset = CustomDataset(x_norm, y_norm)
# test_dataset = CustomDataset(x_test_norm, y_test_norm)
train_dataset = CustomDataset(np.array(x_norm), np.array(y_norm))
test_dataset = CustomDataset(np.array(x_test_norm), np.array(y_test_norm))
trainloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)
testloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# ## Train a MLP model

# %%
# Define a deep learning model
n_input, n_output = x.shape[1], y.shape[1]
n_depth, n_node = 6, 6

model = eqx.nn.MLP(
    n_input, n_output, n_depth, n_node, 
    # activation=jax.nn.tanh, key=key
    activation=jax.nn.leaky_relu, key=key
)

# %%
# Training setup
# scheduler = optax.piecewise_constant_schedule(
#     initial_lr, boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
# )
scheduler = optax.piecewise_constant_schedule(
    initial_lr, boundaries_and_scales={50: 0.1, 100: 0.1, 200: 0.1}
)
# scheduler = optax.constant_schedule(initial_lr)
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer

# %%
# Loss function
@eqx.filter_jit
def loss_func(model, x_batch, y_batch):
    pred_y_batch = jax.vmap(model)(x_batch)
    return jnp.mean((y_batch - pred_y_batch) ** 2)

# %%
opt_state = optim.init(eqx.filter(model, eqx.is_array))

@eqx.filter_jit
def make_step(model, opt_state, x_batch, y_batch):
    loss_value, grads = eqx.filter_value_and_grad(loss_func)(model, x_batch, y_batch)
    updates, opt_state = optim.update(grads, opt_state, model)
    model = eqx.apply_updates(model, updates)
    return model, opt_state, loss_value


loss_train_all = []
loss_test_all = []
for step in range(nsteps):
    start_time = time.time()
    for x_batch_tensor, y_batch_tensor in trainloader:
        x_batch, y_batch = jnp.array(x_batch_tensor), jnp.array(y_batch_tensor)
        model, opt_state, loss_batch = make_step(model, opt_state, x_batch, y_batch)
    epoch_time = time.time() - start_time

    loss_train = loss_func(model, x_norm, y_norm)
    loss_test = loss_func(model, x_test_norm, y_test_norm)
    
    # Rescale
    # loss_train = loss_train * scaler_y.var_
    # loss_test = loss_test * scaler_y.var_
    
    loss_train_all.append(loss_train)
    loss_test_all.append(loss_test)
    print(f"The training loss of step {step}: {loss_train}; the test loss of step {step}: {loss_test}.")
    # print("Epoch {} in {:0.2f} sec".format(step, epoch_time))
    # print("Training set loss: {}".format(loss_train))
    # print("Test set loss {}".format(loss_test))
# Out:
# The training loss of step 0: 0.30891872770525414; the test loss of step 0: 0.33440230348316885.
# The training loss of step 1: 0.2549278176157041; the test loss of step 1: 0.28068452445529973.
# The training loss of step 2: 0.21489988285315484; the test loss of step 2: 0.24163835425683336.
# The training loss of step 3: 0.18598615687069395; the test loss of step 3: 0.21216777106233387.
# The training loss of step 4: 0.16561346942634753; the test loss of step 4: 0.19111863986872857.
# The training loss of step 5: 0.15054715646584407; the test loss of step 5: 0.17525594976346878.
# The training loss of step 6: 0.1398297345920092; the test loss of step 6: 0.1642411627716232.
# The training loss of step 7: 0.13225465000672962; the test loss of step 7: 0.15627386301952417.
# The training loss of step 8: 0.12659704188212462; the test loss of step 8: 0.15001863466436266.
# The training loss of step 9: 0.12242967918081095; the test loss of step 9: 0.14507837495118311.
# The training loss of step 10: 0.11980023687902985; the test loss of step 10: 0.1422260849397833.
# The training loss of step 11: 0.11778954320099205; the test loss of step 11: 0.14018560330651175.
# The training loss of step 12: 0.11659905337416517; the test loss of step 12: 0.13850247934078683.
# The training loss of step 13: 0.11456006279560896; the test loss of step 13: 0.13610548268714942.
# The training loss of step 14: 0.1148868386602627; the test loss of step 14: 0.13567309793194593.
# The training loss of step 15: 0.1128243368116261; the test loss of step 15: 0.13505980340322613.
# The training loss of step 16: 0.11217200322693242; the test loss of step 16: 0.13386723213915983.
# The training loss of step 17: 0.11153154997927464; the test loss of step 17: 0.13357377258454936.
# The training loss of step 18: 0.11104810526494935; the test loss of step 18: 0.1330706782164317.
# The training loss of step 19: 0.11058915755417668; the test loss of step 19: 0.1327902083557725.
# The training loss of step 20: 0.11014973972521153; the test loss of step 20: 0.13375513309743017.
# The training loss of step 21: 0.11009939100617487; the test loss of step 21: 0.1323218508150651.
# The training loss of step 22: 0.1094171513395447; the test loss of step 22: 0.1331660786827677.
# The training loss of step 23: 0.1092989848955873; the test loss of step 23: 0.13422156320191406.
# The training loss of step 24: 0.10904705802378208; the test loss of step 24: 0.13220691196153353.
# The training loss of step 25: 0.10862370159138707; the test loss of step 25: 0.1328051787091531.
# The training loss of step 26: 0.10851308196578807; the test loss of step 26: 0.13386004464898535.
# The training loss of step 27: 0.10831864919676641; the test loss of step 27: 0.13366466796757145.
# The training loss of step 28: 0.10819508257999595; the test loss of step 28: 0.13446186553585804.
# The training loss of step 29: 0.10772005078556936; the test loss of step 29: 0.132707872521195.
# The training loss of step 30: 0.10757719154781749; the test loss of step 30: 0.13284349276967367.
# The training loss of step 31: 0.1078720081148135; the test loss of step 31: 0.1366934786782807.
# The training loss of step 32: 0.10747851366379983; the test loss of step 32: 0.13635593127558657.
# The training loss of step 33: 0.10663475639637461; the test loss of step 33: 0.13495019154543203.
# The training loss of step 34: 0.10656507730060925; the test loss of step 34: 0.13464927193196474.
# The training loss of step 35: 0.10683386975310007; the test loss of step 35: 0.1387295579022479.
# The training loss of step 36: 0.10601637008916569; the test loss of step 36: 0.1350635363095569.
# The training loss of step 37: 0.10594721194163438; the test loss of step 37: 0.13697628668226508.
# The training loss of step 38: 0.10568486695085287; the test loss of step 38: 0.13640219312524024.
# The training loss of step 39: 0.10546244215200533; the test loss of step 39: 0.13696683015473227.
# The training loss of step 40: 0.1055177747190056; the test loss of step 40: 0.138793045338626.
# The training loss of step 41: 0.10538271441135534; the test loss of step 41: 0.1385357799244322.
# The training loss of step 42: 0.10509863238656582; the test loss of step 42: 0.13615012094302048.
# The training loss of step 43: 0.10505876448035632; the test loss of step 43: 0.13472623554249416.
# The training loss of step 44: 0.10487791421253367; the test loss of step 44: 0.13544846286561818.
# The training loss of step 45: 0.10465553661251567; the test loss of step 45: 0.13621946700993381.
# The training loss of step 46: 0.104576800526665; the test loss of step 46: 0.13645232425408657.
# The training loss of step 47: 0.10448351271349307; the test loss of step 47: 0.13868552385000138.
# The training loss of step 48: 0.10510915614376716; the test loss of step 48: 0.14010392259663218.
# The training loss of step 49: 0.10465735220855528; the test loss of step 49: 0.1392188573479062.
# The training loss of step 50: 0.10407299184287205; the test loss of step 50: 0.1381700958859476.
# The training loss of step 51: 0.10385296603351055; the test loss of step 51: 0.13782767143964175.
# The training loss of step 52: 0.10502727108710183; the test loss of step 52: 0.1365675092069653.
# The training loss of step 53: 0.10370880790897535; the test loss of step 53: 0.13778948591936493.
# The training loss of step 54: 0.10397083150045146; the test loss of step 54: 0.13963977793783655.
# The training loss of step 55: 0.10359988143097563; the test loss of step 55: 0.1404273469874156.
# The training loss of step 56: 0.10376277522958427; the test loss of step 56: 0.14061282213570764.
# The training loss of step 57: 0.10336588924297924; the test loss of step 57: 0.13989906421424375.
# The training loss of step 58: 0.10343656000240876; the test loss of step 58: 0.1379708226393653.
# The training loss of step 59: 0.10325825887685725; the test loss of step 59: 0.13900287470207104.
# The training loss of step 60: 0.10305414157866018; the test loss of step 60: 0.13893924664466492.
# The training loss of step 61: 0.1029520036824576; the test loss of step 61: 0.13920713276134566.
# The training loss of step 62: 0.10292806097981995; the test loss of step 62: 0.1407712050072322.
# The training loss of step 63: 0.10299240521259903; the test loss of step 63: 0.13805866674412304.
# The training loss of step 64: 0.10275952953462768; the test loss of step 64: 0.1398271839768571.
# The training loss of step 65: 0.1027781731281993; the test loss of step 65: 0.1384081619799667.
# The training loss of step 66: 0.10264816289459018; the test loss of step 66: 0.13977914698011185.
# The training loss of step 67: 0.10260428064920046; the test loss of step 67: 0.14053025419239837.
# The training loss of step 68: 0.102639779975449; the test loss of step 68: 0.13934334039415044.
# The training loss of step 69: 0.10253742151896116; the test loss of step 69: 0.14242988967864598.
# The training loss of step 70: 0.10229741679486601; the test loss of step 70: 0.14042107690291455.
# The training loss of step 71: 0.10174961427710723; the test loss of step 71: 0.13462455720342792.
# The training loss of step 72: 0.0994887011508362; the test loss of step 72: 0.13165285245816397.
# The training loss of step 73: 0.09780314999531965; the test loss of step 73: 0.12868783946957207.
# The training loss of step 74: 0.09612036581052548; the test loss of step 74: 0.12944740896622517.
# The training loss of step 75: 0.0958642209373752; the test loss of step 75: 0.12471037811257453.
# The training loss of step 76: 0.09284913471497645; the test loss of step 76: 0.12375773976708619.
# The training loss of step 77: 0.0913625812881557; the test loss of step 77: 0.12400392533339513.
# The training loss of step 78: 0.0907976020954741; the test loss of step 78: 0.11915989802093212.
# The training loss of step 79: 0.0892152210311776; the test loss of step 79: 0.12132320186878892.
# The training loss of step 80: 0.08831563405480627; the test loss of step 80: 0.12292880862973886.
# The training loss of step 81: 0.08737994946433954; the test loss of step 81: 0.1258862311770974.
# The training loss of step 82: 0.08655579983537921; the test loss of step 82: 0.1215025793048205.
# The training loss of step 83: 0.08575403942776073; the test loss of step 83: 0.125288902944803.
# The training loss of step 84: 0.08549977076253293; the test loss of step 84: 0.1252616692445273.
# The training loss of step 85: 0.08457073968201834; the test loss of step 85: 0.12482842041237484.
# The training loss of step 86: 0.08385481111271624; the test loss of step 86: 0.12207730682814509.
# The training loss of step 87: 0.08332425236009024; the test loss of step 87: 0.12337120450688276.
# The training loss of step 88: 0.08298879015279342; the test loss of step 88: 0.12343653853326651.
# The training loss of step 89: 0.08255195787709163; the test loss of step 89: 0.12408323379589234.
# The training loss of step 90: 0.08222008043697028; the test loss of step 90: 0.12350330202697433.
# The training loss of step 91: 0.08179155538745911; the test loss of step 91: 0.12296121644932358.
# The training loss of step 92: 0.08148965262788667; the test loss of step 92: 0.12194078222433062.
# The training loss of step 93: 0.0812732825605149; the test loss of step 93: 0.12328623641973833.
# The training loss of step 94: 0.08089943889555862; the test loss of step 94: 0.12203976309680711.
# The training loss of step 95: 0.08060249750775006; the test loss of step 95: 0.11947537130569241.
# The training loss of step 96: 0.08047749419883776; the test loss of step 96: 0.12119460383462027.
# The training loss of step 97: 0.08000564543517394; the test loss of step 97: 0.1220863529814973.
# The training loss of step 98: 0.08006727548661025; the test loss of step 98: 0.12271505436062494.
# The training loss of step 99: 0.07958243895056016; the test loss of step 99: 0.1224259230145509.
# The training loss of step 100: 0.07956426953981345; the test loss of step 100: 0.12472381795577711.
# The training loss of step 101: 0.07908162774418381; the test loss of step 101: 0.12109933787261334.
# The training loss of step 102: 0.07917033797137506; the test loss of step 102: 0.12503997126089827.
# The training loss of step 103: 0.07894604634642367; the test loss of step 103: 0.11968225273860578.
# The training loss of step 104: 0.07898595182938468; the test loss of step 104: 0.11893122310322206.
# The training loss of step 105: 0.07838813199537441; the test loss of step 105: 0.12050141990682108.
# The training loss of step 106: 0.07821727688043317; the test loss of step 106: 0.12144237039478666.
# The training loss of step 107: 0.07814831806299072; the test loss of step 107: 0.12432722903415445.
# The training loss of step 108: 0.07796096557690164; the test loss of step 108: 0.12115771308086168.
# The training loss of step 109: 0.0778701547858962; the test loss of step 109: 0.1213111860164622.
# The training loss of step 110: 0.07761634364292583; the test loss of step 110: 0.12316208713376751.
# The training loss of step 111: 0.07763292770093823; the test loss of step 111: 0.12281972867336556.
# The training loss of step 112: 0.07737813152874813; the test loss of step 112: 0.12244990651805113.
# The training loss of step 113: 0.07726306781610431; the test loss of step 113: 0.1213966198404854.
# The training loss of step 114: 0.07723240105448552; the test loss of step 114: 0.12225619774024973.
# The training loss of step 115: 0.07706502371690281; the test loss of step 115: 0.12367676854952557.
# The training loss of step 116: 0.07703520048077044; the test loss of step 116: 0.12316654712770123.
# The training loss of step 117: 0.07685070557572884; the test loss of step 117: 0.12391008314769748.
# The training loss of step 118: 0.07692739258588945; the test loss of step 118: 0.12194745591478569.
# The training loss of step 119: 0.07655532259052088; the test loss of step 119: 0.12296259739074918.
# The training loss of step 120: 0.0766213340393051; the test loss of step 120: 0.12061066292348455.
# The training loss of step 121: 0.07668353332436953; the test loss of step 121: 0.12120101731196438.
# The training loss of step 122: 0.07658991247246029; the test loss of step 122: 0.12210758813987597.
# The training loss of step 123: 0.07659530265880099; the test loss of step 123: 0.11889712215596285.
# The training loss of step 124: 0.07627749368457266; the test loss of step 124: 0.1205532261503316.
# The training loss of step 125: 0.0759987693753296; the test loss of step 125: 0.12233267142681896.
# The training loss of step 126: 0.07587470097462448; the test loss of step 126: 0.12018380583357204.
# The training loss of step 127: 0.07597165123046173; the test loss of step 127: 0.124154889917502.
# The training loss of step 128: 0.07575421815915366; the test loss of step 128: 0.1238819032387018.
# The training loss of step 129: 0.07592503483819797; the test loss of step 129: 0.12255179277651816.
# The training loss of step 130: 0.0755931033637015; the test loss of step 130: 0.12018705611240248.
# The training loss of step 131: 0.07554914760822733; the test loss of step 131: 0.12483757186953287.
# The training loss of step 132: 0.07557093447910039; the test loss of step 132: 0.11979298993220872.
# The training loss of step 133: 0.07548506851848656; the test loss of step 133: 0.12125661779813532.
# The training loss of step 134: 0.07529785580357709; the test loss of step 134: 0.12176087375545691.
# The training loss of step 135: 0.07546102144687916; the test loss of step 135: 0.12483326839777334.
# The training loss of step 136: 0.07542537182822805; the test loss of step 136: 0.12114426492491252.
# The training loss of step 137: 0.07523158797281047; the test loss of step 137: 0.12299983255959471.
# The training loss of step 138: 0.07512146660906553; the test loss of step 138: 0.12210199140962062.
# The training loss of step 139: 0.0751069340870155; the test loss of step 139: 0.12103628587776484.
# The training loss of step 140: 0.07493515108348117; the test loss of step 140: 0.1216960293007571.
# The training loss of step 141: 0.07488001062061539; the test loss of step 141: 0.12057963648522878.
# The training loss of step 142: 0.07491320841723001; the test loss of step 142: 0.1259744595282575.
# The training loss of step 143: 0.07476411267451173; the test loss of step 143: 0.12261082743040526.
# The training loss of step 144: 0.0745832833482273; the test loss of step 144: 0.12207288669891037.
# The training loss of step 145: 0.07467758245904259; the test loss of step 145: 0.11929576442454905.
# The training loss of step 146: 0.07487057161989377; the test loss of step 146: 0.12746776228933843.
# The training loss of step 147: 0.07431567547457434; the test loss of step 147: 0.12245014400629056.
# The training loss of step 148: 0.07421133577024798; the test loss of step 148: 0.12085426790362001.
# The training loss of step 149: 0.07436173573202413; the test loss of step 149: 0.11790875115297642.
# The training loss of step 150: 0.07422231811732054; the test loss of step 150: 0.12040445037044939.
# The training loss of step 151: 0.07424162589033194; the test loss of step 151: 0.12221108833215882.
# The training loss of step 152: 0.07397386620031121; the test loss of step 152: 0.12198118026651164.
# The training loss of step 153: 0.07387380323211255; the test loss of step 153: 0.12056109158399612.
# The training loss of step 154: 0.07386565932102512; the test loss of step 154: 0.11945472307105251.
# The training loss of step 155: 0.07392354825591312; the test loss of step 155: 0.12051396260631402.
# The training loss of step 156: 0.07395626528123293; the test loss of step 156: 0.11960883320891473.
# The training loss of step 157: 0.07411175777519503; the test loss of step 157: 0.12507078238884248.
# The training loss of step 158: 0.07380584581242738; the test loss of step 158: 0.12378200163309162.
# The training loss of step 159: 0.0736301397042882; the test loss of step 159: 0.11914194354165343.
# The training loss of step 160: 0.07357573120387068; the test loss of step 160: 0.12076312725505264.
# The training loss of step 161: 0.07415442824222696; the test loss of step 161: 0.1296558434596901.
# The training loss of step 162: 0.07371235826417284; the test loss of step 162: 0.12015402702525232.
# The training loss of step 163: 0.07343034322369581; the test loss of step 163: 0.1227613425563389.
# The training loss of step 164: 0.07328626787925352; the test loss of step 164: 0.12225472142265593.
# The training loss of step 165: 0.07320347535580117; the test loss of step 165: 0.11928846160690956.
# The training loss of step 166: 0.07327925523631536; the test loss of step 166: 0.12118319056476481.
# The training loss of step 167: 0.07310589587778253; the test loss of step 167: 0.12309475082289219.
# The training loss of step 168: 0.07407432832696673; the test loss of step 168: 0.11930639400644809.
# The training loss of step 169: 0.07314088484370583; the test loss of step 169: 0.12408105369555424.
# The training loss of step 170: 0.07300835169186012; the test loss of step 170: 0.12213784754366201.
# The training loss of step 171: 0.07297354743508844; the test loss of step 171: 0.11913445062443113.
# The training loss of step 172: 0.07292512006905226; the test loss of step 172: 0.1193751764192019.
# The training loss of step 173: 0.07311325102934961; the test loss of step 173: 0.1260416396537064.
# The training loss of step 174: 0.07279426399633988; the test loss of step 174: 0.11968757886380808.
# The training loss of step 175: 0.07291551337253019; the test loss of step 175: 0.12014574159854931.
# The training loss of step 176: 0.07267833869669288; the test loss of step 176: 0.1225829838877422.
# The training loss of step 177: 0.07269904103703848; the test loss of step 177: 0.11989172059754846.
# The training loss of step 178: 0.07347894889616685; the test loss of step 178: 0.1243313684885178.
# The training loss of step 179: 0.07282929258926865; the test loss of step 179: 0.12304383833663485.
# The training loss of step 180: 0.07259513135976932; the test loss of step 180: 0.12205515018762268.
# The training loss of step 181: 0.07245670073885634; the test loss of step 181: 0.1220143243384544.
# The training loss of step 182: 0.07270511781930036; the test loss of step 182: 0.12271948991610057.
# The training loss of step 183: 0.07265224819571403; the test loss of step 183: 0.1225871972640134.
# The training loss of step 184: 0.0724390426162087; the test loss of step 184: 0.12290870425965973.
# The training loss of step 185: 0.07257931447062603; the test loss of step 185: 0.11904873840888379.
# The training loss of step 186: 0.07233374579269507; the test loss of step 186: 0.12172551726364851.
# The training loss of step 187: 0.07270063217383341; the test loss of step 187: 0.12629953109356956.
# The training loss of step 188: 0.07230014866925669; the test loss of step 188: 0.12302867340897.
# The training loss of step 189: 0.07227319309560301; the test loss of step 189: 0.12271526252237981.
# The training loss of step 190: 0.07254764310443153; the test loss of step 190: 0.12131283152521175.
# The training loss of step 191: 0.07229349478534494; the test loss of step 191: 0.12449273911630823.
# The training loss of step 192: 0.07238393043228832; the test loss of step 192: 0.1206005431025223.
# The training loss of step 193: 0.0722849449648087; the test loss of step 193: 0.11978420053972519.
# The training loss of step 194: 0.07256262206443269; the test loss of step 194: 0.12057668228251749.
# The training loss of step 195: 0.0723612515972195; the test loss of step 195: 0.12457884334066417.
# The training loss of step 196: 0.07217079327387443; the test loss of step 196: 0.12373177407443492.
# The training loss of step 197: 0.07205130924877881; the test loss of step 197: 0.12264165800739854.
# The training loss of step 198: 0.07205450087066198; the test loss of step 198: 0.12336976805701319.
# The training loss of step 199: 0.07234015581347511; the test loss of step 199: 0.12493889539128564.
# The training loss of step 200: 0.07206761135213802; the test loss of step 200: 0.12424374113230428.
# The training loss of step 201: 0.07206082196428917; the test loss of step 201: 0.12242839216907557.
# The training loss of step 202: 0.07244179703300753; the test loss of step 202: 0.1246593510774432.
# The training loss of step 203: 0.07203987388197394; the test loss of step 203: 0.1238837994018886.
# The training loss of step 204: 0.07189970456278776; the test loss of step 204: 0.12301735045054515.
# The training loss of step 205: 0.07213955667492712; the test loss of step 205: 0.12075701907177065.
# The training loss of step 206: 0.07212667094407652; the test loss of step 206: 0.12544679284016078.
# The training loss of step 207: 0.0731747174755836; the test loss of step 207: 0.11889816442233246.
# The training loss of step 208: 0.07225555372331986; the test loss of step 208: 0.12168021899408997.
# The training loss of step 209: 0.07196617039612652; the test loss of step 209: 0.12012663394865941.
# The training loss of step 210: 0.07182850906279115; the test loss of step 210: 0.12469373808165038.
# The training loss of step 211: 0.0718673768088998; the test loss of step 211: 0.12234449175578357.
# The training loss of step 212: 0.0718133670701771; the test loss of step 212: 0.12084789641802858.
# The training loss of step 213: 0.07239254878602229; the test loss of step 213: 0.12289223756923173.
# The training loss of step 214: 0.07218283813482372; the test loss of step 214: 0.12428065258628573.
# The training loss of step 215: 0.07175193739435674; the test loss of step 215: 0.12350945694019082.
# The training loss of step 216: 0.07167254609642112; the test loss of step 216: 0.12317301888398037.
# The training loss of step 217: 0.07165547747960534; the test loss of step 217: 0.12384392829260167.
# The training loss of step 218: 0.07191386315568263; the test loss of step 218: 0.12754258055259332.
# The training loss of step 219: 0.07174454593849101; the test loss of step 219: 0.12265173361214687.
# The training loss of step 220: 0.07244759389564491; the test loss of step 220: 0.12250727125269317.
# The training loss of step 221: 0.07163943208207788; the test loss of step 221: 0.12256027813242588.
# The training loss of step 222: 0.07168868829460892; the test loss of step 222: 0.12621981392529755.
# The training loss of step 223: 0.07189750560011526; the test loss of step 223: 0.11936419883880003.
# The training loss of step 224: 0.07204246521999955; the test loss of step 224: 0.11997392676818339.
# The training loss of step 225: 0.07205600284618732; the test loss of step 225: 0.12617568342626886.
# The training loss of step 226: 0.07159763983800599; the test loss of step 226: 0.125475556029337.
# The training loss of step 227: 0.07160674003286997; the test loss of step 227: 0.12438834638625346.
# The training loss of step 228: 0.07148010979593171; the test loss of step 228: 0.12478772731008543.
# The training loss of step 229: 0.07165427761070707; the test loss of step 229: 0.12394376687488934.
# The training loss of step 230: 0.07151211080954724; the test loss of step 230: 0.12341816785690232.
# The training loss of step 231: 0.07157397823044791; the test loss of step 231: 0.12622342565098718.
# The training loss of step 232: 0.072036976852818; the test loss of step 232: 0.12830830127772194.
# The training loss of step 233: 0.07153141474473727; the test loss of step 233: 0.12689833726818334.
# The training loss of step 234: 0.07150188014721268; the test loss of step 234: 0.12315955322897411.
# The training loss of step 235: 0.07160698793407803; the test loss of step 235: 0.12670252264889045.
# The training loss of step 236: 0.0716249618163203; the test loss of step 236: 0.12060423772140184.
# The training loss of step 237: 0.07152376348912909; the test loss of step 237: 0.12615586779066548.
# The training loss of step 238: 0.07161700214822385; the test loss of step 238: 0.125378930625346.
# The training loss of step 239: 0.07145599166201402; the test loss of step 239: 0.12414094323191391.
# The training loss of step 240: 0.07166170462084763; the test loss of step 240: 0.12464467743119385.
# The training loss of step 241: 0.07146344295369964; the test loss of step 241: 0.1233178424185051.
# The training loss of step 242: 0.07157109743773311; the test loss of step 242: 0.12596885228556914.
# The training loss of step 243: 0.07135264374168246; the test loss of step 243: 0.12568767807659809.
# The training loss of step 244: 0.0720509630103765; the test loss of step 244: 0.12431841407109889.
# The training loss of step 245: 0.07172196150190738; the test loss of step 245: 0.1238654500202209.
# The training loss of step 246: 0.07142213737334324; the test loss of step 246: 0.12529556373698603.
# The training loss of step 247: 0.07155780783192793; the test loss of step 247: 0.120951813801992.
# The training loss of step 248: 0.07189644342471652; the test loss of step 248: 0.12742055439169142.
# The training loss of step 249: 0.071516175891168; the test loss of step 249: 0.12456518895287666.
# The training loss of step 250: 0.07131742700207362; the test loss of step 250: 0.12634134969355315.
# The training loss of step 251: 0.07136929098912337; the test loss of step 251: 0.12494876904264687.
# The training loss of step 252: 0.07131360421083474; the test loss of step 252: 0.12319842709106311.
# The training loss of step 253: 0.071489341595063; the test loss of step 253: 0.12540446711815614.
# The training loss of step 254: 0.07132705713150642; the test loss of step 254: 0.12574680618838.
# The training loss of step 255: 0.07144863122339835; the test loss of step 255: 0.12074859915350866.
# The training loss of step 256: 0.07139764136046027; the test loss of step 256: 0.12288263898098761.
# The training loss of step 257: 0.0713765482063203; the test loss of step 257: 0.12627436737306655.
# The training loss of step 258: 0.07130730805163542; the test loss of step 258: 0.12721577989594257.
# The training loss of step 259: 0.07130615437194734; the test loss of step 259: 0.12445232341835222.
# The training loss of step 260: 0.0712356918203659; the test loss of step 260: 0.12700616917625931.
# The training loss of step 261: 0.07123519775413736; the test loss of step 261: 0.12385077218221645.
# The training loss of step 262: 0.07124691964229038; the test loss of step 262: 0.1260078574317481.
# The training loss of step 263: 0.07126586950512445; the test loss of step 263: 0.12728278902303403.
# The training loss of step 264: 0.07127450022101467; the test loss of step 264: 0.12405208986663165.
# The training loss of step 265: 0.07119943221885071; the test loss of step 265: 0.12381544451760951.
# The training loss of step 266: 0.07164776936224586; the test loss of step 266: 0.12642507683431348.
# The training loss of step 267: 0.07120972302576457; the test loss of step 267: 0.12532307996421485.
# The training loss of step 268: 0.07120646622281424; the test loss of step 268: 0.12346015036562794.
# The training loss of step 269: 0.07119969619366906; the test loss of step 269: 0.12293890112408352.
# The training loss of step 270: 0.07132071502600634; the test loss of step 270: 0.12645387335645572.
# The training loss of step 271: 0.07150008036712938; the test loss of step 271: 0.1206888271731995.
# The training loss of step 272: 0.07122059592194116; the test loss of step 272: 0.1258193623871602.
# The training loss of step 273: 0.0712899425503761; the test loss of step 273: 0.12557000005470995.
# The training loss of step 274: 0.07141823441596812; the test loss of step 274: 0.12328542807401041.
# The training loss of step 275: 0.07147947814773044; the test loss of step 275: 0.12998698339203962.
# The training loss of step 276: 0.07119390089361528; the test loss of step 276: 0.12560779304699193.
# The training loss of step 277: 0.07131217538152264; the test loss of step 277: 0.12389950605604404.
# The training loss of step 278: 0.07117312559524064; the test loss of step 278: 0.1262351233651722.
# The training loss of step 279: 0.0713102446096862; the test loss of step 279: 0.12098811281883766.
# The training loss of step 280: 0.0712359578071697; the test loss of step 280: 0.1273473477252846.
# The training loss of step 281: 0.07123679802440604; the test loss of step 281: 0.12603594079151811.
# The training loss of step 282: 0.07152614868264177; the test loss of step 282: 0.12634093670787355.
# The training loss of step 283: 0.07115377770591468; the test loss of step 283: 0.1243832398886942.
# The training loss of step 284: 0.07139123188106608; the test loss of step 284: 0.12906537530628556.
# The training loss of step 285: 0.07112519728743559; the test loss of step 285: 0.12466363380098308.
# The training loss of step 286: 0.0712106228320455; the test loss of step 286: 0.12690618847520446.
# The training loss of step 287: 0.07111843895516293; the test loss of step 287: 0.1245176644003917.
# The training loss of step 288: 0.07107101045448119; the test loss of step 288: 0.12687940176723148.
# The training loss of step 289: 0.07109610289801382; the test loss of step 289: 0.1251755268698623.
# The training loss of step 290: 0.07131978433241341; the test loss of step 290: 0.12349302092130975.
# The training loss of step 291: 0.07112987748873134; the test loss of step 291: 0.1272587182099185.
# The training loss of step 292: 0.07107389641921939; the test loss of step 292: 0.12249143319171325.
# The training loss of step 293: 0.07122009493764578; the test loss of step 293: 0.12784769426782153.
# The training loss of step 294: 0.07146082665532763; the test loss of step 294: 0.1262141296913658.
# The training loss of step 295: 0.07116351846500234; the test loss of step 295: 0.12313956704506605.
# The training loss of step 296: 0.07117179686290796; the test loss of step 296: 0.12674377041467913.
# The training loss of step 297: 0.07105485381312339; the test loss of step 297: 0.1271314087475237.
# The training loss of step 298: 0.07117569847720931; the test loss of step 298: 0.12578695268791854.
# The training loss of step 299: 0.07108236375763848; the test loss of step 299: 0.12721239796104616.

# %%
# Plot the loss function
loss_train_all = loss_train_all*scaler_y.var_
loss_test_all = loss_test_all*scaler_y.var_

fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.plot(loss_train_all, label="Calibration period")
ax.plot(loss_test_all, label="Test period")
ax.legend()

# %% [markdown]
# # Predictions on both training and test datasets

# %%
def l2_func(y, y_true):
    return np.mean((y - y_true) ** 2)

# %%
# Sensitivity analysis
def model_scaler(x, model):
    return model(x)[0]

# %% [markdown]
# ## MLP

# %% [markdown]
# ### Sensitivity analysis

# %%
grad = jax.vmap(jax.grad(model_scaler), in_axes=[0, None])(x_norm, model)
grad_test = jax.vmap(jax.grad(model_scaler), in_axes=[0, None])(x_test_norm, model)

# %%
# fig, axes = plt.subplots(len(varns), 1, figsize = (20, 20))
# for i,ax in enumerate(axes):
#     ax.plot(grad[:,i])
#     ax.set(ylabel=varns[i])
# # grad.mean(axis=0), grad_test.mean(axis=0)

# %%
# fig, axes = plt.subplots(len(varns), 1, figsize = (20, 20))
# for i,ax in enumerate(axes):
#     ax.plot(grad_test[:,i])
#     ax.set(ylabel=varns[i])
# # grad.mean(axis=0), grad_test.mean(axis=0)

# %% [markdown]
# ### Predictions

# %%
pred_y_norm_calib = jax.vmap(model)(x_norm)
pred_y_norm_test = jax.vmap(model)(x_test_norm)

pred_y_calib = scaler_y.inverse_transform(pred_y_norm_calib)
pred_y_test = scaler_y.inverse_transform(pred_y_norm_test)

l2_calib = l2_func(pred_y_calib, y)
l2_test = l2_func(pred_y_test, y_test)

# %%
metrics = compute_metrics(pred_y_calib, y)
metrics_test = compute_metrics(pred_y_test, y_test)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 28.497652765015207, 'mse': 812.1162131153789, 'r2': 0.922113822648611, 'kge': 0.9422687114467786, 'nse': 0.9289176362423616, 'mkge': 0.9462380125153003, 'cc': 0.9638482564768953, 'alpha': 0.9945211762841578, 'beta': 0.9605869916241427}
# {'rmse': 38.123510036354084, 'mse': 1453.4020174919906, 'r2': 0.8267443920269144, 'kge': 0.8038976766707081, 'nse': 0.8782722158865843, 'mkge': 0.867619799597408, 'cc': 0.9452588341746808, 'alpha': 0.9036542481303199, 'beta': 0.9275747397700128}

# %%
plot_timeseries_obs_1to1(
    y,
    pred_y_calib,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2], Test period",
)

plot_timeseries_obs_1to1(
    y_test,
    pred_y_test,
    lim=[-100, 1000],
    met=met_test,
    varn="Latent heat fluxes [W m-2], Test period",
);

# %%
# fig, axes = plt.subplots(2, 1, figsize=(12, 8))
# ax = axes[0]
# ax.plot(timesteps, y, label="obs")
# ax.plot(timesteps, pred_y_calib, label="DNN")
# ax.set(
#     title=f"Calibration period (L2: {l2_calib})", ylabel="Latent heat fluxes [W m-2]"
# )
# ax.legend()

# ax = axes[1]
# ax.plot(timesteps_test, y_test, label="obs")
# ax.plot(timesteps_test, pred_y_test, label="DNN")
# ax.set(title=f"Test period (L2: {l2_test})", ylabel="Latent heat fluxes [W m-2]")
# ax.legend()

# %% [markdown]
# ## Plot

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 8))
ax = axes[0]
ax.plot(timesteps, y, label="obs")
ax.plot(timesteps, pred_y_calib, label="DNN")
ax.set(
    title=f"Calibration period (L2: {l2_calib})", ylabel="Latent heat fluxes [W m-2]"
)
ax.legend()

ax = axes[1]
ax.plot(timesteps_test, y_test, label="obs")
ax.plot(timesteps_test, pred_y_test, label="DNN")
ax.set(title=f"Test period (L2: {l2_test})", ylabel="Latent heat fluxes [W m-2]")
ax.legend()

# %% [markdown]
# # Save

# %%
import pickle

train = {"time": timesteps, "loss": list(loss_train_all), "LE": pred_y_calib.flatten()}
test = {"time": timesteps_test, "loss": list(loss_test_all), "LE": pred_y_test.flatten()}
out = {"train": train, "test": test}
pickle.dump(out, open(f"{site}_dl.pkl", "wb"), pickle.HIGHEST_PROTOCOL)
