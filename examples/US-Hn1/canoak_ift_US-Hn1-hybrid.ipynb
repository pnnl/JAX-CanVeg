# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# # TODO: A more generic way is needed here to load the path
# import sys

# sys.path.append(
#     "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
#     # "/global/homes/p/peishi89/jax-watershed/src"
# )

# %%
import optax
import equinox as eqx

import pickle
from functools import partial

from math import floor

# import numpy as np
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import pandas as pd

from jax_canoak.physics.energy_fluxes import get_dispersion_matrix

from jax_canoak.models import CanoakLeafRHHybridIFT
from jax_canoak.models import get_canle, update_canle
from jax_canoak.models import get_soilresp, update_soilresp
from jax_canoak.models import load_model, save_model
# from jax_canoak.models import run_canoak_in_batch

# from jax_canoak.shared_utilities.optim import perform_optimization
from jax_canoak.shared_utilities.optim import perform_optimization_batch, mse
from jax_canoak.shared_utilities import compute_metrics
from jax_canoak.subjects import convert_met_to_batched_met
from jax_canoak.subjects import (
    # convert_batchedstates_to_states,
    convert_obs_to_batched_obs,
)
from jax_canoak.subjects import get_met_forcings, get_obs, initialize_parameters


import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_daily,
    plot_imshow2,
    plot_timeseries_obs_1to1,
    plot_rad,
    plot_ir,
    visualize_tree_diff,
)
from jax_canoak.shared_utilities.plot import (
    plot_obs_1to1,
    plot_obs_comparison,
    plot_obs_energy_closure,
    plot_dij,
    plot_para_sensitivity_ranking,
    plot_le_gs_lai,
    get_time,
)

# from jax_canoak.shared_utilities.plot import plot_veg_temp, plot_dij
# from jax_canoak.shared_utilities.plot import plot_ir, plot_rad, plot_prof2
from jax_canoak.shared_utilities import tune_jax_naninfs_for_debug

jax.config.update("jax_enable_x64", True)
tune_jax_naninfs_for_debug(False)
# jax.config.update("jax_debug_nans", False)
# jax.config.update("jax_debug_infs", False)
# jax.config.update("XLA_PYTHON_CLIENT_ALLOCATOR", 'platform')

# %load_ext autoreload
# %autoreload 2

# %%
# import os
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="FALSE"

# %% [markdown]
# # Model parameters and settings

# %%
time_zone = -8
latitude = 46.4089
longitude = -119.2750
stomata = 0
veg_ht = 1.2
leafangle = 2  # erectophile
n_can_layers = 50
n_atmos_layers = 50
meas_ht = 5.0
soil_depth = 0.15
n_hr_per_day = 48
niter = 15
# niter = 1

# batch_size = 2
# batch_size = 1274
# batch_size = int(27744/2)
batch_size, batch_size_test = int(27744/2), None

site = "US-Hn1"
key = "hybridRH"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings-v2.csv"
# f_obs = "../../data/fluxtower/US-Hn1/US-Hn1-fluxes.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes-nonegle-v2.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test-v2.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-nonegle-test-v2.csv"

# Models
f_model = f"{site}_{key}_model.eqx"
# f_model_new = f"{site}_{key}_model.eqx"

# %% [markdown]
# # Load and set the model forcings

# %%
# Training
met, n_time = get_met_forcings(f_forcing)
if batch_size is None: batch_size = n_time
n_batch = floor(n_time / batch_size)
batched_met = convert_met_to_batched_met(met, n_batch, batch_size)
timesteps = get_time(met)

# %%
# Test
met_test, n_time_test = get_met_forcings(f_forcing_test)
if batch_size_test is None: batch_size_test = n_time_test
n_batch_test = floor(n_time_test / batch_size_test)
batched_met_test = convert_met_to_batched_met(met_test, n_batch_test, batch_size_test)
timesteps_test = get_time(met_test)

# %%
plt.plot(met.soilmoisture)

# %% [markdown]
# # Load the observations

# %%
# Training
obs = get_obs(f_obs)

# Test
obs_test = get_obs(f_obs_test)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Create the model parameter instance

# %%
setup, para, para_min, para_max = initialize_parameters(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    obs=obs,
    met=met,
    niter=niter,
    get_para_bounds=True,
)

# %% [markdown]
# # Generate or read the dispersion matrix

# %%
# dij = get_dispersion_matrix(setup, para)
dij = get_dispersion_matrix(setup, para, f"../../data/dij/Dij_{site}.csv")
# import numpy as np
# np.savetxt(f"../../data/dij/Dij_{site}.csv", np.array(dij), delimiter=',')

# %%
plot_dij(dij, para)
# Out:
# <Axes: xlabel='Dij [s/m]', ylabel='Height [m]'>

# %% [markdown]
# # Run CANOAK!

# %%
jax.clear_caches()
canoak_eqx_ift = CanoakLeafRHHybridIFT(para, setup, dij)

# %%
# Training data
# met, prof, ir, qin, sun, shade, soil, veg, can = canoak_eqx_ift(met)
states, drivers = canoak_eqx_ift(met)
met, prof, ir, qin, sun, shade, soil, veg, can = states
quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
# Test data
states_test, drivers_test = canoak_eqx_ift(met_test)
met_test, prof_test, ir_test, qin_test, sun_test, shade_test, soil_test, veg_test, can_test = states_test
quantum_test, nir_test, rnet_test, sun_ang_test, leaf_ang_test, lai_test = drivers_test

# %%
# Leaf relative humidity
plot_imshow2(
    sun.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)

plot_imshow2(
    sun_test.Leaf_RH.T,
    met_test,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")

# %%
# Daily average
plot_daily(met, soil, veg, para);
plot_daily(met_test, soil_test, veg_test, para);

# %%
# Analyze nan
nanind = jnp.where(jnp.isnan(prof.Tair_K.mean(axis=1)))

met.lai[nanind]
# qin.sun_abs[nanind]
# ir.ir_in[nanind]
sun.Tsfc[nanind, :]
# Out:
# Array([], dtype=float64)

# %% [markdown]
# # Local sensitivity analysis

# %%
jax.clear_caches()


@eqx.filter_jit
@partial(jax.grad, argnums=0)
def df_canoak_le(para, met, canoak_eqx):
    canoak_eqx = eqx.tree_at(lambda t: t.para, canoak_eqx, para)
    can_le = canoak_eqx.get_fixed_point_states(met, update_canle, get_canle)
    # met, update_soilresp, get_soilresp)
    return can_le.sum()


@eqx.filter_jit
def df_canoak_le_batched(para, batched_met, canoak_eqx):
    def compute_grad(para, met):
        grad = df_canoak_le(para, met, canoak_eqx)
        return para, grad

    _, gradients = jax.lax.scan(compute_grad, para, xs=batched_met)
    return gradients


# eqx.filter_make_jaxpr(df_canoak_le3)(para, met, canoak_eqx)

# %% [markdown]
# ## Perform SA at one time step

# %%
start, ntime = 20, 1
met2 = jtu.tree_map(lambda x: x[start : start + ntime], met)

# %%
gradients = df_canoak_le(para, met2, canoak_eqx_ift)

# %%
gradients.lleaf
# Out:
# Array(-20.70639241, dtype=float64, weak_type=True)

# %% [markdown]
# ## Perform SA at multiple steps

# %%
jax.clear_caches()
batched_met_sa = convert_met_to_batched_met(met, n_time, 1)
gradients = df_canoak_le_batched(para, batched_met_sa, canoak_eqx_ift)

# %%
plot_para_sensitivity_ranking(gradients, category="photosyn")
# plot_para_sensitivity_ranking(gradients, category=None)

# %%
# gm = jtu.tree_map(lambda x:x.mean(), gradients)
# a, b = jtu.tree_flatten(gm)

# %%
# bb = b.node_data()[1]
# names = bb.dynamic_field_names

# %% [markdown]
# # Comparison with the observations

# %%
plot_obs_energy_closure(obs)
# Out:
# <Axes: xlabel='Rnet, measured', ylabel='H+LE+Gsoil, measured'>

# %%
plot_obs_1to1(obs.rnet, can.rnet, lim=[-50, 800], varn="Rnet")
# Out:
# <Axes: title={'center': 'Rnet (L2: 1371.509)'}, xlabel='Measured', ylabel='Simulated'>

# %%
plot_timeseries_obs_1to1(
    obs.rnet,
    can.rnet,
    lim=[-100, 800],
    met=met,
    varn="Net radiation [W m-2]",
);

# %%
# plt.figure(0)
# plt.plot(obs.P)
# plt.figure(1)
# plt.plot(obs.Rsoil)
# plt.figure(1)
# plt.plot(soil.resp)

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
);

# %%
plot_obs_comparison(obs, can);

# %% [markdown]
# # Perform parameter estimation

# %%
# Filter the parameters to be estimated
filter_model_spec = jtu.tree_map(lambda _: False, canoak_eqx_ift)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.weight for layer in t.para.LeafRHDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [layer.bias for layer in t.para.LeafRHDL.layers],
    filter_model_spec,
    replace=[True for layer in filter_model_spec.para.LeafRHDL.layers],
)
filter_model_spec = eqx.tree_at(
    lambda t: [t.para.bprime, t.para.kball, t.para.lleaf, t.para.qalpha],
    filter_model_spec,
    replace=[True, True, True, True],
)

# %%
# Define optimizer and observations
args = [update_canle, get_canle]
# nsteps = 5  # number of epoches
nsteps = 300  # number of epoches
# nsteps = 10  # number of epoches
batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE
scheduler = optax.piecewise_constant_schedule(
    0.01, boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
)
# scheduler = optax.exponential_decay(0.01, transition_steps=30, decay_rate=0.1)
# optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
# optim = optax.adam(learning_rate=0.01)  # Adam optimizer

batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE

batched_obs_test = convert_obs_to_batched_obs(obs_test, n_batch_test, batch_size_test)
batched_y_test = batched_obs_test.LE

# %%
# jax.clear_caches()
args = [update_canle, get_canle]
canoak_eqx_new, loss_train_set, loss_test_set = perform_optimization_batch(
    canoak_eqx_ift.get_fixed_point_states,
    filter_model_spec.get_fixed_point_states,
    optim,
    nsteps,
    mse,
    batched_y,
    batched_met,
    batched_y_test,
    batched_met_test,
    para_min,
    para_max,
    *args,
)
# canoak_eqx_new = canoak_eqx_new.args[0]
canoak_eqx_new = canoak_eqx_new.__self__
# Out:
# Argument model is triggering a compile.
# Argument filter_model_spec is triggering a compile.
# Argument batched_y is triggering a compile.
# Argument opt_state is triggering a compile.
# Argument batched_met is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 0: 25036.397338050472; the test loss of step 0: 34854.14081744311.
# Argument model is triggering a compile.
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 1: 21915.20135239004; the test loss of step 1: 28997.99635242888.
# Compiling calculate_test_loss ...
# The training loss of step 2: 17858.144918989925; the test loss of step 2: 22968.94905288797.
# Compiling calculate_test_loss ...
# The training loss of step 3: 13707.202137639468; the test loss of step 3: 16399.75220757792.
# Compiling calculate_test_loss ...
# The training loss of step 4: 9320.89550919822; the test loss of step 4: 9310.330020218713.
# Compiling calculate_test_loss ...
# The training loss of step 5: 5001.688672860237; the test loss of step 5: 7206.093438069109.
# Compiling calculate_test_loss ...
# The training loss of step 6: 3878.7229236287003; the test loss of step 6: 5271.334675716407.
# Compiling calculate_test_loss ...
# The training loss of step 7: 2894.412108195868; the test loss of step 7: 3615.8431866535384.
# Compiling calculate_test_loss ...
# The training loss of step 8: 2094.6368230808757; the test loss of step 8: 2301.8991288784646.
# Compiling calculate_test_loss ...
# The training loss of step 9: 1496.587186014181; the test loss of step 9: 1327.8908118969973.
# Compiling calculate_test_loss ...
# The training loss of step 10: 1082.6032005120862; the test loss of step 10: 702.6602844434785.
# Compiling calculate_test_loss ...
# The training loss of step 11: 841.4307157652356; the test loss of step 11: 353.9831804783417.
# Compiling calculate_test_loss ...
# The training loss of step 12: 745.8741155305809; the test loss of step 12: 211.30024489573174.
# Compiling calculate_test_loss ...
# The training loss of step 13: 765.7305237185121; the test loss of step 13: 209.58287975567265.
# Compiling calculate_test_loss ...
# The training loss of step 14: 849.9592579827311; the test loss of step 14: 237.90519785681596.
# Compiling calculate_test_loss ...
# The training loss of step 15: 936.3102451319393; the test loss of step 15: 252.97073429053367.
# Compiling calculate_test_loss ...
# The training loss of step 16: 1004.0563068099073; the test loss of step 16: 259.1668850898625.
# Compiling calculate_test_loss ...
# The training loss of step 17: 1054.0252422815176; the test loss of step 17: 261.7023515972856.
# Compiling calculate_test_loss ...
# The training loss of step 18: 1090.1890910544728; the test loss of step 18: 262.5612604039107.
# Compiling calculate_test_loss ...
# The training loss of step 19: 1119.3238982143296; the test loss of step 19: 262.839446691053.
# Compiling calculate_test_loss ...
# The training loss of step 20: 1143.3086425035467; the test loss of step 20: 250.92377013194982.
# Compiling calculate_test_loss ...
# The training loss of step 21: 1136.0925968003162; the test loss of step 21: 227.53026077265469.
# Compiling calculate_test_loss ...
# The training loss of step 22: 1070.7771541365478; the test loss of step 22: 206.12417285492987.
# Compiling calculate_test_loss ...
# The training loss of step 23: 989.3653954071201; the test loss of step 23: 218.23183472699105.
# Compiling calculate_test_loss ...
# The training loss of step 24: 899.2012961308421; the test loss of step 24: 292.0393046108497.
# Compiling calculate_test_loss ...
# The training loss of step 25: 855.8322809171277; the test loss of step 25: 416.5505639858595.
# Compiling calculate_test_loss ...
# The training loss of step 26: 859.5224421470016; the test loss of step 26: 564.2044014632763.
# Compiling calculate_test_loss ...
# The training loss of step 27: 894.2487746777301; the test loss of step 27: 705.9474156512332.
# Compiling calculate_test_loss ...
# The training loss of step 28: 940.152110782877; the test loss of step 28: 813.1047173403084.
# Compiling calculate_test_loss ...
# The training loss of step 29: 980.0585125461378; the test loss of step 29: 867.9191585851722.
# Compiling calculate_test_loss ...
# The training loss of step 30: 1002.814337312629; the test loss of step 30: 865.5481283476656.
# Compiling calculate_test_loss ...
# The training loss of step 31: 1003.424576056675; the test loss of step 31: 810.9610239040142.
# Compiling calculate_test_loss ...
# The training loss of step 32: 984.1384420354472; the test loss of step 32: 718.0635395868334.
# Compiling calculate_test_loss ...
# The training loss of step 33: 952.6742321116086; the test loss of step 33: 604.5821140416713.
# Compiling calculate_test_loss ...
# The training loss of step 34: 918.7012590472123; the test loss of step 34: 490.05880690814024.
# Compiling calculate_test_loss ...
# The training loss of step 35: 892.522070565878; the test loss of step 35: 391.15632037453486.
# Compiling calculate_test_loss ...
# The training loss of step 36: 880.9923405433626; the test loss of step 36: 317.4438245428365.
# Compiling calculate_test_loss ...
# The training loss of step 37: 884.8437901249484; the test loss of step 37: 270.3095604599359.
# Compiling calculate_test_loss ...
# The training loss of step 38: 898.8159332314068; the test loss of step 38: 245.09851619732848.
# Compiling calculate_test_loss ...
# The training loss of step 39: 913.376675410255; the test loss of step 39: 235.41509846111285.
# Compiling calculate_test_loss ...
# The training loss of step 40: 919.5476354405579; the test loss of step 40: 236.58235868450305.
# Compiling calculate_test_loss ...
# The training loss of step 41: 913.3123544083155; the test loss of step 41: 247.9098038319955.
# Compiling calculate_test_loss ...
# The training loss of step 42: 896.8554765378142; the test loss of step 42: 271.3999707269306.
# Compiling calculate_test_loss ...
# The training loss of step 43: 877.0727591722983; the test loss of step 43: 308.045558576648.
# Compiling calculate_test_loss ...
# The training loss of step 44: 860.4654745415532; the test loss of step 44: 354.7674020345921.
# Compiling calculate_test_loss ...
# The training loss of step 45: 851.3418980703898; the test loss of step 45: 405.1065846893642.
# Compiling calculate_test_loss ...
# The training loss of step 46: 848.9751756551243; the test loss of step 46: 450.67568420688195.
# Compiling calculate_test_loss ...
# The training loss of step 47: 850.7319968617237; the test loss of step 47: 483.0712010282723.
# Compiling calculate_test_loss ...
# The training loss of step 48: 852.9331153844282; the test loss of step 48: 496.68769766425334.
# Compiling calculate_test_loss ...
# The training loss of step 49: 852.1416836133127; the test loss of step 49: 490.0278425908716.
# Compiling calculate_test_loss ...
# The training loss of step 50: 847.3871780974614; the test loss of step 50: 477.6854909082823.
# Compiling calculate_test_loss ...
# The training loss of step 51: 843.1447592798042; the test loss of step 51: 458.24720158770185.
# Compiling calculate_test_loss ...
# The training loss of step 52: 837.3881936676732; the test loss of step 52: 433.90069606937436.
# Compiling calculate_test_loss ...
# The training loss of step 53: 831.1804664924052; the test loss of step 53: 407.13254077081683.
# Compiling calculate_test_loss ...
# The training loss of step 54: 825.7798763412322; the test loss of step 54: 380.1482449529098.
# Compiling calculate_test_loss ...
# The training loss of step 55: 821.2180602826122; the test loss of step 55: 354.82088220865006.
# Compiling calculate_test_loss ...
# The training loss of step 56: 818.2149587565291; the test loss of step 56: 332.65498453546553.
# Compiling calculate_test_loss ...
# The training loss of step 57: 816.5812363460961; the test loss of step 57: 314.4031767075288.
# Compiling calculate_test_loss ...
# The training loss of step 58: 816.1701575380652; the test loss of step 58: 300.4037884641522.
# Compiling calculate_test_loss ...
# The training loss of step 59: 816.435963643541; the test loss of step 59: 290.6515861112848.
# Compiling calculate_test_loss ...
# The training loss of step 60: 816.753284996377; the test loss of step 60: 285.0023874052272.
# Compiling calculate_test_loss ...
# The training loss of step 61: 816.4259731486227; the test loss of step 61: 283.0903005932027.
# Compiling calculate_test_loss ...
# The training loss of step 62: 815.6627886785761; the test loss of step 62: 284.6667529228262.
# Compiling calculate_test_loss ...
# The training loss of step 63: 814.0354259258787; the test loss of step 63: 289.38101584798517.
# Compiling calculate_test_loss ...
# The training loss of step 64: 811.940225629751; the test loss of step 64: 296.6945091173554.
# Compiling calculate_test_loss ...
# The training loss of step 65: 809.5127814222379; the test loss of step 65: 306.17781214535694.
# Compiling calculate_test_loss ...
# The training loss of step 66: 807.0246807929009; the test loss of step 66: 317.1432866811124.
# Compiling calculate_test_loss ...
# The training loss of step 67: 805.1515542812303; the test loss of step 67: 328.9009122971155.
# Compiling calculate_test_loss ...
# The training loss of step 68: 803.620265989244; the test loss of step 68: 340.39471334899355.
# Compiling calculate_test_loss ...
# The training loss of step 69: 802.580474840291; the test loss of step 69: 350.79204353524347.
# Compiling calculate_test_loss ...
# The training loss of step 70: 801.9357595107615; the test loss of step 70: 359.3272740652534.
# Compiling calculate_test_loss ...
# The training loss of step 71: 801.4555169969459; the test loss of step 71: 365.523968924928.
# Compiling calculate_test_loss ...
# The training loss of step 72: 800.8787133707278; the test loss of step 72: 368.87855264033226.
# Compiling calculate_test_loss ...
# The training loss of step 73: 800.1981481834478; the test loss of step 73: 369.42901185032.
# Compiling calculate_test_loss ...
# The training loss of step 74: 799.2903160888704; the test loss of step 74: 367.20773325368106.
# Compiling calculate_test_loss ...
# The training loss of step 75: 797.9648879395018; the test loss of step 75: 362.69055065237416.
# Compiling calculate_test_loss ...
# The training loss of step 76: 796.8250086415874; the test loss of step 76: 356.5813211363484.
# Compiling calculate_test_loss ...
# The training loss of step 77: 795.6731493891791; the test loss of step 77: 349.52784545479824.
# Compiling calculate_test_loss ...
# The training loss of step 78: 794.3497720385202; the test loss of step 78: 342.14043145947556.
# Compiling calculate_test_loss ...
# The training loss of step 79: 793.5558403605089; the test loss of step 79: 335.2523081762619.
# Compiling calculate_test_loss ...
# The training loss of step 80: 792.9880466071083; the test loss of step 80: 329.2911245736497.
# Compiling calculate_test_loss ...
# The training loss of step 81: 792.6297888308707; the test loss of step 81: 324.56463667001685.
# Compiling calculate_test_loss ...
# The training loss of step 82: 792.1286933859612; the test loss of step 82: 321.4011722354882.
# Compiling calculate_test_loss ...
# The training loss of step 83: 791.949221692624; the test loss of step 83: 319.7845089035018.
# Compiling calculate_test_loss ...
# The training loss of step 84: 791.3273325739472; the test loss of step 84: 319.6813863769842.
# Compiling calculate_test_loss ...
# The training loss of step 85: 790.8602443358557; the test loss of step 85: 321.0207227771077.
# Compiling calculate_test_loss ...
# The training loss of step 86: 790.2057570531031; the test loss of step 86: 323.5595842652517.
# Compiling calculate_test_loss ...
# The training loss of step 87: 789.5742177156878; the test loss of step 87: 326.9088185933144.
# Compiling calculate_test_loss ...
# The training loss of step 88: 788.7817281461039; the test loss of step 88: 330.87416957131717.
# Compiling calculate_test_loss ...
# The training loss of step 89: 787.9999537792219; the test loss of step 89: 335.2181034540009.
# Compiling calculate_test_loss ...
# The training loss of step 90: 787.2284158433986; the test loss of step 90: 339.08836164719264.
# Compiling calculate_test_loss ...
# The training loss of step 91: 786.1603254648791; the test loss of step 91: 342.41779863890224.
# Compiling calculate_test_loss ...
# The training loss of step 92: 785.0782914003935; the test loss of step 92: 344.8931858079152.
# Compiling calculate_test_loss ...
# The training loss of step 93: 783.9881111601354; the test loss of step 93: 346.40049561984546.
# Compiling calculate_test_loss ...
# The training loss of step 94: 782.7704547926134; the test loss of step 94: 346.6723154553327.
# Compiling calculate_test_loss ...
# The training loss of step 95: 781.4378684299031; the test loss of step 95: 345.9922631365944.
# Compiling calculate_test_loss ...
# The training loss of step 96: 779.9741522654003; the test loss of step 96: 344.38490941106136.
# Compiling calculate_test_loss ...
# The training loss of step 97: 778.8485317184508; the test loss of step 97: 342.152063045177.
# Compiling calculate_test_loss ...
# The training loss of step 98: 777.6588758298126; the test loss of step 98: 339.606994754594.
# Compiling calculate_test_loss ...
# The training loss of step 99: 776.5037206474337; the test loss of step 99: 336.9001437830891.
# Compiling calculate_test_loss ...
# The training loss of step 100: 775.4619667972909; the test loss of step 100: 335.52535894473976.
# Compiling calculate_test_loss ...
# The training loss of step 101: 774.97226995457; the test loss of step 101: 334.3634102792058.
# Compiling calculate_test_loss ...
# The training loss of step 102: 774.5892314496734; the test loss of step 102: 333.3986218665232.
# Compiling calculate_test_loss ...
# The training loss of step 103: 774.2722936690275; the test loss of step 103: 332.57534785806723.
# Compiling calculate_test_loss ...
# The training loss of step 104: 773.8964863597488; the test loss of step 104: 331.9178983360011.
# Compiling calculate_test_loss ...
# The training loss of step 105: 773.6193150552585; the test loss of step 105: 331.4044567977752.
# Compiling calculate_test_loss ...
# The training loss of step 106: 773.714619374877; the test loss of step 106: 331.0564877723992.
# Compiling calculate_test_loss ...
# The training loss of step 107: 773.3362811039813; the test loss of step 107: 330.8415257987407.
# Compiling calculate_test_loss ...
# The training loss of step 108: 773.0832483520435; the test loss of step 108: 330.8545078045757.
# Compiling calculate_test_loss ...
# The training loss of step 109: 773.0597239637749; the test loss of step 109: 331.03115817258674.
# Compiling calculate_test_loss ...
# The training loss of step 110: 772.847240088665; the test loss of step 110: 331.21674371308404.
# Compiling calculate_test_loss ...
# The training loss of step 111: 772.5217005826643; the test loss of step 111: 331.4692933752334.
# Compiling calculate_test_loss ...
# The training loss of step 112: 772.2268520036957; the test loss of step 112: 331.8093998404596.
# Compiling calculate_test_loss ...
# The training loss of step 113: 771.8707892899527; the test loss of step 113: 332.08340984250026.
# Compiling calculate_test_loss ...
# The training loss of step 114: 771.5501577109346; the test loss of step 114: 332.4439356460322.
# Compiling calculate_test_loss ...
# The training loss of step 115: 771.1701492733098; the test loss of step 115: 332.8195957950793.
# Compiling calculate_test_loss ...
# The training loss of step 116: 770.8189556041771; the test loss of step 116: 333.239193007276.
# Compiling calculate_test_loss ...
# The training loss of step 117: 770.4180664979594; the test loss of step 117: 333.58940855071023.
# Compiling calculate_test_loss ...
# The training loss of step 118: 769.9866389023928; the test loss of step 118: 333.9620741741595.
# Compiling calculate_test_loss ...
# The training loss of step 119: 769.4656175368832; the test loss of step 119: 334.2675462429933.
# Compiling calculate_test_loss ...
# The training loss of step 120: 769.09665360956; the test loss of step 120: 334.53516141024267.
# Compiling calculate_test_loss ...
# The training loss of step 121: 768.5369971593441; the test loss of step 121: 334.7196272181757.
# Compiling calculate_test_loss ...
# The training loss of step 122: 768.0217693489537; the test loss of step 122: 334.8522448553181.
# Compiling calculate_test_loss ...
# The training loss of step 123: 767.5717955445018; the test loss of step 123: 334.9095306395255.
# Compiling calculate_test_loss ...
# The training loss of step 124: 767.2114307727775; the test loss of step 124: 334.86262286393685.
# Compiling calculate_test_loss ...
# The training loss of step 125: 766.8299799322708; the test loss of step 125: 334.7238388886321.
# Compiling calculate_test_loss ...
# The training loss of step 126: 766.4509261438105; the test loss of step 126: 334.559652757701.
# Compiling calculate_test_loss ...
# The training loss of step 127: 766.0942200461759; the test loss of step 127: 334.3328475140547.
# Compiling calculate_test_loss ...
# The training loss of step 128: 765.6533886498999; the test loss of step 128: 334.03144570105525.
# Compiling calculate_test_loss ...
# The training loss of step 129: 765.1641418131173; the test loss of step 129: 333.8155344422316.
# Compiling calculate_test_loss ...
# The training loss of step 130: 764.7794986306446; the test loss of step 130: 333.5268276563772.
# Compiling calculate_test_loss ...
# The training loss of step 131: 764.2803644132682; the test loss of step 131: 333.13842954811815.
# Compiling calculate_test_loss ...
# The training loss of step 132: 763.8489155186046; the test loss of step 132: 332.69267114355387.
# Compiling calculate_test_loss ...
# The training loss of step 133: 763.4114198715832; the test loss of step 133: 332.27998446418366.
# Compiling calculate_test_loss ...
# The training loss of step 134: 763.0688391719657; the test loss of step 134: 331.84683698781555.
# Compiling calculate_test_loss ...
# The training loss of step 135: 762.6258180469811; the test loss of step 135: 331.4577150813099.
# Compiling calculate_test_loss ...
# The training loss of step 136: 762.1033778715407; the test loss of step 136: 331.076812064031.
# Compiling calculate_test_loss ...
# The training loss of step 137: 761.6302082567067; the test loss of step 137: 330.6957559657756.
# Compiling calculate_test_loss ...
# The training loss of step 138: 761.1018173273449; the test loss of step 138: 330.188805359871.
# Compiling calculate_test_loss ...
# The training loss of step 139: 760.6684726485132; the test loss of step 139: 329.6993930994468.
# Compiling calculate_test_loss ...
# The training loss of step 140: 760.2086499924053; the test loss of step 140: 329.3338535527278.
# Compiling calculate_test_loss ...
# The training loss of step 141: 759.6561341606504; the test loss of step 141: 329.06487934089995.
# Compiling calculate_test_loss ...
# The training loss of step 142: 758.9886488329832; the test loss of step 142: 328.8124521693933.
# Compiling calculate_test_loss ...
# The training loss of step 143: 758.5290455822912; the test loss of step 143: 328.68750350826843.
# Compiling calculate_test_loss ...
# The training loss of step 144: 758.2087230072323; the test loss of step 144: 328.61774699604905.
# Compiling calculate_test_loss ...
# The training loss of step 145: 757.7711298958901; the test loss of step 145: 328.6564133413124.
# Compiling calculate_test_loss ...
# The training loss of step 146: 757.3679285384644; the test loss of step 146: 328.6699283768019.
# Compiling calculate_test_loss ...
# The training loss of step 147: 756.9716963067441; the test loss of step 147: 328.6450794225848.
# Compiling calculate_test_loss ...
# The training loss of step 148: 756.6818298893611; the test loss of step 148: 328.59458223802704.
# Compiling calculate_test_loss ...
# The training loss of step 149: 756.27119597095; the test loss of step 149: 328.52604610658784.
# Compiling calculate_test_loss ...
# The training loss of step 150: 755.7971901109529; the test loss of step 150: 328.35913138016645.
# Compiling calculate_test_loss ...
# The training loss of step 151: 755.3926441683196; the test loss of step 151: 328.1403611873363.
# Compiling calculate_test_loss ...
# The training loss of step 152: 754.846674414925; the test loss of step 152: 327.83635019177126.
# Compiling calculate_test_loss ...
# The training loss of step 153: 754.5183219987578; the test loss of step 153: 327.57286424552166.
# Compiling calculate_test_loss ...
# The training loss of step 154: 754.0741511400536; the test loss of step 154: 327.2560811563168.
# Compiling calculate_test_loss ...
# The training loss of step 155: 753.6361155575173; the test loss of step 155: 326.94453467783825.
# Compiling calculate_test_loss ...
# The training loss of step 156: 753.3170344652791; the test loss of step 156: 326.7111616433975.
# Compiling calculate_test_loss ...
# The training loss of step 157: 752.8622336257996; the test loss of step 157: 326.4438648873121.
# Compiling calculate_test_loss ...
# The training loss of step 158: 752.5017893093668; the test loss of step 158: 326.1912497034986.
# Compiling calculate_test_loss ...
# The training loss of step 159: 752.1616995382435; the test loss of step 159: 325.8895039368366.
# Compiling calculate_test_loss ...
# The training loss of step 160: 751.8178118902761; the test loss of step 160: 325.6300096418221.
# Compiling calculate_test_loss ...
# The training loss of step 161: 751.4961171821188; the test loss of step 161: 325.32316083245234.
# Compiling calculate_test_loss ...
# The training loss of step 162: 751.1248723093695; the test loss of step 162: 325.02710039110315.
# Compiling calculate_test_loss ...
# The training loss of step 163: 750.7220375288234; the test loss of step 163: 324.69725042256715.
# Compiling calculate_test_loss ...
# The training loss of step 164: 750.3029740657787; the test loss of step 164: 324.33195162341514.
# Compiling calculate_test_loss ...
# The training loss of step 165: 749.7093624564682; the test loss of step 165: 323.9147140456955.
# Compiling calculate_test_loss ...
# The training loss of step 166: 749.2654717515355; the test loss of step 166: 323.5045047308984.
# Compiling calculate_test_loss ...
# The training loss of step 167: 748.7908797175193; the test loss of step 167: 323.1002283972322.
# Compiling calculate_test_loss ...
# The training loss of step 168: 748.3281444122867; the test loss of step 168: 322.7634277770324.
# Compiling calculate_test_loss ...
# The training loss of step 169: 747.7527793457227; the test loss of step 169: 322.4401900795925.
# Compiling calculate_test_loss ...
# The training loss of step 170: 747.1581645555777; the test loss of step 170: 322.1857640614958.
# Compiling calculate_test_loss ...
# The training loss of step 171: 746.7521213162761; the test loss of step 171: 322.09700657455994.
# Compiling calculate_test_loss ...
# The training loss of step 172: 746.3705227971748; the test loss of step 172: 322.1102714972269.
# Compiling calculate_test_loss ...
# The training loss of step 173: 746.0778929307647; the test loss of step 173: 322.1186605629667.
# Compiling calculate_test_loss ...
# The training loss of step 174: 745.7876686423282; the test loss of step 174: 322.09675138553524.
# Compiling calculate_test_loss ...
# The training loss of step 175: 745.5099258610232; the test loss of step 175: 322.0300347488779.
# Compiling calculate_test_loss ...
# The training loss of step 176: 745.1977008445399; the test loss of step 176: 322.02101093642307.
# Compiling calculate_test_loss ...
# The training loss of step 177: 744.9800123715372; the test loss of step 177: 321.9151823865536.
# Compiling calculate_test_loss ...
# The training loss of step 178: 744.7561121743203; the test loss of step 178: 321.7328314663506.
# Compiling calculate_test_loss ...
# The training loss of step 179: 744.4826269389563; the test loss of step 179: 321.49621139828145.
# Compiling calculate_test_loss ...
# The training loss of step 180: 744.0887912642979; the test loss of step 180: 321.18982332825334.
# Compiling calculate_test_loss ...
# The training loss of step 181: 743.7309150488838; the test loss of step 181: 320.86852317932266.
# Compiling calculate_test_loss ...
# The training loss of step 182: 743.3262377564381; the test loss of step 182: 320.5200228569512.
# Compiling calculate_test_loss ...
# The training loss of step 183: 742.9317704241704; the test loss of step 183: 320.10784773702153.
# Compiling calculate_test_loss ...
# The training loss of step 184: 742.4629592863066; the test loss of step 184: 319.648299243294.
# Compiling calculate_test_loss ...
# The training loss of step 185: 741.9709084896357; the test loss of step 185: 319.27275590162503.
# Compiling calculate_test_loss ...
# The training loss of step 186: 741.4855165661579; the test loss of step 186: 318.9939428764374.
# Compiling calculate_test_loss ...
# The training loss of step 187: 741.044959377497; the test loss of step 187: 318.83273242720674.
# Compiling calculate_test_loss ...
# The training loss of step 188: 740.6182370909081; the test loss of step 188: 318.77702119233277.
# Compiling calculate_test_loss ...
# The training loss of step 189: 740.2112019209364; the test loss of step 189: 318.7794010203108.
# Compiling calculate_test_loss ...
# The training loss of step 190: 739.8597668484144; the test loss of step 190: 318.7796793675923.
# Compiling calculate_test_loss ...
# The training loss of step 191: 739.5017615823865; the test loss of step 191: 318.9813897048552.
# Compiling calculate_test_loss ...
# The training loss of step 192: 739.1446547197233; the test loss of step 192: 319.15929682435836.
# Compiling calculate_test_loss ...
# The training loss of step 193: 738.8464399898648; the test loss of step 193: 319.4122934735807.
# Compiling calculate_test_loss ...
# The training loss of step 194: 738.6226804233095; the test loss of step 194: 319.59097382704846.
# Compiling calculate_test_loss ...
# The training loss of step 195: 738.4692219429194; the test loss of step 195: 319.72014854732316.
# Compiling calculate_test_loss ...
# The training loss of step 196: 738.2272180323585; the test loss of step 196: 319.78107092173866.
# Compiling calculate_test_loss ...
# The training loss of step 197: 737.9996687961839; the test loss of step 197: 319.7106726713911.
# Compiling calculate_test_loss ...
# The training loss of step 198: 737.8070092597832; the test loss of step 198: 319.4616100398933.
# Compiling calculate_test_loss ...
# The training loss of step 199: 737.5565178878664; the test loss of step 199: 319.1426206601212.
# Compiling calculate_test_loss ...
# The training loss of step 200: 737.355515666442; the test loss of step 200: 318.96172524943586.
# Compiling calculate_test_loss ...
# The training loss of step 201: 737.284720541971; the test loss of step 201: 318.75128139592846.
# Compiling calculate_test_loss ...
# The training loss of step 202: 737.1902777801984; the test loss of step 202: 318.5152372500381.
# Compiling calculate_test_loss ...
# The training loss of step 203: 737.1272888009881; the test loss of step 203: 318.25199821214164.
# Compiling calculate_test_loss ...
# The training loss of step 204: 737.1349756488094; the test loss of step 204: 317.97258660126346.
# Compiling calculate_test_loss ...
# The training loss of step 205: 737.1054225430931; the test loss of step 205: 317.6760941907601.
# Compiling calculate_test_loss ...
# The training loss of step 206: 737.0493758003528; the test loss of step 206: 317.3736306875455.
# Compiling calculate_test_loss ...
# The training loss of step 207: 736.9812447424483; the test loss of step 207: 316.966958319619.
# Compiling calculate_test_loss ...
# The training loss of step 208: 736.8498996281207; the test loss of step 208: 316.56681636159294.
# Compiling calculate_test_loss ...
# The training loss of step 209: 736.8053570146326; the test loss of step 209: 316.2115674706768.
# Compiling calculate_test_loss ...
# The training loss of step 210: 736.7694972272238; the test loss of step 210: 315.8730157638796.
# Compiling calculate_test_loss ...
# The training loss of step 211: 736.6988105562364; the test loss of step 211: 315.51026284577614.
# Compiling calculate_test_loss ...
# The training loss of step 212: 736.6468545456019; the test loss of step 212: 315.1685314292524.
# Compiling calculate_test_loss ...
# The training loss of step 213: 736.5436223688885; the test loss of step 213: 314.86526033940174.
# Compiling calculate_test_loss ...
# The training loss of step 214: 736.4619682217744; the test loss of step 214: 314.5333362949773.
# Compiling calculate_test_loss ...
# The training loss of step 215: 736.3428513152244; the test loss of step 215: 314.14080127218614.
# Compiling calculate_test_loss ...
# The training loss of step 216: 736.2180098537675; the test loss of step 216: 313.8140621760609.
# Compiling calculate_test_loss ...
# The training loss of step 217: 736.1118568395207; the test loss of step 217: 313.51533450892987.
# Compiling calculate_test_loss ...
# The training loss of step 218: 735.953526335742; the test loss of step 218: 313.14774856687376.
# Compiling calculate_test_loss ...
# The training loss of step 219: 735.8158060482897; the test loss of step 219: 312.8896066386837.
# Compiling calculate_test_loss ...
# The training loss of step 220: 735.684674121705; the test loss of step 220: 312.69859560174007.
# Compiling calculate_test_loss ...
# The training loss of step 221: 735.6912612450581; the test loss of step 221: 312.5360517791526.
# Compiling calculate_test_loss ...
# The training loss of step 222: 735.7227315935766; the test loss of step 222: 312.4895420587771.
# Compiling calculate_test_loss ...
# The training loss of step 223: 735.8519545329768; the test loss of step 223: 312.50189006877395.
# Compiling calculate_test_loss ...
# The training loss of step 224: 736.0113655797868; the test loss of step 224: 312.57129326147543.
# Compiling calculate_test_loss ...
# The training loss of step 225: 736.0995170036122; the test loss of step 225: 312.5963887361177.
# Compiling calculate_test_loss ...
# The training loss of step 226: 736.2017002984753; the test loss of step 226: 312.56501976011793.
# Compiling calculate_test_loss ...
# The training loss of step 227: 736.2157106764968; the test loss of step 227: 312.6394028172293.
# Compiling calculate_test_loss ...
# The training loss of step 228: 736.293980273635; the test loss of step 228: 312.6819370656257.
# Compiling calculate_test_loss ...
# The training loss of step 229: 736.347674915385; the test loss of step 229: 312.5365757498932.
# Compiling calculate_test_loss ...
# The training loss of step 230: 736.3157717998341; the test loss of step 230: 312.411497793329.
# Compiling calculate_test_loss ...
# The training loss of step 231: 736.2825490401727; the test loss of step 231: 312.30488676218107.
# Compiling calculate_test_loss ...
# The training loss of step 232: 736.3427223377037; the test loss of step 232: 312.1987884367001.
# Compiling calculate_test_loss ...
# The training loss of step 233: 736.3781859159806; the test loss of step 233: 312.10435998101735.
# Compiling calculate_test_loss ...
# The training loss of step 234: 736.4316650726191; the test loss of step 234: 311.99652766420013.
# Compiling calculate_test_loss ...
# The training loss of step 235: 736.4859606642516; the test loss of step 235: 311.8589977920686.
# Compiling calculate_test_loss ...
# The training loss of step 236: 736.4854698070494; the test loss of step 236: 311.76487715783145.
# Compiling calculate_test_loss ...
# The training loss of step 237: 736.5026398216554; the test loss of step 237: 311.60264490584314.
# Compiling calculate_test_loss ...
# The training loss of step 238: 736.5964340852329; the test loss of step 238: 311.460981096564.
# Compiling calculate_test_loss ...
# The training loss of step 239: 736.716465801183; the test loss of step 239: 311.2241081513263.
# Compiling calculate_test_loss ...
# The training loss of step 240: 736.7765958279417; the test loss of step 240: 310.9912470339168.
# Compiling calculate_test_loss ...
# The training loss of step 241: 736.8466242724778; the test loss of step 241: 310.6982573945947.
# Compiling calculate_test_loss ...
# The training loss of step 242: 736.8120523522512; the test loss of step 242: 310.26231615043883.
# Compiling calculate_test_loss ...
# The training loss of step 243: 736.7456171978579; the test loss of step 243: 309.8887838967444.
# Compiling calculate_test_loss ...
# The training loss of step 244: 736.6580651883869; the test loss of step 244: 309.54006801416915.
# Compiling calculate_test_loss ...
# The training loss of step 245: 736.5866736053229; the test loss of step 245: 309.14055132104676.
# Compiling calculate_test_loss ...
# The training loss of step 246: 736.4825871040211; the test loss of step 246: 308.8444267120868.
# Compiling calculate_test_loss ...
# The training loss of step 247: 736.4571937462449; the test loss of step 247: 308.63296817030204.
# Compiling calculate_test_loss ...
# The training loss of step 248: 736.4853819452018; the test loss of step 248: 308.3593361013312.
# Compiling calculate_test_loss ...
# The training loss of step 249: 736.4782073097081; the test loss of step 249: 308.1147891260001.
# Compiling calculate_test_loss ...
# The training loss of step 250: 736.5412774240017; the test loss of step 250: 307.9460088569496.
# Compiling calculate_test_loss ...
# The training loss of step 251: 736.5963562564277; the test loss of step 251: 307.87348556071083.
# Compiling calculate_test_loss ...
# The training loss of step 252: 736.668096706311; the test loss of step 252: 307.7182939297298.
# Compiling calculate_test_loss ...
# The training loss of step 253: 736.7837191685069; the test loss of step 253: 307.70632514647207.
# Compiling calculate_test_loss ...
# The training loss of step 254: 736.9286261320128; the test loss of step 254: 307.7695336272579.
# Compiling calculate_test_loss ...
# The training loss of step 255: 737.1300734819545; the test loss of step 255: 307.7459220750162.
# Compiling calculate_test_loss ...
# The training loss of step 256: 737.2639218297396; the test loss of step 256: 307.69100526225054.
# Compiling calculate_test_loss ...
# The training loss of step 257: 737.2948646180985; the test loss of step 257: 307.5188810146585.
# Compiling calculate_test_loss ...
# The training loss of step 258: 737.2772804188176; the test loss of step 258: 307.294502949126.
# Compiling calculate_test_loss ...
# The training loss of step 259: 737.2454227366031; the test loss of step 259: 306.8942342869138.
# Compiling calculate_test_loss ...
# The training loss of step 260: 737.1731844501883; the test loss of step 260: 306.4319096596191.
# Compiling calculate_test_loss ...
# The training loss of step 261: 737.0365264377763; the test loss of step 261: 305.88892768985403.
# Compiling calculate_test_loss ...
# The training loss of step 262: 736.9104755495663; the test loss of step 262: 305.33765062382037.
# Compiling calculate_test_loss ...
# The training loss of step 263: 736.833915123224; the test loss of step 263: 304.9209482584698.
# Compiling calculate_test_loss ...
# The training loss of step 264: 736.7193643626978; the test loss of step 264: 304.5802931208773.
# Compiling calculate_test_loss ...
# The training loss of step 265: 736.6735781161375; the test loss of step 265: 304.37327009163516.
# Compiling calculate_test_loss ...
# The training loss of step 266: 736.6749976536289; the test loss of step 266: 304.40130719943113.
# Compiling calculate_test_loss ...
# The training loss of step 267: 736.8628995512413; the test loss of step 267: 304.5705583967111.
# Compiling calculate_test_loss ...
# The training loss of step 268: 737.1629206520454; the test loss of step 268: 304.87667278214633.
# Compiling calculate_test_loss ...
# The training loss of step 269: 737.4757773686463; the test loss of step 269: 305.5583336963916.
# Compiling calculate_test_loss ...
# The training loss of step 270: 737.900094058858; the test loss of step 270: 306.3302473544698.
# Compiling calculate_test_loss ...
# The training loss of step 271: 738.3719172622514; the test loss of step 271: 306.9952136763194.
# Compiling calculate_test_loss ...
# The training loss of step 272: 738.7911894571209; the test loss of step 272: 307.49790764265776.
# Compiling calculate_test_loss ...
# The training loss of step 273: 739.165530569579; the test loss of step 273: 307.9695156256467.
# Compiling calculate_test_loss ...
# The training loss of step 274: 739.6244966285258; the test loss of step 274: 308.35222502563147.
# Compiling calculate_test_loss ...
# The training loss of step 275: 739.9807154180138; the test loss of step 275: 308.5574279069581.
# Compiling calculate_test_loss ...
# The training loss of step 276: 740.2113779293959; the test loss of step 276: 308.6989735583057.
# Compiling calculate_test_loss ...
# The training loss of step 277: 740.3105497362941; the test loss of step 277: 308.5446041036768.
# Compiling calculate_test_loss ...
# The training loss of step 278: 740.3569420144058; the test loss of step 278: 308.29670973096603.
# Compiling calculate_test_loss ...
# The training loss of step 279: 740.2881092777577; the test loss of step 279: 307.95170750032577.
# Compiling calculate_test_loss ...
# The training loss of step 280: 740.1609457962596; the test loss of step 280: 307.5532999033479.
# Compiling calculate_test_loss ...
# The training loss of step 281: 740.0315318190458; the test loss of step 281: 306.96350932003224.
# Compiling calculate_test_loss ...
# The training loss of step 282: 739.8784501201271; the test loss of step 282: 306.5189892878987.
# Compiling calculate_test_loss ...
# The training loss of step 283: 739.66410269269; the test loss of step 283: 306.23708507628925.
# Compiling calculate_test_loss ...
# The training loss of step 284: 739.4996176517843; the test loss of step 284: 306.2570969037584.
# Compiling calculate_test_loss ...
# The training loss of step 285: 739.5203032615445; the test loss of step 285: 306.4689479281521.
# Compiling calculate_test_loss ...
# The training loss of step 286: 739.656718016711; the test loss of step 286: 306.89313910844777.
# Compiling calculate_test_loss ...
# The training loss of step 287: 739.9165317094125; the test loss of step 287: 307.30665435608455.
# Compiling calculate_test_loss ...
# The training loss of step 288: 740.1743599477683; the test loss of step 288: 307.5754292184223.
# Compiling calculate_test_loss ...
# The training loss of step 289: 740.4870280048863; the test loss of step 289: 307.84833347119604.
# Compiling calculate_test_loss ...
# The training loss of step 290: 740.6763286635996; the test loss of step 290: 307.9379875959307.
# Compiling calculate_test_loss ...
# The training loss of step 291: 740.7565857361067; the test loss of step 291: 308.08963029388514.
# Compiling calculate_test_loss ...
# The training loss of step 292: 740.8855106289313; the test loss of step 292: 308.3499800275028.
# Compiling calculate_test_loss ...
# The training loss of step 293: 741.0551170709176; the test loss of step 293: 308.6938877852493.
# Compiling calculate_test_loss ...
# The training loss of step 294: 741.2448739494844; the test loss of step 294: 309.42686853963573.
# Compiling calculate_test_loss ...
# The training loss of step 295: 741.5239207744826; the test loss of step 295: 310.3173078444543.
# Compiling calculate_test_loss ...
# The training loss of step 296: 741.7939158333186; the test loss of step 296: 310.9395132442245.
# Compiling calculate_test_loss ...
# The training loss of step 297: 742.0421469989406; the test loss of step 297: 311.6338856863205.
# Compiling calculate_test_loss ...
# The training loss of step 298: 742.2969519551166; the test loss of step 298: 312.2537368248748.
# Compiling calculate_test_loss ...
# The training loss of step 299: 742.5513876299632; the test loss of step 299: 312.68581607702174.

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.plot(loss_train_set, label='Train')
ax.plot(loss_test_set, label='Test')
ax.set(xlabel="Epochs", ylabel="L2", title="Loss function", yscale="linear");
ax.legend()

# %% [markdown]
# ## Rerun the model using the estimated parameters

# %% [markdown]
# ### Calibration period

# %%
states, drivers = canoak_eqx_new(met)
(
    met_new,
    prof_new,
    ir_new,
    qin_new,
    sun_new,
    shade_new,
    soil_new,
    veg_new,
    can_new,
) = states
# quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
plot_obs_comparison(obs, can_new);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can_new.LE,
    lim=[-100, 400],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %% [markdown]
# ### Test period

# %%
states_test, drivers_test = canoak_eqx_new(met_test)
(
    _,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test

# %%
plot_obs_comparison(obs_test, can_test);

# %%
plot_timeseries_obs_1to1(
    obs_test.LE,
    can_test.LE,
    lim=[-100, 200],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
);

# %%
metrics = compute_metrics(obs.LE, can_new.LE)
metrics_test = compute_metrics(obs_test.LE, can_test.LE)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 27.25387010725419, 'mse': 742.7734358230836, 'r2': 0.2515606813402831, 'kge': 0.2982986969447018, 'nse': -0.2477427864334496, 'mkge': 0.3466537760708459, 'cc': 0.6020320073425511, 'alpha': 1.499224222886563, 'beta': 0.8612270183861707}
# {'rmse': 17.68292442094977, 'mse': 312.6858160770218, 'r2': -0.21685411635809104, 'kge': 0.486625225930727, 'nse': 0.2076286725341353, 'mkge': 0.5191577199702799, 'cc': 0.5430305120539805, 'alpha': 0.8678517440290205, 'beta': 0.9298214862343117}

# %% [markdown]
# # Save the models

# %%
config = {
    "site": site,
    "key": key,
    "f_forcing": f_forcing,
    "f_obs": f_obs,
    "f_forcing_test": f_forcing_test,
    "f_obs_test": f_obs_test,
}

train = {
    "loss": loss_train_set,
    "time": timesteps,
    "can.LE": can_new.LE,
    "sun.gs": sun_new.gs,
    "shade.gs": shade_new.gs,
    "sun.Ps": sun_new.Ps,
    "shade.Ps": shade_new.Ps,
    "can.H": can_new.H,
    "can.rnet": can_new.rnet,
    "can.gsoil": can_new.gsoil,
    "sun.Tlk": sun_new.Tsfc,
    "shade.Tlk": shade_new.Tsfc,
    "sun.Leaf_RH": sun_new.Leaf_RH,
    "shade.Leaf_RH": shade_new.Leaf_RH,
    "soil.Tsoil": soil_new.T_soil,
}

test = {
    "loss": loss_test_set,
    "time": timesteps_test,
    "can.LE": can_test.LE,
    "sun.gs": sun_test.gs,
    "shade.gs": shade_test.gs,
    "sun.Ps": sun_test.Ps,
    "shade.Ps": shade_test.Ps,
    "can.H": can_test.H,
    "can.rnet": can_test.rnet,
    "can.gsoil": can_test.gsoil,
    "sun.Tlk": sun_test.Tsfc,
    "shade.Tlk": shade_test.Tsfc,
    "sun.Leaf_RH": sun_test.Leaf_RH,
    "shade.Leaf_RH": shade_test.Leaf_RH,
    "soil.Tsoil": soil_test.T_soil,
}

out = {"train": train, "test": test, "config": config}
pickle.dump(out, open(f"{site}_{key}.pkl", "wb"), pickle.HIGHEST_PROTOCOL)

# %%
# Save the model
hyperparams = dict(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    niter=niter,
)

save_model(f_model, hyperparams, canoak_eqx_new)
