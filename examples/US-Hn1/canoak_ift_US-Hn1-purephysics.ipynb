# %% [markdown]
# This notebook is used to run JAX-CANOAK in US-Hn1 site.

# %% [markdown]
# # Load the necessary libraries

# %%
# # TODO: A more generic way is needed here to load the path
# import sys

# sys.path.append(
#     "/Users/jian449/Library/CloudStorage/OneDrive-PNNL/Codes/jax-watershed/src"
#     # "/global/homes/p/peishi89/jax-watershed/src"
# )

# %%
import optax
import equinox as eqx

import pickle
from functools import partial

from math import floor

# import numpy as np
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import pandas as pd

from jax_canoak.physics.energy_fluxes import get_dispersion_matrix

from jax_canoak.models import CanoakIFT
from jax_canoak.models import get_canle, update_canle
from jax_canoak.models import get_soilresp, update_soilresp
from jax_canoak.models import load_model, save_model
# from jax_canoak.models import run_canoak_in_batch

# from jax_canoak.shared_utilities.optim import perform_optimization
from jax_canoak.shared_utilities.optim import perform_optimization_batch, mse
from jax_canoak.shared_utilities import compute_metrics
from jax_canoak.subjects import convert_met_to_batched_met
from jax_canoak.subjects import (
    # convert_batchedstates_to_states,
    convert_obs_to_batched_obs,
)
from jax_canoak.subjects import get_met_forcings, get_obs, initialize_parameters


import matplotlib.pyplot as plt
from jax_canoak.shared_utilities.plot import (
    plot_daily,
    plot_imshow2,
    plot_timeseries_obs_1to1,
    plot_rad,
    plot_ir,
    visualize_tree_diff,
)
from jax_canoak.shared_utilities.plot import (
    plot_obs_1to1,
    plot_obs_comparison,
    plot_obs_energy_closure,
    plot_dij,
    plot_para_sensitivity_ranking,
    plot_le_gs_lai,
    get_time,
)

# from jax_canoak.shared_utilities.plot import plot_veg_temp, plot_dij
# from jax_canoak.shared_utilities.plot import plot_ir, plot_rad, plot_prof2
from jax_canoak.shared_utilities import tune_jax_naninfs_for_debug

jax.config.update("jax_enable_x64", True)
tune_jax_naninfs_for_debug(False)
# jax.config.update("jax_debug_nans", False)
# jax.config.update("jax_debug_infs", False)
# jax.config.update("XLA_PYTHON_CLIENT_ALLOCATOR", 'platform')

# %load_ext autoreload
# %autoreload 2

# %%
# import os
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="FALSE"

# %% [markdown]
# # Model parameters and settings

# %%
time_zone = -8
latitude = 46.4089
longitude = -119.2750
stomata = 0
veg_ht = 1.2
leafangle = 2  # erectophile
n_can_layers = 50
n_atmos_layers = 50
meas_ht = 5.0
soil_depth = 0.15
n_hr_per_day = 48
niter = 15
# niter = 1

# batch_size = 2
# batch_size = 1274
# batch_size = int(27744/2)
batch_size, batch_size_test = int(27744/2), None

site = "US-Hn1"
key = "purephysics"

# Calibration period
f_forcing = f"../../data/fluxtower/{site}/{site}-forcings-v2.csv"
# f_obs = "../../data/fluxtower/US-Hn1/US-Hn1-fluxes.csv"
f_obs = f"../../data/fluxtower/{site}/{site}-fluxes-nonegle-v2.csv"

# Test period
f_forcing_test = f"../../data/fluxtower/{site}/{site}-forcings-test-v2.csv"
f_obs_test = f"../../data/fluxtower/{site}/{site}-fluxes-nonegle-test-v2.csv"

# Models
f_model = f"{site}_{key}_model.eqx"
# f_model_new = f"{site}_{key}_model.eqx"

# %% [markdown]
# # Load and set the model forcings

# %%
# Training
met, n_time = get_met_forcings(f_forcing)
if batch_size is None: batch_size = n_time
n_batch = floor(n_time / batch_size)
batched_met = convert_met_to_batched_met(met, n_batch, batch_size)
timesteps = get_time(met)

# %%
# Test
met_test, n_time_test = get_met_forcings(f_forcing_test)
if batch_size_test is None: batch_size_test = n_time_test
n_batch_test = floor(n_time_test / batch_size_test)
batched_met_test = convert_met_to_batched_met(met_test, n_batch_test, batch_size_test)
timesteps_test = get_time(met_test)

# %%
plt.plot(met.soilmoisture)

# %% [markdown]
# # Load the observations

# %%
# Training
obs = get_obs(f_obs)

# Test
obs_test = get_obs(f_obs_test)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/subjects/initialization_update.py:270: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   obs.interpolate(method="linear", limit_direction="both", inplace=True)

# %% [markdown]
# # Create the model parameter instance

# %%
setup, para, para_min, para_max = initialize_parameters(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    obs=obs,
    met=met,
    niter=niter,
    get_para_bounds=True,
)

# %% [markdown]
# # Generate or read the dispersion matrix

# %%
# dij = get_dispersion_matrix(setup, para)
dij = get_dispersion_matrix(setup, para, f"../../data/dij/Dij_{site}.csv")
# import numpy as np
# np.savetxt(f"../../data/dij/Dij_{site}.csv", np.array(dij), delimiter=',')

# %%
plot_dij(dij, para)
# Out:
# <Axes: xlabel='Dij [s/m]', ylabel='Height [m]'>

# %% [markdown]
# # Run CANOAK!

# %%
jax.clear_caches()
canoak_eqx_ift = CanoakIFT(para, setup, dij)

# %%
# Training data
# met, prof, ir, qin, sun, shade, soil, veg, can = canoak_eqx_ift(met)
states, drivers = canoak_eqx_ift(met)
met, prof, ir, qin, sun, shade, soil, veg, can = states
quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
# Test data
states_test, drivers_test = canoak_eqx_ift(met_test)
met_test, prof_test, ir_test, qin_test, sun_test, shade_test, soil_test, veg_test, can_test = states_test
quantum_test, nir_test, rnet_test, sun_ang_test, leaf_ang_test, lai_test = drivers_test

# %%
# Leaf relative humidity
plot_imshow2(
    sun.Leaf_RH.T,
    met,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)

plot_imshow2(
    sun_test.Leaf_RH.T,
    met_test,
    para.zht1,
    key="T",
    title="Leaf relative humidity [-]",
    cmap="Blues",
)
# Out:
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
# /global/homes/p/peishi89/jax-watershed/src/jax_canoak/shared_utilities/plot.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")

# %%
# Daily average
plot_daily(met, soil, veg, para);
plot_daily(met_test, soil_test, veg_test, para);

# %%
# Analyze nan
nanind = jnp.where(jnp.isnan(prof.Tair_K.mean(axis=1)))

met.lai[nanind]
# qin.sun_abs[nanind]
# ir.ir_in[nanind]
sun.Tsfc[nanind, :]
# Out:
# Array([], dtype=float64)

# %% [markdown]
# # Local sensitivity analysis

# %%
jax.clear_caches()


@eqx.filter_jit
@partial(jax.grad, argnums=0)
def df_canoak_le(para, met, canoak_eqx):
    canoak_eqx = eqx.tree_at(lambda t: t.para, canoak_eqx, para)
    can_le = canoak_eqx.get_fixed_point_states(met, update_canle, get_canle)
    # met, update_soilresp, get_soilresp)
    return can_le.sum()


@eqx.filter_jit
def df_canoak_le_batched(para, batched_met, canoak_eqx):
    def compute_grad(para, met):
        grad = df_canoak_le(para, met, canoak_eqx)
        return para, grad

    _, gradients = jax.lax.scan(compute_grad, para, xs=batched_met)
    return gradients


# eqx.filter_make_jaxpr(df_canoak_le3)(para, met, canoak_eqx)

# %% [markdown]
# ## Perform SA at one time step

# %%
start, ntime = 20, 1
met2 = jtu.tree_map(lambda x: x[start : start + ntime], met)

# %%
gradients = df_canoak_le(para, met2, canoak_eqx_ift)

# %%
gradients.lleaf
# Out:
# Array(-20.70639241, dtype=float64, weak_type=True)

# %% [markdown]
# ## Perform SA at multiple steps

# %%
jax.clear_caches()
batched_met_sa = convert_met_to_batched_met(met, n_time, 1)
gradients = df_canoak_le_batched(para, batched_met_sa, canoak_eqx_ift)

# %%
plot_para_sensitivity_ranking(gradients, category="photosyn")
# plot_para_sensitivity_ranking(gradients, category=None)

# %%
# gm = jtu.tree_map(lambda x:x.mean(), gradients)
# a, b = jtu.tree_flatten(gm)

# %%
# bb = b.node_data()[1]
# names = bb.dynamic_field_names

# %% [markdown]
# # Comparison with the observations

# %%
plot_obs_energy_closure(obs)
# Out:
# <Axes: xlabel='Rnet, measured', ylabel='H+LE+Gsoil, measured'>

# %%
plot_obs_1to1(obs.rnet, can.rnet, lim=[-50, 800], varn="Rnet")
# Out:
# <Axes: title={'center': 'Rnet (L2: 1371.509)'}, xlabel='Measured', ylabel='Simulated'>

# %%
plot_timeseries_obs_1to1(
    obs.rnet,
    can.rnet,
    lim=[-100, 800],
    met=met,
    varn="Net radiation [W m-2]",
);

# %%
# plt.figure(0)
# plt.plot(obs.P)
# plt.figure(1)
# plt.plot(obs.Rsoil)
# plt.figure(1)
# plt.plot(soil.resp)

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can.LE,
    lim=[-100, 1000],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %%
plot_timeseries_obs_1to1(
    obs.H,
    can.H,
    lim=[-100, 800],
    met=met,
    varn="Sensible heat fluxes [W m-2]",
);

# %%
plot_obs_comparison(obs, can);

# %% [markdown]
# # Perform parameter estimation

# %%
# Filter the parameters to be estimated
filter_model_spec = jtu.tree_map(lambda _: False, canoak_eqx_ift)
filter_model_spec = eqx.tree_at(
    lambda t: (
        t.para.bprime,
        # t.para.ep,
        t.para.lleaf,
        t.para.qalpha,
        t.para.kball,
        # t.para.leaf_clumping_factor,
    ),
    filter_model_spec,
    replace=(True, True, True, True),
)

# %%
# Define optimizer and observations
args = [update_canle, get_canle]
# nsteps = 5  # number of epoches
nsteps = 300  # number of epoches
# nsteps = 100  # number of epoches
batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE
scheduler = optax.piecewise_constant_schedule(
    0.01, boundaries_and_scales={50: 0.5, 100: 0.5, 200: 0.5}
)
# scheduler = optax.exponential_decay(0.01, transition_steps=30, decay_rate=0.1)
# optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
optim = optax.adam(learning_rate=scheduler)  # Adam optimizer
# optim = optax.adam(learning_rate=0.01)  # Adam optimizer

batched_obs = convert_obs_to_batched_obs(obs, n_batch, batch_size)
batched_y = batched_obs.LE

batched_obs_test = convert_obs_to_batched_obs(obs_test, n_batch_test, batch_size_test)
batched_y_test = batched_obs_test.LE

# %%
# jax.clear_caches()
args = [update_canle, get_canle]
canoak_eqx_new, loss_train_set, loss_test_set = perform_optimization_batch(
    canoak_eqx_ift.get_fixed_point_states,
    filter_model_spec.get_fixed_point_states,
    optim,
    nsteps,
    mse,
    batched_y,
    batched_met,
    batched_y_test,
    batched_met_test,
    para_min,
    para_max,
    *args,
)
# canoak_eqx_new = canoak_eqx_new.args[0]
canoak_eqx_new = canoak_eqx_new.__self__
# Out:
# Argument model is triggering a compile.
# Argument filter_model_spec is triggering a compile.
# Argument batched_y is triggering a compile.
# Argument opt_state is triggering a compile.
# Argument batched_met is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 0: 13099.478975079433; the test loss of step 0: 14942.450743518439.
# Argument model is triggering a compile.
# Argument opt_state is triggering a compile.
# Compiling make_step ...
# Compiling calculate_test_loss ...
# The training loss of step 1: 9878.826060233288; the test loss of step 1: 10204.110588290956.
# Compiling calculate_test_loss ...
# The training loss of step 2: 6714.080713104646; the test loss of step 2: 6036.506881697305.
# Compiling calculate_test_loss ...
# The training loss of step 3: 3986.6474516039707; the test loss of step 3: 2738.302295374163.
# Compiling calculate_test_loss ...
# The training loss of step 4: 1927.1972167061422; the test loss of step 4: 817.9484950205119.
# Compiling calculate_test_loss ...
# The training loss of step 5: 1116.4722355245035; the test loss of step 5: 680.6691163705937.
# Compiling calculate_test_loss ...
# The training loss of step 6: 1106.830625571669; the test loss of step 6: 619.488173905868.
# Compiling calculate_test_loss ...
# The training loss of step 7: 1085.5659575172308; the test loss of step 7: 567.6508322443696.
# Compiling calculate_test_loss ...
# The training loss of step 8: 1068.9945172015841; the test loss of step 8: 523.87950145535.
# Compiling calculate_test_loss ...
# The training loss of step 9: 1056.1116438188278; the test loss of step 9: 486.3923993977744.
# Compiling calculate_test_loss ...
# The training loss of step 10: 1046.1775506187607; the test loss of step 10: 453.9653710044004.
# Compiling calculate_test_loss ...
# The training loss of step 11: 1038.704503987007; the test loss of step 11: 426.0829100724262.
# Compiling calculate_test_loss ...
# The training loss of step 12: 1033.2630545163895; the test loss of step 12: 402.1662527977692.
# Compiling calculate_test_loss ...
# The training loss of step 13: 1029.4375906076614; the test loss of step 13: 381.4871456873678.
# Compiling calculate_test_loss ...
# The training loss of step 14: 1027.0207075880348; the test loss of step 14: 367.84602520731545.
# Compiling calculate_test_loss ...
# The training loss of step 15: 1007.8154479483502; the test loss of step 15: 376.1112998519773.
# Compiling calculate_test_loss ...
# The training loss of step 16: 971.8276834591286; the test loss of step 16: 409.32756637987114.
# Compiling calculate_test_loss ...
# The training loss of step 17: 925.4822099441761; the test loss of step 17: 501.08363473483706.
# Compiling calculate_test_loss ...
# The training loss of step 18: 905.9164381545575; the test loss of step 18: 624.0293733478726.
# Compiling calculate_test_loss ...
# The training loss of step 19: 920.4328136939503; the test loss of step 19: 732.8143670358472.
# Compiling calculate_test_loss ...
# The training loss of step 20: 947.9787788544999; the test loss of step 20: 788.6251591885007.
# Compiling calculate_test_loss ...
# The training loss of step 21: 964.499871165621; the test loss of step 21: 776.3272005172503.
# Compiling calculate_test_loss ...
# The training loss of step 22: 960.335595168288; the test loss of step 22: 703.8650906908629.
# Compiling calculate_test_loss ...
# The training loss of step 23: 937.2980902715158; the test loss of step 23: 594.4707828827818.
# Compiling calculate_test_loss ...
# The training loss of step 24: 907.4732698675024; the test loss of step 24: 480.2465665110119.
# Compiling calculate_test_loss ...
# The training loss of step 25: 885.8498776625331; the test loss of step 25: 385.1279288407873.
# Compiling calculate_test_loss ...
# The training loss of step 26: 880.7603300089205; the test loss of step 26: 322.9686607358774.
# Compiling calculate_test_loss ...
# The training loss of step 27: 889.5214481340547; the test loss of step 27: 291.19919799204763.
# Compiling calculate_test_loss ...
# The training loss of step 28: 900.7403377543694; the test loss of step 28: 281.4468067944693.
# Compiling calculate_test_loss ...
# The training loss of step 29: 903.3167781158614; the test loss of step 29: 290.37524395324346.
# Compiling calculate_test_loss ...
# The training loss of step 30: 895.613929866085; the test loss of step 30: 319.0149632427565.
# Compiling calculate_test_loss ...
# The training loss of step 31: 884.0723715241011; the test loss of step 31: 366.9328776369076.
# Compiling calculate_test_loss ...
# The training loss of step 32: 877.4146351310874; the test loss of step 32: 424.5362121345125.
# Compiling calculate_test_loss ...
# The training loss of step 33: 879.2289410230255; the test loss of step 33: 477.19197545548207.
# Compiling calculate_test_loss ...
# The training loss of step 34: 886.105413143767; the test loss of step 34: 509.88294965675004.
# Compiling calculate_test_loss ...
# The training loss of step 35: 892.54210261146; the test loss of step 35: 514.2125838829976.
# Compiling calculate_test_loss ...
# The training loss of step 36: 893.9000629545034; the test loss of step 36: 490.67291064130706.
# Compiling calculate_test_loss ...
# The training loss of step 37: 889.941829119791; the test loss of step 37: 448.15651927851155.
# Compiling calculate_test_loss ...
# The training loss of step 38: 883.793392536734; the test loss of step 38: 399.2598227342263.
# Compiling calculate_test_loss ...
# The training loss of step 39: 879.5356917185765; the test loss of step 39: 355.3299796218698.
# Compiling calculate_test_loss ...
# The training loss of step 40: 879.2186260315673; the test loss of step 40: 324.1811077954941.
# Compiling calculate_test_loss ...
# The training loss of step 41: 882.1470134540172; the test loss of step 41: 308.3613020851584.
# Compiling calculate_test_loss ...
# The training loss of step 42: 884.9081310317267; the test loss of step 42: 307.8519672162318.
# Compiling calculate_test_loss ...
# The training loss of step 43: 884.9881152178657; the test loss of step 43: 321.4179638837254.
# Compiling calculate_test_loss ...
# The training loss of step 44: 882.5666734759352; the test loss of step 44: 346.5877761269417.
# Compiling calculate_test_loss ...
# The training loss of step 45: 879.7251830605026; the test loss of step 45: 378.8911939911753.
# Compiling calculate_test_loss ...
# The training loss of step 46: 878.7784599410444; the test loss of step 46: 411.0140019297996.
# Compiling calculate_test_loss ...
# The training loss of step 47: 880.1787976175176; the test loss of step 47: 434.8056625933527.
# Compiling calculate_test_loss ...
# The training loss of step 48: 882.2320430505808; the test loss of step 48: 444.2822679289609.
# Compiling calculate_test_loss ...
# The training loss of step 49: 883.1398179424825; the test loss of step 49: 438.05120938389433.
# Compiling calculate_test_loss ...
# The training loss of step 50: 882.0600428335918; the test loss of step 50: 428.66592713878646.
# Compiling calculate_test_loss ...
# The training loss of step 51: 880.8764823337133; the test loss of step 51: 415.0560889006037.
# Compiling calculate_test_loss ...
# The training loss of step 52: 879.5459931945647; the test loss of step 52: 399.1952609812592.
# Compiling calculate_test_loss ...
# The training loss of step 53: 878.3753257940411; the test loss of step 53: 383.97545641967633.
# Compiling calculate_test_loss ...
# The training loss of step 54: 877.7854118595424; the test loss of step 54: 370.7062086866765.
# Compiling calculate_test_loss ...
# The training loss of step 55: 877.7193801466652; the test loss of step 55: 360.9144655200853.
# Compiling calculate_test_loss ...
# The training loss of step 56: 877.9557068251639; the test loss of step 56: 355.2164400204582.
# Compiling calculate_test_loss ...
# The training loss of step 57: 878.279632248568; the test loss of step 57: 354.07376102175715.
# Compiling calculate_test_loss ...
# The training loss of step 58: 878.3491885869776; the test loss of step 58: 357.3573914647828.
# Compiling calculate_test_loss ...
# The training loss of step 59: 878.0756478928722; the test loss of step 59: 364.336243418919.
# Compiling calculate_test_loss ...
# The training loss of step 60: 877.6407804368544; the test loss of step 60: 373.9510517558.
# Compiling calculate_test_loss ...
# The training loss of step 61: 877.4005285751127; the test loss of step 61: 384.8969536652208.
# Compiling calculate_test_loss ...
# The training loss of step 62: 877.2592070297535; the test loss of step 62: 395.88806830752196.
# Compiling calculate_test_loss ...
# The training loss of step 63: 877.3973485622495; the test loss of step 63: 405.7031305564275.
# Compiling calculate_test_loss ...
# The training loss of step 64: 877.689489841588; the test loss of step 64: 413.29187766068924.
# Compiling calculate_test_loss ...
# The training loss of step 65: 878.0312424811146; the test loss of step 65: 417.1921202255555.
# Compiling calculate_test_loss ...
# The training loss of step 66: 878.2232038556513; the test loss of step 66: 417.67429431109304.
# Compiling calculate_test_loss ...
# The training loss of step 67: 878.2074273903211; the test loss of step 67: 414.9921847788617.
# Compiling calculate_test_loss ...
# The training loss of step 68: 878.0347279667345; the test loss of step 68: 409.7446926724846.
# Compiling calculate_test_loss ...
# The training loss of step 69: 877.723669083385; the test loss of step 69: 403.25761707804816.
# Compiling calculate_test_loss ...
# The training loss of step 70: 877.4210810059001; the test loss of step 70: 396.66392766899736.
# Compiling calculate_test_loss ...
# The training loss of step 71: 877.2037030093618; the test loss of step 71: 390.80608028585846.
# Compiling calculate_test_loss ...
# The training loss of step 72: 877.0967803100152; the test loss of step 72: 386.3932758036474.
# Compiling calculate_test_loss ...
# The training loss of step 73: 877.1421366100196; the test loss of step 73: 384.1189013014498.
# Compiling calculate_test_loss ...
# The training loss of step 74: 877.1107087193204; the test loss of step 74: 384.07142225084664.
# Compiling calculate_test_loss ...
# The training loss of step 75: 877.0773639182293; the test loss of step 75: 386.17167626955626.
# Compiling calculate_test_loss ...
# The training loss of step 76: 877.0642379051939; the test loss of step 76: 390.0008843549774.
# Compiling calculate_test_loss ...
# The training loss of step 77: 877.0606095354512; the test loss of step 77: 394.7873696626914.
# Compiling calculate_test_loss ...
# The training loss of step 78: 877.1162398585714; the test loss of step 78: 400.01027854642973.
# Compiling calculate_test_loss ...
# The training loss of step 79: 877.2474792870544; the test loss of step 79: 404.8361093051247.
# Compiling calculate_test_loss ...
# The training loss of step 80: 877.3751326381528; the test loss of step 80: 408.61001312809066.
# Compiling calculate_test_loss ...
# The training loss of step 81: 877.5181083826296; the test loss of step 81: 410.88565859769557.
# Compiling calculate_test_loss ...
# The training loss of step 82: 877.645093119499; the test loss of step 82: 411.3336879066801.
# Compiling calculate_test_loss ...
# The training loss of step 83: 877.6521073072875; the test loss of step 83: 410.2655802562846.
# Compiling calculate_test_loss ...
# The training loss of step 84: 877.6155692535859; the test loss of step 84: 408.0196578108701.
# Compiling calculate_test_loss ...
# The training loss of step 85: 877.5881697325367; the test loss of step 85: 405.0187403469132.
# Compiling calculate_test_loss ...
# The training loss of step 86: 877.3944640102062; the test loss of step 86: 401.9236972985002.
# Compiling calculate_test_loss ...
# The training loss of step 87: 877.2908499119203; the test loss of step 87: 398.94280472992403.
# Compiling calculate_test_loss ...
# The training loss of step 88: 877.2767497086454; the test loss of step 88: 396.8441959696632.
# Compiling calculate_test_loss ...
# The training loss of step 89: 877.331133978201; the test loss of step 89: 395.779997800582.
# Compiling calculate_test_loss ...
# The training loss of step 90: 877.3117621178048; the test loss of step 90: 395.7864535504706.
# Compiling calculate_test_loss ...
# The training loss of step 91: 877.3142441471757; the test loss of step 91: 396.81592254244185.
# Compiling calculate_test_loss ...
# The training loss of step 92: 877.3149989715821; the test loss of step 92: 398.5223698666535.
# Compiling calculate_test_loss ...
# The training loss of step 93: 877.3653909015859; the test loss of step 93: 400.46528157655086.
# Compiling calculate_test_loss ...
# The training loss of step 94: 877.443598619072; the test loss of step 94: 402.533964352895.
# Compiling calculate_test_loss ...
# The training loss of step 95: 877.502879163065; the test loss of step 95: 404.28842758552645.
# Compiling calculate_test_loss ...
# The training loss of step 96: 877.492297201211; the test loss of step 96: 405.5973247796438.
# Compiling calculate_test_loss ...
# The training loss of step 97: 877.5452209054304; the test loss of step 97: 406.2638253830476.
# Compiling calculate_test_loss ...
# The training loss of step 98: 877.6037013390822; the test loss of step 98: 406.12523931974613.
# Compiling calculate_test_loss ...
# The training loss of step 99: 877.6146209630098; the test loss of step 99: 405.2519389466375.
# Compiling calculate_test_loss ...
# The training loss of step 100: 877.625145430681; the test loss of step 100: 404.53784150672334.
# Compiling calculate_test_loss ...
# The training loss of step 101: 877.5611332809417; the test loss of step 101: 403.72233833564883.
# Compiling calculate_test_loss ...
# The training loss of step 102: 877.5735968209408; the test loss of step 102: 402.9775358638241.
# Compiling calculate_test_loss ...
# The training loss of step 103: 877.553217371292; the test loss of step 103: 402.1622738362818.
# Compiling calculate_test_loss ...
# The training loss of step 104: 877.5774034651403; the test loss of step 104: 401.45083059063575.
# Compiling calculate_test_loss ...
# The training loss of step 105: 877.5534766842441; the test loss of step 105: 400.9172870529114.
# Compiling calculate_test_loss ...
# The training loss of step 106: 877.5284957203725; the test loss of step 106: 400.4978308529604.
# Compiling calculate_test_loss ...
# The training loss of step 107: 877.5210176470578; the test loss of step 107: 400.2110166829003.
# Compiling calculate_test_loss ...
# The training loss of step 108: 877.5295462919867; the test loss of step 108: 400.1606985209381.
# Compiling calculate_test_loss ...
# The training loss of step 109: 877.5577288811587; the test loss of step 109: 400.2635384059124.
# Compiling calculate_test_loss ...
# The training loss of step 110: 877.538459365564; the test loss of step 110: 400.5123223508284.
# Compiling calculate_test_loss ...
# The training loss of step 111: 877.5547758673333; the test loss of step 111: 400.89964553289724.
# Compiling calculate_test_loss ...
# The training loss of step 112: 877.5457541980493; the test loss of step 112: 401.3621305195729.
# Compiling calculate_test_loss ...
# The training loss of step 113: 877.5964344294807; the test loss of step 113: 401.85685909551813.
# Compiling calculate_test_loss ...
# The training loss of step 114: 877.5619176580651; the test loss of step 114: 402.3637675079499.
# Compiling calculate_test_loss ...
# The training loss of step 115: 877.5834064363644; the test loss of step 115: 402.77946871390077.
# Compiling calculate_test_loss ...
# The training loss of step 116: 877.600779263656; the test loss of step 116: 403.0859575441916.
# Compiling calculate_test_loss ...
# The training loss of step 117: 877.6126039010038; the test loss of step 117: 403.23411856257246.
# Compiling calculate_test_loss ...
# The training loss of step 118: 877.6382509639955; the test loss of step 118: 403.2423008619081.
# Compiling calculate_test_loss ...
# The training loss of step 119: 877.6306760813734; the test loss of step 119: 403.07554612484614.
# Compiling calculate_test_loss ...
# The training loss of step 120: 877.6310359534978; the test loss of step 120: 402.7928088420065.
# Compiling calculate_test_loss ...
# The training loss of step 121: 877.6193945463444; the test loss of step 121: 402.495978341602.
# Compiling calculate_test_loss ...
# The training loss of step 122: 877.5670509915049; the test loss of step 122: 402.14584355687595.
# Compiling calculate_test_loss ...
# The training loss of step 123: 877.5596607862431; the test loss of step 123: 401.7853552733577.
# Compiling calculate_test_loss ...
# The training loss of step 124: 877.5649617099162; the test loss of step 124: 401.46001993026044.
# Compiling calculate_test_loss ...
# The training loss of step 125: 877.5272740164802; the test loss of step 125: 401.13745991019005.
# Compiling calculate_test_loss ...
# The training loss of step 126: 877.4883971124384; the test loss of step 126: 400.95972469139457.
# Compiling calculate_test_loss ...
# The training loss of step 127: 877.4881506155532; the test loss of step 127: 400.8321061393176.
# Compiling calculate_test_loss ...
# The training loss of step 128: 877.4884097669988; the test loss of step 128: 400.8316416475164.
# Compiling calculate_test_loss ...
# The training loss of step 129: 877.4819323898387; the test loss of step 129: 400.8352700125937.
# Compiling calculate_test_loss ...
# The training loss of step 130: 877.4862197651878; the test loss of step 130: 400.89235165081254.
# Compiling calculate_test_loss ...
# The training loss of step 131: 877.4943132341363; the test loss of step 131: 401.0451671815854.
# Compiling calculate_test_loss ...
# The training loss of step 132: 877.4682874797869; the test loss of step 132: 401.21870622807535.
# Compiling calculate_test_loss ...
# The training loss of step 133: 877.4605659842913; the test loss of step 133: 401.40542344264276.
# Compiling calculate_test_loss ...
# The training loss of step 134: 877.463242170209; the test loss of step 134: 401.5637030389893.
# Compiling calculate_test_loss ...
# The training loss of step 135: 877.4681888747575; the test loss of step 135: 401.7519194645952.
# Compiling calculate_test_loss ...
# The training loss of step 136: 877.4633348332707; the test loss of step 136: 401.8637496698641.
# Compiling calculate_test_loss ...
# The training loss of step 137: 877.4485841244895; the test loss of step 137: 401.8784106556961.
# Compiling calculate_test_loss ...
# The training loss of step 138: 877.4329907284184; the test loss of step 138: 401.7794990088291.
# Compiling calculate_test_loss ...
# The training loss of step 139: 877.4349053870492; the test loss of step 139: 401.62949999504946.
# Compiling calculate_test_loss ...
# The training loss of step 140: 877.4556649304168; the test loss of step 140: 401.4180178335166.
# Compiling calculate_test_loss ...
# The training loss of step 141: 877.4691427258233; the test loss of step 141: 401.3105444500926.
# Compiling calculate_test_loss ...
# The training loss of step 142: 877.4697405626177; the test loss of step 142: 401.1712701048013.
# Compiling calculate_test_loss ...
# The training loss of step 143: 877.436757224403; the test loss of step 143: 401.0817358784055.
# Compiling calculate_test_loss ...
# The training loss of step 144: 877.4309708479057; the test loss of step 144: 401.04150194783256.
# Compiling calculate_test_loss ...
# The training loss of step 145: 877.4508315994618; the test loss of step 145: 401.082300952047.
# Compiling calculate_test_loss ...
# The training loss of step 146: 877.4607587076317; the test loss of step 146: 401.14249081214945.
# Compiling calculate_test_loss ...
# The training loss of step 147: 877.4307619356748; the test loss of step 147: 401.25376606138747.
# Compiling calculate_test_loss ...
# The training loss of step 148: 877.4522074426259; the test loss of step 148: 401.3722319397169.
# Compiling calculate_test_loss ...
# The training loss of step 149: 877.4695731550529; the test loss of step 149: 401.53130867313837.
# Compiling calculate_test_loss ...
# The training loss of step 150: 877.4741550676979; the test loss of step 150: 401.6563174594759.
# Compiling calculate_test_loss ...
# The training loss of step 151: 877.4864578824181; the test loss of step 151: 401.755696459419.
# Compiling calculate_test_loss ...
# The training loss of step 152: 877.5216052995623; the test loss of step 152: 401.79743621019344.
# Compiling calculate_test_loss ...
# The training loss of step 153: 877.5375731903449; the test loss of step 153: 401.7509709074234.
# Compiling calculate_test_loss ...
# The training loss of step 154: 877.5115135379676; the test loss of step 154: 401.72801920518265.
# Compiling calculate_test_loss ...
# The training loss of step 155: 877.511026004687; the test loss of step 155: 401.7310166431542.
# Compiling calculate_test_loss ...
# The training loss of step 156: 877.4792026366681; the test loss of step 156: 401.6586601823701.
# Compiling calculate_test_loss ...
# The training loss of step 157: 877.4672763911897; the test loss of step 157: 401.59477448342426.
# Compiling calculate_test_loss ...
# The training loss of step 158: 877.4409457452263; the test loss of step 158: 401.6487173088168.
# Compiling calculate_test_loss ...
# The training loss of step 159: 877.4372242905026; the test loss of step 159: 401.6914202810542.
# Compiling calculate_test_loss ...
# The training loss of step 160: 877.4414995503273; the test loss of step 160: 401.7649828612023.
# Compiling calculate_test_loss ...
# The training loss of step 161: 877.4434804225693; the test loss of step 161: 401.7635147905197.
# Compiling calculate_test_loss ...
# The training loss of step 162: 877.3936416813792; the test loss of step 162: 401.7139981979954.
# Compiling calculate_test_loss ...
# The training loss of step 163: 877.3758613760102; the test loss of step 163: 401.81004015387765.
# Compiling calculate_test_loss ...
# The training loss of step 164: 877.3932270853039; the test loss of step 164: 401.7969282083388.
# Compiling calculate_test_loss ...
# The training loss of step 165: 877.3901172399909; the test loss of step 165: 401.85780376745123.
# Compiling calculate_test_loss ...
# The training loss of step 166: 877.4197935666045; the test loss of step 166: 401.86746775374974.
# Compiling calculate_test_loss ...
# The training loss of step 167: 877.4334403510884; the test loss of step 167: 401.87329626465555.
# Compiling calculate_test_loss ...
# The training loss of step 168: 877.4439852324613; the test loss of step 168: 401.8633856311384.
# Compiling calculate_test_loss ...
# The training loss of step 169: 877.4100090486281; the test loss of step 169: 401.75899971398115.
# Compiling calculate_test_loss ...
# The training loss of step 170: 877.4229874610717; the test loss of step 170: 401.5901399035153.
# Compiling calculate_test_loss ...
# The training loss of step 171: 877.3993070147758; the test loss of step 171: 401.3404364438708.
# Compiling calculate_test_loss ...
# The training loss of step 172: 877.3771117170642; the test loss of step 172: 401.08472715765004.
# Compiling calculate_test_loss ...
# The training loss of step 173: 877.338676007207; the test loss of step 173: 400.9174884967558.
# Compiling calculate_test_loss ...
# The training loss of step 174: 877.3538598300856; the test loss of step 174: 400.84350383016556.
# Compiling calculate_test_loss ...
# The training loss of step 175: 877.3580876447686; the test loss of step 175: 400.7553997759749.
# Compiling calculate_test_loss ...
# The training loss of step 176: 877.4078707698575; the test loss of step 176: 400.76642771776704.
# Compiling calculate_test_loss ...
# The training loss of step 177: 877.3958461558508; the test loss of step 177: 400.8432717654466.
# Compiling calculate_test_loss ...
# The training loss of step 178: 877.3864466167819; the test loss of step 178: 401.02993901345195.
# Compiling calculate_test_loss ...
# The training loss of step 179: 877.3805271680014; the test loss of step 179: 401.1899321642985.
# Compiling calculate_test_loss ...
# The training loss of step 180: 877.4262903027884; the test loss of step 180: 401.4544730829686.
# Compiling calculate_test_loss ...
# The training loss of step 181: 877.4181824488803; the test loss of step 181: 401.7413739088136.
# Compiling calculate_test_loss ...
# The training loss of step 182: 877.4687984766133; the test loss of step 182: 402.0069303679264.
# Compiling calculate_test_loss ...
# The training loss of step 183: 877.509003736239; the test loss of step 183: 402.1972852108697.
# Compiling calculate_test_loss ...
# The training loss of step 184: 877.5025611677813; the test loss of step 184: 402.38314849934005.
# Compiling calculate_test_loss ...
# The training loss of step 185: 877.5049703175671; the test loss of step 185: 402.4959453233116.
# Compiling calculate_test_loss ...
# The training loss of step 186: 877.5051195110195; the test loss of step 186: 402.436012806691.
# Compiling calculate_test_loss ...
# The training loss of step 187: 877.5336944995772; the test loss of step 187: 402.33255234685794.
# Compiling calculate_test_loss ...
# The training loss of step 188: 877.4540905927228; the test loss of step 188: 402.00568349149717.
# Compiling calculate_test_loss ...
# The training loss of step 189: 877.4193905905586; the test loss of step 189: 401.74059378802724.
# Compiling calculate_test_loss ...
# The training loss of step 190: 877.404879548031; the test loss of step 190: 401.5163146799122.
# Compiling calculate_test_loss ...
# The training loss of step 191: 877.3489294061874; the test loss of step 191: 401.39314473411775.
# Compiling calculate_test_loss ...
# The training loss of step 192: 877.3254965697218; the test loss of step 192: 401.25479105519645.
# Compiling calculate_test_loss ...
# The training loss of step 193: 877.3486559246486; the test loss of step 193: 401.1681392299461.
# Compiling calculate_test_loss ...
# The training loss of step 194: 877.3785842027146; the test loss of step 194: 401.22760735268923.
# Compiling calculate_test_loss ...
# The training loss of step 195: 877.3715385312497; the test loss of step 195: 401.33595822267426.
# Compiling calculate_test_loss ...
# The training loss of step 196: 877.3740953064242; the test loss of step 196: 401.47527817735806.
# Compiling calculate_test_loss ...
# The training loss of step 197: 877.3911803557199; the test loss of step 197: 401.72410731752535.
# Compiling calculate_test_loss ...
# The training loss of step 198: 877.4108244230865; the test loss of step 198: 401.7888225041674.
# Compiling calculate_test_loss ...
# The training loss of step 199: 877.4380088959384; the test loss of step 199: 401.95781912818245.
# Compiling calculate_test_loss ...
# The training loss of step 200: 877.4417651053526; the test loss of step 200: 402.0044811185397.
# Compiling calculate_test_loss ...
# The training loss of step 201: 877.4554103668684; the test loss of step 201: 402.0342943061494.
# Compiling calculate_test_loss ...
# The training loss of step 202: 877.4351871993522; the test loss of step 202: 402.02412849462684.
# Compiling calculate_test_loss ...
# The training loss of step 203: 877.4371359328551; the test loss of step 203: 401.9883598668647.
# Compiling calculate_test_loss ...
# The training loss of step 204: 877.4342534466437; the test loss of step 204: 401.9381785595631.
# Compiling calculate_test_loss ...
# The training loss of step 205: 877.4042806034043; the test loss of step 205: 401.9086943704798.
# Compiling calculate_test_loss ...
# The training loss of step 206: 877.3782861380043; the test loss of step 206: 401.82311969882073.
# Compiling calculate_test_loss ...
# The training loss of step 207: 877.3582382298636; the test loss of step 207: 401.79292890038585.
# Compiling calculate_test_loss ...
# The training loss of step 208: 877.3642397004571; the test loss of step 208: 401.77122224080813.
# Compiling calculate_test_loss ...
# The training loss of step 209: 877.3593377403381; the test loss of step 209: 401.73285374268795.
# Compiling calculate_test_loss ...
# The training loss of step 210: 877.3562527729607; the test loss of step 210: 401.71013529805515.
# Compiling calculate_test_loss ...
# The training loss of step 211: 877.3814202373269; the test loss of step 211: 401.660457384005.
# Compiling calculate_test_loss ...
# The training loss of step 212: 877.3654287479619; the test loss of step 212: 401.6559220445398.
# Compiling calculate_test_loss ...
# The training loss of step 213: 877.383581054266; the test loss of step 213: 401.6473560680905.
# Compiling calculate_test_loss ...
# The training loss of step 214: 877.3792910678892; the test loss of step 214: 401.58366654937777.
# Compiling calculate_test_loss ...
# The training loss of step 215: 877.3671359652835; the test loss of step 215: 401.55842670493104.
# Compiling calculate_test_loss ...
# The training loss of step 216: 877.3552429181088; the test loss of step 216: 401.573614179063.
# Compiling calculate_test_loss ...
# The training loss of step 217: 877.3459604029522; the test loss of step 217: 401.5890289376723.
# Compiling calculate_test_loss ...
# The training loss of step 218: 877.3273456665992; the test loss of step 218: 401.6398794128968.
# Compiling calculate_test_loss ...
# The training loss of step 219: 877.3187739712083; the test loss of step 219: 401.7147610141449.
# Compiling calculate_test_loss ...
# The training loss of step 220: 877.3101301480467; the test loss of step 220: 401.82291556707656.
# Compiling calculate_test_loss ...
# The training loss of step 221: 877.3295616320003; the test loss of step 221: 401.90665278213373.
# Compiling calculate_test_loss ...
# The training loss of step 222: 877.3335933859287; the test loss of step 222: 401.9975704827617.
# Compiling calculate_test_loss ...
# The training loss of step 223: 877.3300804679295; the test loss of step 223: 402.07273761094814.
# Compiling calculate_test_loss ...
# The training loss of step 224: 877.3570324085815; the test loss of step 224: 402.1310497972125.
# Compiling calculate_test_loss ...
# The training loss of step 225: 877.3974822378844; the test loss of step 225: 402.10795508629053.
# Compiling calculate_test_loss ...
# The training loss of step 226: 877.3655910345561; the test loss of step 226: 402.0625044052403.
# Compiling calculate_test_loss ...
# The training loss of step 227: 877.3603338000331; the test loss of step 227: 402.06618656679217.
# Compiling calculate_test_loss ...
# The training loss of step 228: 877.3592837183955; the test loss of step 228: 401.9996476444605.
# Compiling calculate_test_loss ...
# The training loss of step 229: 877.3377560283326; the test loss of step 229: 401.9330840361461.
# Compiling calculate_test_loss ...
# The training loss of step 230: 877.3180256774664; the test loss of step 230: 401.8296554648254.
# Compiling calculate_test_loss ...
# The training loss of step 231: 877.311027303425; the test loss of step 231: 401.6894567447568.
# Compiling calculate_test_loss ...
# The training loss of step 232: 877.3046861057157; the test loss of step 232: 401.6067076345576.
# Compiling calculate_test_loss ...
# The training loss of step 233: 877.3048112006783; the test loss of step 233: 401.44966233075627.
# Compiling calculate_test_loss ...
# The training loss of step 234: 877.286130322183; the test loss of step 234: 401.33403741477395.
# Compiling calculate_test_loss ...
# The training loss of step 235: 877.3116293184889; the test loss of step 235: 401.24511357816664.
# Compiling calculate_test_loss ...
# The training loss of step 236: 877.3025173302692; the test loss of step 236: 401.1688637460387.
# Compiling calculate_test_loss ...
# The training loss of step 237: 877.2865462674274; the test loss of step 237: 401.0771791019386.
# Compiling calculate_test_loss ...
# The training loss of step 238: 877.2921263183; the test loss of step 238: 400.9845927711811.
# Compiling calculate_test_loss ...
# The training loss of step 239: 877.2933306176293; the test loss of step 239: 400.9593941803523.
# Compiling calculate_test_loss ...
# The training loss of step 240: 877.3087973421054; the test loss of step 240: 400.9510218563998.
# Compiling calculate_test_loss ...
# The training loss of step 241: 877.3058333578304; the test loss of step 241: 400.9196983652736.
# Compiling calculate_test_loss ...
# The training loss of step 242: 877.2808875092938; the test loss of step 242: 400.94603913913704.
# Compiling calculate_test_loss ...
# The training loss of step 243: 877.2729231522028; the test loss of step 243: 400.9957131601956.
# Compiling calculate_test_loss ...
# The training loss of step 244: 877.2616483836432; the test loss of step 244: 401.09467909027427.
# Compiling calculate_test_loss ...
# The training loss of step 245: 877.2708189146942; the test loss of step 245: 401.19085222785907.
# Compiling calculate_test_loss ...
# The training loss of step 246: 877.2790822824518; the test loss of step 246: 401.29373721266273.
# Compiling calculate_test_loss ...
# The training loss of step 247: 877.28576164518; the test loss of step 247: 401.4254951482023.
# Compiling calculate_test_loss ...
# The training loss of step 248: 877.2782613183123; the test loss of step 248: 401.5109922398691.
# Compiling calculate_test_loss ...
# The training loss of step 249: 877.2603738373532; the test loss of step 249: 401.59672674892664.
# Compiling calculate_test_loss ...
# The training loss of step 250: 877.2370986362595; the test loss of step 250: 401.6502104621307.
# Compiling calculate_test_loss ...
# The training loss of step 251: 877.2795833002722; the test loss of step 251: 401.70814816818944.
# Compiling calculate_test_loss ...
# The training loss of step 252: 877.2744759684617; the test loss of step 252: 401.75746918582263.
# Compiling calculate_test_loss ...
# The training loss of step 253: 877.2424143709816; the test loss of step 253: 401.77429849315297.
# Compiling calculate_test_loss ...
# The training loss of step 254: 877.2393211066899; the test loss of step 254: 401.75844891982536.
# Compiling calculate_test_loss ...
# The training loss of step 255: 877.2328866466462; the test loss of step 255: 401.7075311489315.
# Compiling calculate_test_loss ...
# The training loss of step 256: 877.2395969145516; the test loss of step 256: 401.61795858899654.
# Compiling calculate_test_loss ...
# The training loss of step 257: 877.2495150649979; the test loss of step 257: 401.5620058538466.
# Compiling calculate_test_loss ...
# The training loss of step 258: 877.2898394688555; the test loss of step 258: 401.5440020556637.
# Compiling calculate_test_loss ...
# The training loss of step 259: 877.2548536387544; the test loss of step 259: 401.483748188739.
# Compiling calculate_test_loss ...
# The training loss of step 260: 877.2487235621363; the test loss of step 260: 401.43145721175017.
# Compiling calculate_test_loss ...
# The training loss of step 261: 877.2228422283997; the test loss of step 261: 401.3884709001605.
# Compiling calculate_test_loss ...
# The training loss of step 262: 877.2377617248476; the test loss of step 262: 401.3590456710109.
# Compiling calculate_test_loss ...
# The training loss of step 263: 877.2440158920772; the test loss of step 263: 401.3649541397017.
# Compiling calculate_test_loss ...
# The training loss of step 264: 877.2366917178636; the test loss of step 264: 401.4289967059437.
# Compiling calculate_test_loss ...
# The training loss of step 265: 877.233568021576; the test loss of step 265: 401.4085288472273.
# Compiling calculate_test_loss ...
# The training loss of step 266: 877.2683215259281; the test loss of step 266: 401.5425081394829.
# Compiling calculate_test_loss ...
# The training loss of step 267: 877.2957214888477; the test loss of step 267: 401.69041632641483.
# Compiling calculate_test_loss ...
# The training loss of step 268: 877.286375400075; the test loss of step 268: 401.8358544955457.
# Compiling calculate_test_loss ...
# The training loss of step 269: 877.2992685239083; the test loss of step 269: 402.0140970677721.
# Compiling calculate_test_loss ...
# The training loss of step 270: 877.2932713188058; the test loss of step 270: 402.2130082118361.
# Compiling calculate_test_loss ...
# The training loss of step 271: 877.299638679933; the test loss of step 271: 402.37209852942505.
# Compiling calculate_test_loss ...
# The training loss of step 272: 877.3066999800715; the test loss of step 272: 402.42562527969386.
# Compiling calculate_test_loss ...
# The training loss of step 273: 877.3257540480904; the test loss of step 273: 402.48282215130456.
# Compiling calculate_test_loss ...
# The training loss of step 274: 877.3426515658364; the test loss of step 274: 402.4550932236313.
# Compiling calculate_test_loss ...
# The training loss of step 275: 877.3406147631181; the test loss of step 275: 402.3326553202922.
# Compiling calculate_test_loss ...
# The training loss of step 276: 877.2884590320105; the test loss of step 276: 402.1475005403488.
# Compiling calculate_test_loss ...
# The training loss of step 277: 877.2834562349351; the test loss of step 277: 401.9153221358581.
# Compiling calculate_test_loss ...
# The training loss of step 278: 877.2714186689687; the test loss of step 278: 401.7196953069836.
# Compiling calculate_test_loss ...
# The training loss of step 279: 877.2562869840956; the test loss of step 279: 401.51316432870976.
# Compiling calculate_test_loss ...
# The training loss of step 280: 877.2360475636563; the test loss of step 280: 401.38842138719804.
# Compiling calculate_test_loss ...
# The training loss of step 281: 877.293436190433; the test loss of step 281: 401.28352401115035.
# Compiling calculate_test_loss ...
# The training loss of step 282: 877.2398548900509; the test loss of step 282: 401.2151876976877.
# Compiling calculate_test_loss ...
# The training loss of step 283: 877.2053362390944; the test loss of step 283: 401.1914413471352.
# Compiling calculate_test_loss ...
# The training loss of step 284: 877.2037156107335; the test loss of step 284: 401.2057649035659.
# Compiling calculate_test_loss ...
# The training loss of step 285: 877.2165934320409; the test loss of step 285: 401.30415635239984.
# Compiling calculate_test_loss ...
# The training loss of step 286: 877.2362963407396; the test loss of step 286: 401.400948591687.
# Compiling calculate_test_loss ...
# The training loss of step 287: 877.2263101395275; the test loss of step 287: 401.56016547192263.
# Compiling calculate_test_loss ...
# The training loss of step 288: 877.2454470311925; the test loss of step 288: 401.6950390869606.
# Compiling calculate_test_loss ...
# The training loss of step 289: 877.2950018848007; the test loss of step 289: 401.7905622884898.
# Compiling calculate_test_loss ...
# The training loss of step 290: 877.2833639237574; the test loss of step 290: 401.8923121800791.
# Compiling calculate_test_loss ...
# The training loss of step 291: 877.3033144921789; the test loss of step 291: 401.98226769741.
# Compiling calculate_test_loss ...
# The training loss of step 292: 877.2979570957918; the test loss of step 292: 402.04827480776123.
# Compiling calculate_test_loss ...
# The training loss of step 293: 877.2843013956485; the test loss of step 293: 402.0624683164328.
# Compiling calculate_test_loss ...
# The training loss of step 294: 877.2964370424723; the test loss of step 294: 402.05173029767167.
# Compiling calculate_test_loss ...
# The training loss of step 295: 877.2977981924389; the test loss of step 295: 402.014615088322.
# Compiling calculate_test_loss ...
# The training loss of step 296: 877.2617711900357; the test loss of step 296: 402.028458842423.
# Compiling calculate_test_loss ...
# The training loss of step 297: 877.2269030868956; the test loss of step 297: 401.9918901573567.
# Compiling calculate_test_loss ...
# The training loss of step 298: 877.2494376676475; the test loss of step 298: 401.9759215245519.
# Compiling calculate_test_loss ...
# The training loss of step 299: 877.2740155311807; the test loss of step 299: 401.93033379753064.

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.plot(loss_train_set, label='Train')
ax.plot(loss_test_set, label='Test')
ax.set(xlabel="Epochs", ylabel="L2", title="Loss function", yscale="linear");
ax.legend()

# %% [markdown]
# ## Rerun the model using the estimated parameters

# %% [markdown]
# ### Calibration period

# %%
states, drivers = canoak_eqx_new(met)
(
    met_new,
    prof_new,
    ir_new,
    qin_new,
    sun_new,
    shade_new,
    soil_new,
    veg_new,
    can_new,
) = states
# quantum, nir, rnet, sun_ang, leaf_ang, lai = drivers
# met, prof, ir, qin, sun, shade, soil, veg, can = run_canoak_in_batch(batched_met, canoak_eqx_ift)

# %%
plot_obs_comparison(obs, can_new);

# %%
plot_timeseries_obs_1to1(
    obs.LE,
    can_new.LE,
    lim=[-100, 400],
    met=met,
    varn="Latent heat fluxes [W m-2]",
);

# %% [markdown]
# ### Test period

# %%
states_test, drivers_test = canoak_eqx_new(met_test)
(
    _,
    prof_test,
    ir_test,
    qin_test,
    sun_test,
    shade_test,
    soil_test,
    veg_test,
    can_test,
) = states_test

# %%
plot_obs_comparison(obs_test, can_test);

# %%
plot_timeseries_obs_1to1(
    obs_test.LE,
    can_test.LE,
    lim=[-100, 200],
    met=met_test,
    varn="Latent heat fluxes [W m-2]",
);

# %%
metrics = compute_metrics(obs.LE, can_new.LE)
metrics_test = compute_metrics(obs_test.LE, can_test.LE)
print(metrics)
print(metrics_test)
# Out:
# {'rmse': 29.619519673249833, 'mse': 877.3159456740339, 'r2': 0.11599187994389337, 'kge': 0.22209363773438573, 'nse': -0.6876819587250875, 'mkge': 0.32069651162436763, 'cc': 0.4902032649545927, 'alpha': 1.4467016934003332, 'beta': 0.9550765610218853}
# {'rmse': 20.048200263303727, 'mse': 401.9303337975316, 'r2': -0.5641597924295794, 'kge': 0.4149959987119499, 'nse': 0.2569157508584282, 'mkge': 0.5034686110883242, 'cc': 0.5978348174891087, 'alpha': 0.7102950534435687, 'beta': 0.9703751777849285}

# %% [markdown]
# # Save the models

# %%
config = {
    "site": site,
    "key": key,
    "f_forcing": f_forcing,
    "f_obs": f_obs,
    "f_forcing_test": f_forcing_test,
    "f_obs_test": f_obs_test,
}

train = {
    "loss": loss_train_set,
    "time": timesteps,
    "can.LE": can_new.LE,
    "sun.gs": sun_new.gs,
    "shade.gs": shade_new.gs,
    "sun.Ps": sun_new.Ps,
    "shade.Ps": shade_new.Ps,
    "can.H": can_new.H,
    "can.rnet": can_new.rnet,
    "can.gsoil": can_new.gsoil,
    "sun.Tlk": sun_new.Tsfc,
    "shade.Tlk": shade_new.Tsfc,
    "sun.Leaf_RH": sun_new.Leaf_RH,
    "shade.Leaf_RH": shade_new.Leaf_RH,
    "soil.Tsoil": soil_new.T_soil,
}

test = {
    "loss": loss_test_set,
    "time": timesteps_test,
    "can.LE": can_test.LE,
    "sun.gs": sun_test.gs,
    "shade.gs": shade_test.gs,
    "sun.Ps": sun_test.Ps,
    "shade.Ps": shade_test.Ps,
    "can.H": can_test.H,
    "can.rnet": can_test.rnet,
    "can.gsoil": can_test.gsoil,
    "sun.Tlk": sun_test.Tsfc,
    "shade.Tlk": shade_test.Tsfc,
    "sun.Leaf_RH": sun_test.Leaf_RH,
    "shade.Leaf_RH": shade_test.Leaf_RH,
    "soil.Tsoil": soil_test.T_soil,
}

out = {"train": train, "test": test, "config": config}
pickle.dump(out, open(f"{site}_{key}.pkl", "wb"), pickle.HIGHEST_PROTOCOL)

# %%
# Save the model
hyperparams = dict(
    time_zone=time_zone,
    latitude=latitude,
    longitude=longitude,
    stomata=stomata,
    veg_ht=veg_ht,
    leafangle=leafangle,
    n_can_layers=n_can_layers,
    n_atmos_layers=n_atmos_layers,
    meas_ht=meas_ht,
    soil_depth=soil_depth,
    n_hr_per_day=n_hr_per_day,
    n_time=n_time,
    npart=int(1e6),
    niter=niter,
)

save_model(f_model, hyperparams, canoak_eqx_new)
